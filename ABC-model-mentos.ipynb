# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Applying-MENTOS-to-the-ABC-model" data-toc-modified-id="Applying-MENTOS-to-the-ABC-model-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Applying MENTOS to the ABC model</a></div><div class="lev2 toc-item"><a href="#From-chemical-potential-to-standard-free-energy-of-the-reaction" data-toc-modified-id="From-chemical-potential-to-standard-free-energy-of-the-reaction-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>From chemical potential to standard free energy of the reaction</a></div><div class="lev1 toc-item"><a href="#Convex-problem-formulation-for-MENTOS" data-toc-modified-id="Convex-problem-formulation-for-MENTOS-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Convex problem formulation for MENTOS</a></div><div class="lev2 toc-item"><a href="#Predicting-steady-state-fluxes-of-the-ABC-model" data-toc-modified-id="Predicting-steady-state-fluxes-of-the-ABC-model-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Predicting steady state fluxes of the ABC model</a></div><div class="lev2 toc-item"><a href="#Using-energy-barriers-and-sinks-to-constrain-the-internal-potentials" data-toc-modified-id="Using-energy-barriers-and-sinks-to-constrain-the-internal-potentials-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Using energy barriers and sinks to constrain the internal potentials</a></div><div class="lev3 toc-item"><a href="#Intensional-constraints" data-toc-modified-id="Intensional-constraints-221"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Intensional constraints</a></div><div class="lev2 toc-item"><a href="#Solving-for-the-product-concentrations-that-yield-equilibrium" data-toc-modified-id="Solving-for-the-product-concentrations-that-yield-equilibrium-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Solving for the product concentrations that yield equilibrium</a></div><div class="lev3 toc-item"><a href="#Extensional-constraints" data-toc-modified-id="Extensional-constraints-231"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Extensional constraints</a></div><div class="lev2 toc-item"><a href="#mTOW-algorithm" data-toc-modified-id="mTOW-algorithm-24"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>mTOW algorithm</a></div><div class="lev2 toc-item"><a href="#Combining-energy-minimization-and-FBA-using-the-external-free-energy-as-a-constraint-on-the-Delta-G-of-each-reaction" data-toc-modified-id="Combining-energy-minimization-and-FBA-using-the-external-free-energy-as-a-constraint-on-the-Delta-G-of-each-reaction-25"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Combining energy minimization and FBA using the external free energy as a constraint on the $\Delta G$ of each reaction</a></div><div class="lev2 toc-item"><a href="#Using-the-external-free-energy-as-a-constraint-on-the-Delta-G-of-each-reaction" data-toc-modified-id="Using-the-external-free-energy-as-a-constraint-on-the-Delta-G-of-each-reaction-26"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Using the external free energy as a constraint on the $\Delta G$ of each reaction</a></div><div class="lev3 toc-item"><a href="#Likelihoods-first-then-FBA" data-toc-modified-id="Likelihoods-first-then-FBA-261"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Likelihoods first then FBA</a></div><div class="lev3 toc-item"><a href="#FBA-first,-then-likelihoods" data-toc-modified-id="FBA-first,-then-likelihoods-262"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>FBA first, then likelihoods</a></div><div class="lev2 toc-item"><a href="#Solving-for-convex-mentos-without-FBA" data-toc-modified-id="Solving-for-convex-mentos-without-FBA-27"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Solving for convex mentos without FBA</a></div><div class="lev2 toc-item"><a href="#Convex-mentos-solving-for-likelihoods-then-fluxes-without-FBA" data-toc-modified-id="Convex-mentos-solving-for-likelihoods-then-fluxes-without-FBA-28"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Convex mentos solving for likelihoods then fluxes without FBA</a></div><div class="lev2 toc-item"><a href="#maximizing-entropy-of-the-log-likelihoods-of-the-ABC-model" data-toc-modified-id="maximizing-entropy-of-the-log-likelihoods-of-the-ABC-model-29"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>maximizing entropy of the log likelihoods of the ABC model</a></div><div class="lev1 toc-item"><a href="#Nonconvex-formulations-of-MENTOS" data-toc-modified-id="Nonconvex-formulations-of-MENTOS-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Nonconvex formulations of MENTOS</a></div><div class="lev2 toc-item"><a href="#Maximize-entropy-production-for-the-ABC-model" data-toc-modified-id="Maximize-entropy-production-for-the-ABC-model-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Maximize entropy production for the ABC model</a></div><div class="lev2 toc-item"><a href="#Minimize-entropy-production-for-the-ABC-model" data-toc-modified-id="Minimize-entropy-production-for-the-ABC-model-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Minimize entropy production for the ABC model</a></div><div class="lev2 toc-item"><a href="#Maximize-microscopic-entropy-production-net-flux-difference-using-external-free-energy-constraint-for-the-ABC-model" data-toc-modified-id="Maximize-microscopic-entropy-production-net-flux-difference-using-external-free-energy-constraint-for-the-ABC-model-33"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Maximize microscopic entropy production net flux difference using external free energy constraint for the ABC model</a></div><div class="lev2 toc-item"><a href="#Maximize-microscopic-entropy-production-net-flux-difference-using-energy-barrier/sink-as-constraints-on-each-potential-for-the-ABC-model" data-toc-modified-id="Maximize-microscopic-entropy-production-net-flux-difference-using-energy-barrier/sink-as-constraints-on-each-potential-for-the-ABC-model-34"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Maximize microscopic entropy production net flux difference using energy barrier/sink as constraints on each potential for the ABC model</a></div><div class="lev2 toc-item"><a href="#Maximize-microscopic-entropy-production-net-flux-for-the-ABC-model" data-toc-modified-id="Maximize-microscopic-entropy-production-net-flux-for-the-ABC-model-35"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Maximize microscopic entropy production net flux for the ABC model</a></div><div class="lev3 toc-item"><a href="#PyOpt-optimization" data-toc-modified-id="PyOpt-optimization-351"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>PyOpt optimization</a></div><div class="lev3 toc-item"><a href="#Scipy-Optimization" data-toc-modified-id="Scipy-Optimization-352"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Scipy Optimization</a></div><div class="lev2 toc-item"><a href="#Maximize-microscopic-entropy-production-rate-for-the-ABC-model" data-toc-modified-id="Maximize-microscopic-entropy-production-rate-for-the-ABC-model-36"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Maximize microscopic entropy production rate for the ABC model</a></div><div class="lev2 toc-item"><a href="#Maximize-macroscopic-entropy-production-rate-for-the-ABC-model" data-toc-modified-id="Maximize-macroscopic-entropy-production-rate-for-the-ABC-model-37"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Maximize macroscopic entropy production rate for the ABC model</a></div><div class="lev3 toc-item"><a href="#Scipy.optimize-with-scipy.stats.entropy" data-toc-modified-id="Scipy.optimize-with-scipy.stats.entropy-371"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>Scipy.optimize with scipy.stats.entropy</a></div><div class="lev3 toc-item"><a href="#PyOpt-with-scipy.stats.entropy" data-toc-modified-id="PyOpt-with-scipy.stats.entropy-372"><span class="toc-item-num">3.7.2&nbsp;&nbsp;</span>PyOpt with scipy.stats.entropy</a></div><div class="lev3 toc-item"><a href="#PyOpt-without-scipy.stats.entropy" data-toc-modified-id="PyOpt-without-scipy.stats.entropy-373"><span class="toc-item-num">3.7.3&nbsp;&nbsp;</span>PyOpt without scipy.stats.entropy</a></div><div class="lev2 toc-item"><a href="#Maximize-macroscopic-entropy-production-rate-with-steady-state-constraint-for-net-likelihoods-for-the-ABC-model" data-toc-modified-id="Maximize-macroscopic-entropy-production-rate-with-steady-state-constraint-for-net-likelihoods-for-the-ABC-model-38"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Maximize macroscopic entropy production rate with steady state constraint for net likelihoods for the ABC model</a></div><div class="lev3 toc-item"><a href="#SS-Net-likelihood-Scipy.optimize-with-scipy.stats.entropy" data-toc-modified-id="SS-Net-likelihood-Scipy.optimize-with-scipy.stats.entropy-381"><span class="toc-item-num">3.8.1&nbsp;&nbsp;</span>SS Net likelihood Scipy.optimize with scipy.stats.entropy</a></div><div class="lev3 toc-item"><a href="#SS-net-likelihood-PyOpt-optimize-w-SciPy-entropy" data-toc-modified-id="SS-net-likelihood-PyOpt-optimize-w-SciPy-entropy-382"><span class="toc-item-num">3.8.2&nbsp;&nbsp;</span>SS net likelihood PyOpt optimize w SciPy entropy</a></div><div class="lev2 toc-item"><a href="#Maximize-macroscopic-entropy-production-net-flux-difference-for-the-ABC-model" data-toc-modified-id="Maximize-macroscopic-entropy-production-net-flux-difference-for-the-ABC-model-39"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Maximize macroscopic entropy production net flux difference for the ABC model</a></div><div class="lev1 toc-item"><a href="#Use-probabilities-as-decision-variables" data-toc-modified-id="Use-probabilities-as-decision-variables-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Use probabilities as decision variables</a></div><div class="lev1 toc-item"><a href="#Comparing-the-predictions-of-alternative-objective-functions" data-toc-modified-id="Comparing-the-predictions-of-alternative-objective-functions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Comparing the predictions of alternative objective functions</a></div><div class="lev1 toc-item"><a href="#Boltzmann-comparison" data-toc-modified-id="Boltzmann-comparison-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Boltzmann comparison</a></div><div class="lev2 toc-item"><a href="#Computing-the-forward-and-reverse-rates-from-the-likelihood-and-the-flux" data-toc-modified-id="Computing-the-forward-and-reverse-rates-from-the-likelihood-and-the-flux-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Computing the forward and reverse rates from the likelihood and the flux</a></div><div class="lev2 toc-item"><a href="#Comparing-Boltzmann-output-vs-various-mentos-variations" data-toc-modified-id="Comparing-Boltzmann-output-vs-various-mentos-variations-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Comparing Boltzmann output vs various mentos variations</a></div>

# %% [markdown]
# # Applying MENTOS to the ABC model #

# %%
import mentos
from IPython.display import Image, display
import sys
from scipy.stats import entropy
import numpy as np
import cvxpy as cvx
import pandas as pd
import sys, cobra, re
from IPython.display import display, HTML
#import pandas.core.format as fmt
pd.options.display.float_format = '{:.3g}'.format 
#pd.options.display.float_+ormat = '{:.0f}'.format

pd.options.display.float_format = '{:.3g}'.format

reactions = {}
metab = {}

def print_report( report_dir, out_template, df ):
    nonalphanumRE = re.compile(r'[^A-Za-z0-9_]')
    if not os.path.isdir(report_dir):
        os.mkdir(report_dir)
    for c in df.columns:
        df[c].to_csv(os.path.join(report_dir,out_template.format(nonalphanumRE.sub('_', c))),header=True)

Image('Metabolic-network.JPG')

# %% [markdown]
# The chemical equations for the ABC model are:
#
# $$
# \begin{eqnarray}
#  A_{ext} & \overset{\overset{+1}{\rightharpoonup}}{\underset{-1}{\leftharpoondown}} & A \\
#   A & \overset{\overset{+2}{\rightharpoonup}}{\underset{-2}{\leftharpoondown}} & B \\
#  A & \overset{\overset{+3}{\rightharpoonup}}{\underset{-3}{\leftharpoondown}} & C \\
#  B + E & \overset{\overset{+4}{\rightharpoonup}}{\underset{-4}{\leftharpoondown}}& 2D\\
#  E_{ext} & \overset{\overset{+5}{\rightharpoonup}}{\underset{-5}{\leftharpoondown}} & E \\
#  2B & \overset{\overset{+6}{\rightharpoonup}}{\underset{-6}{\leftharpoondown}} & C + F \\
#  C &\overset{\overset{+7}{\rightharpoonup}}{\underset{-7}{\leftharpoondown}} & D \\
#  D & \overset{\overset{+8}{\rightharpoonup}}{\underset{-8}{\leftharpoondown}}& D_{ext} \\
#  F &\overset{\overset{+9}{\rightharpoonup}}{\underset{-9}{\leftharpoondown}} & F_{ext} \\
# \end{eqnarray}
# $$
#  which can be represented as a Stoichiometric matrix $S_{full}$:
#
# $$
# S_{full} = \left[ {\begin{array}{cccccccccc}
#   & R_1 & R_2 & R_3 & R_4 & R_5 & R_6 & R_7 & R_8 & R_9 \\
# A & 1   & -1  & -1  & 0   & 0   & 0   & 0   & 0   & 0   \\
# B & 0   &  1  & 0   & -1  & 0   & -2  & 0   & 0   & 0   \\
# C & 0   &  0  & 1   & 0   & 0   & 1   & -1  & 0   & 0   \\
# D & 0   &  0  & 0   & 2   & 0   & 0   &  1  & -1  & 0   \\
# E & 0   &  0  & 0   & -1   & 1   & 0   &  0  & 0  & 0   \\
# F & 0   &  0  & 0   &  0   & 0   & 1   &  0  & 0  & -1   \\
# A_{ext} & -1  & 0  & 0  & 0   & 0   & 0   & 0   & 0   & 0   \\
# E_{ext} & 0   & 0  & 0  & 0   & -1   & 0   & 0   & 0   & 0   \\
# D_{ext} & 0   & 0  & 0  & 0   & 0   & 0   & 0   & 1   & 0   \\
# F_{ext} & 0   & 0  & 0  & 0   & 0   & 0   & 0   & 0   & 1   \\
# \end{array}}\right]
# $$

# %%
from mentos.abc_model import fullS
fullS
# Out:
#        R_1  R_2  R_3  R_4  R_5  R_6  R_7  R_8  R_9
# A        1   -1   -1    0    0    0    0    0    0
# B        0    1    0   -1    0   -2    0    0    0
# C        0    0    1    0    0    1   -1    0    0
# D        0    0    0    2    0    0    1   -1    0
# E        0    0    0   -1    1    0    0    0    0
# F        0    0    0    0    0    1    0    0   -1
# A_ext   -1    0    0    0    0    0    0    0    0
# D_ext    0    0    0    0    0    0    0    1    0
# E_ext    0    0    0    0   -1    0    0    0    0
# F_ext    0    0    0    0    0    0    0    0    1

# %% [markdown]
#  How do we predict  metabolite concentrations?  First we need to to obtain the chemical potential for each metabolite.
#
# ##  From chemical potential to standard free energy of the reaction ##
#
#
# Chemical potential $\vec{\mu}^0$ is the Gibbs energy of formation $\Delta G^0_+$ for each metabolite:
# $$
# \vec{\mu}^0 = \Delta \vec{G^0_+} = \left[ {\begin{array}{cc}
# A & 4 \\
# B & 2 \\
# C & 2 \\
# D & 0 \\
# E & 2 \\
# F & 1 \\
# \end{array}}\right]
# $$
#
# Which implies a Change in Standard Gibbs free energy $S^T\vec{\mu}^0 = \Delta G^0$ for each reaction:
# $$
# \Delta \vec{G}^0 = \left[ {\begin{array}{cc}
# R_1 & 0 \\
# R_2 & -2 \\
# R_3 & -2 \\
# R_4 & -4 \\
# R_5 & 0 \\
# R_6 & -1 \\
# R_7 & -2 \\
# R_8 & 0 \\
# R_9 & 0 \\
# \end{array}}\right]
# $$

# %%
from mentos.abc_model import mu0, deltaG0
display(pd.DataFrame(mu0,columns=['$\mu^0$']))
pd.DataFrame(mu0,columns=['$\mu^0$']).to_csv('ABC_standard_chemical_potential.csv', header=True)
display(pd.DataFrame(deltaG0,columns=['$\Delta G^0$']))

# %% [markdown]
# # Convex problem formulation for MENTOS #
#
#
# ## Predicting steady state fluxes of the ABC model##
# Steady-state fluxes can be predicted from flux balance analysis:
#
# $$\begin{array}{ll}
#     \underset{\vec{\bf v}}{\mbox{maximize}}   & v_{biomass} \\
#     \mbox{subject to}  & S\cdot v = 0 \\
#     & 0 \leq v \leq v_{upper} \\
# \end{array}$$

# %%
from mentos.abc_model import n, biomass, v_U, rxns, S
v = cvx.Variable(n)
obj = cvx.Maximize(v[biomass])
constraints = [S*v == 0,
              0 <= v,
              v <= v_U,
              v[0] == 10]
prob = cvx.Problem(obj, constraints)
prob.solve()
fluxes = pd.DataFrame(v.value, index=rxns, columns=['Fluxes'])
fluxes.to_csv('ABC_fba_fluxes.csv',header=True)
fluxes
# Out:
#       Fluxes
# R_1       10
# R_2       10
# R_3 9.05e-11
# R_4       10
# R_5       10
# R_6 1.34e-10
# R_7 2.23e-10
# R_8       20
# R_9 1.35e-10

# %% [markdown]
# ## Using energy barriers and sinks to constrain the internal potentials ##
# ### Intensional constraints ####
# The internal potentials are bounded below by the sum of the efflux potentials and above by the sum of the uptake potentials
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \|\log L_+\|_{2} \\
#     \mbox{subject to}  & \log L_+ = \log K_{eq} - \log Q_r \\
#     &  \log [c_{uptake}] = \log c_{upper}   \\
#     & \log [c_{efflux}] = \log c_{lower} \\
#     & \sum\mu_{efflux} \leq \vec{\mu} \leq \sum\mu_{uptake} \\
# \end{array}$$
#
# Where,
#
# $$\begin{eqnarray}
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, internal, n, m, R, T, biomass
   
algorithm = 'convex_mentos_intensional_constraints'
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)

log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods


thermodynamic_constraints = [log_likelihood == log_K - log_Q]
#met_boundary_constraints = [log_c[fullS.index.get_loc(ext)] == np.log(met_bounds.loc[ext])
#                            for ext in external_mets] 
efflux_constraints = [log_c[efflux] == np.log(c_L)]
uptake_constraints = [log_c[uptake] == np.log(c_U)]
energy_sink_constraints =  [cvx.sum_entries(mu[efflux]) <= mu[internal]]
energy_barrier_constraints = [mu[internal] <= cvx.sum_entries(mu[uptake])]
#energy_sink_constraints = [mu[fullS.index.get_loc(met)] >= cvx.sum_entries(mu[efflux])
#                               for met in internal_mets]   
#energy_barrier_constraints = [mu[fullS.index.get_loc(met)] <= cvx.sum_entries(mu[uptake])
#                                for met in internal_mets]




prob = cvx.Problem( cvx.Minimize( cvx.norm2(log_likelihood)), 
                    #   Subject to:
                                  thermodynamic_constraints + \
                                  efflux_constraints + \
                                  uptake_constraints + \
                                  energy_sink_constraints   + \
                                  energy_barrier_constraints)
prob.solve( )


v_L, v_U = mentos.get_rxn_bounds_from_log_likelihood( log_likelihood )
v = cvx.Variable(n)
obj = cvx.Maximize(v[biomass])
constraints = [S*v == 0,
              v_L <= v,
              v <= v_U]
cvx.Problem(obj, constraints).solve()

forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, v )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
                                                             , forward_rate, backward_rate, S, mets, internal_mets, 
                                                             mu0).astype(np.float64)
display(metab[algorithm].T)

reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')
display(reactions[algorithm].T)
# Out:
#                                    A         B        C        D         E  \
# Counts                      1.35e+03       148 1.35e+03      673  3.02e+03
# Concentrations              2.24e-06  2.47e-07 2.25e-06 1.12e-06  5.02e-06
# Log Concentrations               -13     -15.2      -13    -13.7     -12.2
# Standard Chemical potential        4         2        2        0         2
# Chemical potential             -28.2     -35.7    -30.2      -34     -28.2
# S*forward_rate                  -1.3     -2.69     1.36     2.55     -0.98
# S*backward_rate                 -1.3     -2.69     1.36     2.55     -0.98
# S*net_flux                  2.22e-16 -8.88e-16 1.22e-12 2.45e-12 -4.44e-16
#
#                                     F    A_ext  D_ext    E_ext  F_ext
# Counts                             12 6.02e+05      6 6.02e+05      6
# Concentrations               2.02e-08    0.001  1e-08    0.001  1e-08
# Log Concentrations              -17.7    -6.91  -18.4    -6.91  -18.4
# Standard Chemical potential         1        4      0        2      1
# Chemical potential              -42.9    -13.1  -45.7    -15.1  -44.7
# S*forward_rate              -1.05e-05      nan    nan      nan    nan
# S*backward_rate             -1.05e-05      nan    nan      nan    nan
# S*net_flux                   1.53e-10      nan    nan      nan    nan
#                                                         R_1     R_2      R_3  \
# Forward likelihoods                                     446    20.3     2.23
# Backward likelihoods                                0.00224  0.0493    0.448
# Delta G                                               -15.1   -7.46    -1.99
# log Q_r                                                -6.1    -2.2  0.00372
# log K_eq                                                 -0   0.807    0.807
# Delta G0                                                  0      -2       -2
# logK - logQ                                             6.1    3.01    0.803
# logQ - logK                                            -6.1   -3.01   -0.803
# Forward Log likelihoods                                 6.1    3.01    0.803
# Backward Log likelihoods                               -6.1   -3.01   -0.803
# Forward probabilities                                 0.561  0.0255  0.00281
# Backward probabilities                             2.82e-06 6.2e-05 0.000563
# Net probabilities                                     0.561  0.0255  0.00224
# Net likelihoods                                         446    20.2     1.78
# Forward rate                                           7.27    6.33     2.23
# Backward rate                                        0.0163   0.312        1
# Thermodynamic driving force                             446    20.3     2.23
# Net flux                                               7.25    6.02     1.23
# Forward Entropy Production                            0.324  0.0936   0.0165
# Backward Entropy Production                         3.6e-05  0.0006  0.00421
# Reaction Entropy Production                           0.324  0.0942   0.0207
# Microscopic Reaction Entropy Production Rate           2.36   0.593    0.041
# Microscopic Reaction Entropy Production Net Flux       2.35   0.567   0.0255
# Microscopic Reaction Entropy Production Net Flu...     2.35    0.56   0.0151
# Total Entropy Production                               1.17    1.17     1.17
# Total Microscopic Entropy Production Rate              7.39    7.39     7.39
# Macroscopic Reaction Entropy Production Net Flux       3.31   0.963    0.212
# Macroscopic Reaction Entropy Production Net Flu...     3.31    0.95    0.125
# Total Macroscopic Entropy Production Net Flux          11.9    11.9     11.9
# Total Macroscopic Entropy Production Net Flux D...     11.5    11.5     11.5
#
#                                                         R_4      R_5      R_6  \
# Forward likelihoods                                    4.98      199     2.02
# Backward likelihoods                                  0.201  0.00502    0.496
# Delta G                                               -3.98    -13.1    -1.74
# log Q_r                                             0.00752    -5.29   -0.299
# log K_eq                                               1.61       -0    0.403
# Delta G0                                                 -4        0       -1
# logK - logQ                                            1.61     5.29    0.702
# logQ - logK                                           -1.61    -5.29   -0.702
# Forward Log likelihoods                                1.61     5.29    0.702
# Backward Log likelihoods                              -1.61    -5.29   -0.702
# Forward probabilities                               0.00627     0.25  0.00254
# Backward probabilities                             0.000252 6.31e-06 0.000623
# Net probabilities                                   0.00601     0.25  0.00191
# Net likelihoods                                        4.78      199     1.52
# Forward rate                                           4.98        4     2.02
# Backward rate                                             1   0.0201        1
# Thermodynamic driving force                            4.98      199     2.02
# Net flux                                               3.98     3.98     1.02
# Forward Entropy Production                           0.0318    0.347   0.0152
# Backward Entropy Production                         0.00209 7.56e-05   0.0046
# Reaction Entropy Production                          0.0339    0.347   0.0198
# Microscopic Reaction Entropy Production Rate           0.16     1.39   0.0352
# Microscopic Reaction Entropy Production Net Flux      0.135     1.38   0.0201
# Microscopic Reaction Entropy Production Net Flu...    0.118     1.38   0.0108
# Total Entropy Production                               1.17     1.17     1.17
# Total Microscopic Entropy Production Rate              7.39     7.39     7.39
# Macroscopic Reaction Entropy Production Net Flux      0.346     3.54    0.202
# Macroscopic Reaction Entropy Production Net Flu...    0.303     3.54    0.108
# Total Macroscopic Entropy Production Net Flux          11.9     11.9     11.9
# Total Macroscopic Entropy Production Net Flux D...     11.5     11.5     11.5
#
#                                                         R_7      R_8      R_9
# Forward likelihoods                                     4.5      112     2.02
# Backward likelihoods                                  0.222  0.00894    0.496
# Delta G                                               -3.73    -11.7    -1.74
# log Q_r                                              -0.698    -4.72   -0.702
# log K_eq                                              0.807       -0       -0
# Delta G0                                                 -2        0        0
# logK - logQ                                            1.51     4.72    0.702
# logQ - logK                                           -1.51    -4.72   -0.702
# Forward Log likelihoods                                1.51     4.72    0.702
# Backward Log likelihoods                              -1.51    -4.72   -0.702
# Forward probabilities                               0.00566    0.141  0.00254
# Backward probabilities                             0.000279 1.12e-05 0.000623
# Net probabilities                                   0.00539    0.141  0.00191
# Net likelihoods                                        4.28      112     1.52
# Forward rate                                           2.89     10.3     2.02
# Backward rate                                         0.642   0.0922        1
# Thermodynamic driving force                             4.5      112     2.02
# Net flux                                               2.25     10.2     1.02
# Forward Entropy Production                           0.0293    0.276   0.0152
# Backward Entropy Production                         0.00228 0.000128   0.0046
# Reaction Entropy Production                          0.0316    0.276   0.0198
# Microscopic Reaction Entropy Production Rate         0.0862     2.84   0.0352
# Microscopic Reaction Entropy Production Net Flux     0.0711     2.82   0.0201
# Microscopic Reaction Entropy Production Net Flu...   0.0608     2.82   0.0108
# Total Entropy Production                               1.17     1.17     1.17
# Total Microscopic Entropy Production Rate              7.39     7.39     7.39
# Macroscopic Reaction Entropy Production Net Flux      0.323     2.82    0.202
# Macroscopic Reaction Entropy Production Net Flu...    0.276     2.82    0.108
# Total Macroscopic Entropy Production Net Flux          11.9     11.9     11.9
# Total Macroscopic Entropy Production Net Flux D...     11.5     11.5     11.5

# %% [markdown]
# ## Solving for the product concentrations that yield equilibrium ##

# %%
from mentos.abc_model import fullS, mu0, \
     mets, met_bounds,  \
     R, T
 
efflux_mets, uptake_mets = ['D_ext','F_ext'], ['A_ext','E_ext']
efflux_potential, rxn_df, uptake_potential = mentos.find_equilibrium( met_bounds, efflux_mets, 
                                                                     uptake_mets, fullS, mu0, R, T)
display(efflux_potential)
display(rxn_df)
display(uptake_potential)
# Out:
#        log_c_efflux  mu0_efflux  mu_efflux
# D_ext          -5.7           0      -14.1
# F_ext          -6.1           1      -14.1
#      Product_potential  Reactant_potential  deltaG
# R_1                  0               -13.1    13.1
# R_2                  0                  -0       0
# R_3                  0                  -0       0
# R_4                  0                  -0       0
# R_5                  0               -15.1    15.1
# R_6                  0                  -0       0
# R_7                  0                  -0       0
# R_8              -14.1                  -0   -14.1
# R_9              -14.1                  -0   -14.1
#        log_c_uptake  mu0_uptake  mu_uptake
# A_ext         -6.91           4      -13.1
# E_ext         -6.91           2      -15.1

# %%
c_L = 1e-8
external_mets = fullS.loc[fullS.index.str.contains(r'_ext?')].index

efflux = [fullS.index.get_loc(met) for met in met_bounds[met_bounds == c_L].index]
uptake = [fullS.index.get_loc(met) for met in met_bounds[met_bounds > c_L].index]

efflux_mets = [met for met in met_bounds[met_bounds == c_L].index]
uptake_mets = [met for met in met_bounds[met_bounds > c_L].index]
mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)

external_free_energy = fullS.T[external_mets].dot(mu_ext).sum() #dot(fluxes)
display(external_free_energy)

uptake_sum = fullS.T[uptake_mets].dot(mu_ext[uptake_mets]).sum()

efflux_sum =fullS.T[efflux_mets].dot(mu_ext[efflux_mets]).sum()
uptake_sum

log_c_efflux = cvx.Variable(len(efflux))

mu_efflux = log_c_efflux*R*T + mu0[efflux_mets].values


p = cvx.Problem(cvx.Minimize(cvx.norm2(mu_efflux)), 
                [cvx.sum_entries(fullS.T[efflux_mets].as_matrix()*mu_efflux) == -uptake_sum])
p.solve()
pd.DataFrame(np.exp(np.squeeze(np.asarray(log_c_efflux.value))), index=efflux_mets,columns=['Concentrations'])
# Out:
# -62.08007567828687
#        Concentrations
# D_ext         0.00335
# F_ext         0.00224

# %% [markdown]
# ### Extensional constraints ##
# The internal potentials are bounded below by the sum of the potentials of $D_{ext}$ and $F_{ext}$ and above by the sum of the potentials of $A_{ext}$ and $E_{ext}$
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \|\log L_+\|_{2} \\
#     \mbox{subject to}  & \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_A \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_B \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_C \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_D \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_E \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_F \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
# \end{array}$$
#
# Where,
#
# $$\begin{eqnarray}
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     A, B, C, D, E, F, A_ext, D_ext, E_ext, F_ext

algorithm = 'convex_mentos_extensional_constraints'
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)

log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods
obj  = cvx.Minimize(cvx.norm2(log_likelihood))
constraints = [log_likelihood == log_K - log_Q,
              log_c[A_ext] == cvx.log(c_U),             # Creating a concentration gradient between A, E and D,F
              log_c[E_ext] == cvx.log(c_U),
              log_c[D_ext] == cvx.log(c_L),
              log_c[F_ext] == cvx.log(c_L),
              mu[A] >= mu[D_ext] + mu[F_ext],           # Energy sink constraint
              mu[B] >= mu[D_ext] + mu[F_ext],
              mu[C] >= mu[D_ext] + mu[F_ext],
              mu[D] >= mu[D_ext] + mu[F_ext],
              mu[E] >= mu[D_ext] + mu[F_ext],
              mu[F] >= mu[D_ext] + mu[F_ext],
                
              mu[A] <= mu[A_ext] + mu[E_ext],           # Energy barrier constraint
              mu[B] <= mu[A_ext] + mu[E_ext],
              mu[C] <= mu[A_ext] + mu[E_ext],
              mu[D] <= mu[A_ext] + mu[E_ext],
              mu[E] <= mu[A_ext] + mu[E_ext],
              mu[F] <= mu[A_ext] + mu[E_ext],  
              ]



prob = cvx.Problem(obj, constraints )
prob.solve( )


v_L, v_U = mentos.get_rxn_bounds_from_log_likelihood( log_likelihood )


v = cvx.Variable(n)
obj = cvx.Maximize(v[biomass])
constraints = [S*v == 0,
              v_L <= v,
              v <= v_U]
cvx.Problem(obj, constraints).solve()

forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, v )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value)),
                                                      forward_rate, backward_rate, S, mets, internal_mets, 
                                                      mu0).astype(np.float64)

display(mentos.frame_differences(metab['convex_mentos_extensional_constraints'],
                                 metab['convex_mentos_intensional_constraints']))
reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')

display(mentos.frame_differences(reactions['convex_mentos_extensional_constraints'],
                                 reactions['convex_mentos_intensional_constraints']))
# Out:
#                                     A        B        C        D         E  \
# Counts                       1.35e+03      148 1.35e+03      673  3.02e+03
# Concentrations               2.24e-06 2.47e-07 2.25e-06 1.12e-06  5.02e-06
# Log Concentrations                -13    -15.2      -13    -13.7     -12.2
# Standard Chemical potential         4        2        2        0         2
# Chemical potential              -28.2    -35.7    -30.2      -34     -28.2
# S*forward_rate                   -1.3    -2.69     1.36     2.55     -0.98
# S*backward_rate                  -1.3    -2.69     1.36     2.55     -0.98
# S*net_flux                  -1.33e-15        0 1.22e-12 2.45e-12 -8.88e-16
#
#                                     F    A_ext  D_ext    E_ext  F_ext
# Counts                             12 6.02e+05      6 6.02e+05      6
# Concentrations               2.02e-08    0.001  1e-08    0.001  1e-08
# Log Concentrations              -17.7    -6.91  -18.4    -6.91  -18.4
# Standard Chemical potential         1        4      0        2      1
# Chemical potential              -42.9    -13.1  -45.7    -15.1  -44.7
# S*forward_rate              -1.05e-05      nan    nan      nan    nan
# S*backward_rate             -1.05e-05      nan    nan      nan    nan
# S*net_flux                   1.53e-10      nan    nan      nan    nan
#                                                         R_1     R_2      R_3  \
# Forward likelihoods                                     446    20.3     2.23
# Backward likelihoods                                0.00224  0.0493    0.448
# Delta G                                               -15.1   -7.46    -1.99
# log Q_r                                                -6.1    -2.2  0.00372
# log K_eq                                                 -0   0.807    0.807
# Delta G0                                                  0      -2       -2
# logK - logQ                                             6.1    3.01    0.803
# logQ - logK                                            -6.1   -3.01   -0.803
# Forward Log likelihoods                                 6.1    3.01    0.803
# Backward Log likelihoods                               -6.1   -3.01   -0.803
# Forward probabilities                                 0.561  0.0255  0.00281
# Backward probabilities                             2.82e-06 6.2e-05 0.000563
# Net probabilities                                     0.561  0.0255  0.00224
# Net likelihoods                                         446    20.2     1.78
# Forward rate                                           7.27    6.33     2.23
# Backward rate                                        0.0163   0.312        1
# Thermodynamic driving force                             446    20.3     2.23
# Net flux                                               7.25    6.02     1.23
# Forward Entropy Production                            0.324  0.0936   0.0165
# Backward Entropy Production                         3.6e-05  0.0006  0.00421
# Reaction Entropy Production                           0.324  0.0942   0.0207
# Microscopic Reaction Entropy Production Rate           2.36   0.593    0.041
# Microscopic Reaction Entropy Production Net Flux       2.35   0.567   0.0255
# Microscopic Reaction Entropy Production Net Flu...     2.35    0.56   0.0151
# Total Entropy Production                               1.17    1.17     1.17
# Total Microscopic Entropy Production Rate              7.39    7.39     7.39
# Macroscopic Reaction Entropy Production Net Flux       3.31   0.963    0.212
# Macroscopic Reaction Entropy Production Net Flu...     3.31    0.95    0.125
# Total Macroscopic Entropy Production Net Flux          11.9    11.9     11.9
# Total Macroscopic Entropy Production Net Flux D...     11.5    11.5     11.5
#
#                                                         R_4      R_5      R_6  \
# Forward likelihoods                                    4.98      199     2.02
# Backward likelihoods                                  0.201  0.00502    0.496
# Delta G                                               -3.98    -13.1    -1.74
# log Q_r                                             0.00752    -5.29   -0.299
# log K_eq                                               1.61       -0    0.403
# Delta G0                                                 -4        0       -1
# logK - logQ                                            1.61     5.29    0.702
# logQ - logK                                           -1.61    -5.29   -0.702
# Forward Log likelihoods                                1.61     5.29    0.702
# Backward Log likelihoods                              -1.61    -5.29   -0.702
# Forward probabilities                               0.00627     0.25  0.00254
# Backward probabilities                             0.000252 6.31e-06 0.000623
# Net probabilities                                   0.00601     0.25  0.00191
# Net likelihoods                                        4.78      199     1.52
# Forward rate                                           4.98        4     2.02
# Backward rate                                             1   0.0201        1
# Thermodynamic driving force                            4.98      199     2.02
# Net flux                                               3.98     3.98     1.02
# Forward Entropy Production                           0.0318    0.347   0.0152
# Backward Entropy Production                         0.00209 7.56e-05   0.0046
# Reaction Entropy Production                          0.0339    0.347   0.0198
# Microscopic Reaction Entropy Production Rate           0.16     1.39   0.0352
# Microscopic Reaction Entropy Production Net Flux      0.135     1.38   0.0201
# Microscopic Reaction Entropy Production Net Flu...    0.118     1.38   0.0108
# Total Entropy Production                               1.17     1.17     1.17
# Total Microscopic Entropy Production Rate              7.39     7.39     7.39
# Macroscopic Reaction Entropy Production Net Flux      0.346     3.54    0.202
# Macroscopic Reaction Entropy Production Net Flu...    0.303     3.54    0.108
# Total Macroscopic Entropy Production Net Flux          11.9     11.9     11.9
# Total Macroscopic Entropy Production Net Flux D...     11.5     11.5     11.5
#
#                                                         R_7      R_8      R_9
# Forward likelihoods                                     4.5      112     2.02
# Backward likelihoods                                  0.222  0.00894    0.496
# Delta G                                               -3.73    -11.7    -1.74
# log Q_r                                              -0.698    -4.72   -0.702
# log K_eq                                              0.807       -0       -0
# Delta G0                                                 -2        0        0
# logK - logQ                                            1.51     4.72    0.702
# logQ - logK                                           -1.51    -4.72   -0.702
# Forward Log likelihoods                                1.51     4.72    0.702
# Backward Log likelihoods                              -1.51    -4.72   -0.702
# Forward probabilities                               0.00566    0.141  0.00254
# Backward probabilities                             0.000279 1.12e-05 0.000623
# Net probabilities                                   0.00539    0.141  0.00191
# Net likelihoods                                        4.28      112     1.52
# Forward rate                                           2.89     10.3     2.02
# Backward rate                                         0.642   0.0922        1
# Thermodynamic driving force                             4.5      112     2.02
# Net flux                                               2.25     10.2     1.02
# Forward Entropy Production                           0.0293    0.276   0.0152
# Backward Entropy Production                         0.00228 0.000128   0.0046
# Reaction Entropy Production                          0.0316    0.276   0.0198
# Microscopic Reaction Entropy Production Rate         0.0862     2.84   0.0352
# Microscopic Reaction Entropy Production Net Flux     0.0711     2.82   0.0201
# Microscopic Reaction Entropy Production Net Flu...   0.0608     2.82   0.0108
# Total Entropy Production                               1.17     1.17     1.17
# Total Microscopic Entropy Production Rate              7.39     7.39     7.39
# Macroscopic Reaction Entropy Production Net Flux      0.323     2.82    0.202
# Macroscopic Reaction Entropy Production Net Flu...    0.276     2.82    0.108
# Total Macroscopic Entropy Production Net Flux          11.9     11.9     11.9
# Total Macroscopic Entropy Production Net Flux D...     11.5     11.5     11.5

# %% [markdown]
# ## mTOW algorithm
#
# $$\begin{array}{lll}
#     \underset{\vec{\bf d}, \log(\vec{\bf c}), \vec{\bf v}}{\mbox{minimize}}   & \left(\theta\cdot\sum_{ i\in known\ rates}\left|v_i - v_i^{known}\right| + \sum_{j\in rxns}\frac{|d_j|}{\sigma_j}\right)\\
#     \mbox{subject to}    & \Delta\vec{G}^{'} = (\Delta \vec{G}^{'\circ} + \vec{d}) + RT\cdot S^T\log(\vec{c}) & \text{Gibbs energy} \\
# & -\frac{\Delta G'}{RT}\geq\beta & \text{Second law of thermodynamics} \\
# & S\cdot \vec{v} = 0  & \text{Mass balance } \\
# & d^L\leq \vec{d}\leq d^U & \text{Deviation bounds} \\
# & v_{biomass} = v_{measured} & \text{Growth rate } \\
# & \log(c^L)\leq \log(\vec{c})\leq \log(c^U) & \text{Concentration bounds }
# \end{array}$$
#
# $$\tilde{M}(c_i) = (\log\frac{c_i}{c_L})^2$$
#
# $$\tilde{E}(c,v_j) =\left[\infty - \frac{\Delta G_j}{RT}\right]$$
#
# $$E(c,vj)=\left[ -\Delta G_jRT<\beta v_j\cdot(\alpha+\Delta G_jRT)2\beta<-\Delta G_jRT<\alpha 0 \alpha <-\Delta G_jRT\right]$$

# %% [markdown]
# ## Combining energy minimization and FBA using the external free energy as a constraint on the $\Delta G$ of each reaction ##
#
# The total amount of energy available in the environment acts as both an energy barrier and energy sink for each internal reaction.  If it didn't then at steady state internal potentials could become local maxima or minima, which would not be consistent with a maximum entropy production solution.
#
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}, \vec{\bf v}}{\mbox{maximize}}   & v_{biomass} - \|\log L_+\|_2 \\
#     \mbox{subject to}    & S\cdot v = 0 \\
#     & \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#     & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right| \\
#     & v_{lower}(L) \leq v \leq v_{upper}(L) \\
# \end{array}$$
#
# Where,
#
# $$\begin{eqnarray}
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \Delta G_{ext} & = & \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} -\mu_{E_{ext}} \\
# v_{lower}(L) & = & \min\left(0,\text{sign}(\log L)\cdot v_{lower} \right) \\
# v_{upper}(L) & = & \max\left(0,\text{sign}(\log L)\cdot v_{upper}\right) \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U

algorithm = 'convex_mentos_external_free_energy_constraint'
problem = {}
#met_bounds = mentos.getMetBounds(fullS, fluxes, c_L, c_U)
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)
v = cvx.Variable( n )
log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods
obj  = cvx.Maximize(v[biomass] - cvx.norm2(log_likelihood))
constraints = [S*v == 0,
              log_likelihood == log_K - log_Q,
              log_c[A_ext] == cvx.log(c_U),             # Creating a concentration gradient between A, E and D,F
              log_c[E_ext] == cvx.log(c_U),
              log_c[D_ext] == cvx.log(c_L),
              log_c[F_ext] == cvx.log(c_L),
              -abs(external_free_energy) <= fullS.T.as_matrix()*mu,
                                            fullS.T.as_matrix()*mu <= abs(external_free_energy),
              v_U*cvx.neg(log_likelihood) <= v,#cvx.neg(log_likelihood*v_U) <= v,
              v <= cvx.pos(log_likelihood)*v_U
              ]
cvx.Problem(obj, constraints).solve(verbose=True)


forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, v )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
                                                             , forward_rate, backward_rate, S, mets, internal_mets, 
                                                             mu0).astype(np.float64)
display(mentos.compare_frames(**metab))
reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')
display(mentos.compare_frames(**reactions))
# Out:
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# <ipython-input-36-ba798681190b> in <module>()
#      24               v <= cvx.pos(log_likelihood)*v_U
#      25               ]
# ---> 26 cvx.Problem(obj, constraints).solve(verbose=True)
#      27
#      28
#
# /Users/zuck016/.pyenv/versions/anaconda2-2.5.0/lib/python2.7/site-packages/cvxpy/problems/problem.pyc in solve(self, *args, **kwargs)
#     207             return func(self, *args, **kwargs)
#     208         else:
# --> 209             return self._solve(*args, **kwargs)
#     210
#     211     @classmethod
#
# /Users/zuck016/.pyenv/versions/anaconda2-2.5.0/lib/python2.7/site-packages/cvxpy/problems/problem.pyc in _solve(self, solver, ignore_dcp, warm_start, verbose, parallel, **kwargs)
#     281                       "Solving a convex relaxation.")
#     282             else:
# --> 283                 raise DCPError("Problem does not follow DCP rules.")
#     284
#     285         if solver == s.LS:
#
# DCPError: Problem does not follow DCP rules.

# %% [markdown]
# ## Using the external free energy as a constraint on the $\Delta G$ of each reaction ##
#
# The total amount of energy available in the environment acts as both an energy barrier and energy sink for each internal reaction.  If it didn't then at steady state internal potentials could become local maxima or minima, which would not be consistent with a maximum entropy production solution.
#
#
#
# $$\begin{array}{ll}
#     \underset{\vec{\bf v}}{\mbox{maximize}}   & v_{biomass} \\
#     \mbox{subject to}  & S\cdot v = 0 \\
#     & v_{lower}(L) \leq v \leq v_{upper}(L) \\
# \end{array}$$
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \|\log L_+\|_2 \\
#     \mbox{subject to}  & \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#     & \log L_{+i} \geq 0 & \text{ if } v_i \geq 0 \\
#     & \log L_{+i} \leq 0 & \text{ if } v_i \leq 0 \\
#     & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
# \end{array}$$
#
#
# Where,
#
# $$\begin{eqnarray}
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \Delta G_{ext} & = & \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} -\mu_{E_{ext}} \\
# v_{lower}(L) & = & \min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1 \\
# v_{upper}(L) & = & \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1 \\
# \end{eqnarray}$$

# %% [markdown]
# ### Likelihoods first then FBA
#
#
#
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \|\log L_+\|_2 \\
#     \mbox{subject to}  & \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#     & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
# \end{array}$$
#
#
# $$\begin{array}{ll}
#     \underset{\vec{\bf v}}{\mbox{maximize}}   & v_{biomass} \\
#     \mbox{subject to}  & S\cdot v = 0 \\
#     & v_i \geq 0 & \text{ if } \log L_{+i}  \geq 0 \\
#     & v_i \leq 0 & \text{ if } \log L_{+i} \leq 0 \\
# \end{array}$$
# Where,
#
# $$\begin{eqnarray}
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \Delta G_{ext} & = & \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} -\mu_{E_{ext}} \\
# v_{lower}(L) & = & \min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1 \\
# v_{upper}(L) & = & \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1 \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext

algorithm = 'convex_mentos_likelihoods_then_fba'
problem = {}
#met_bounds = mentos.getMetBounds(fullS, fluxes, c_L, c_U)
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)

log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods
obj  = cvx.Minimize(cvx.norm2(log_likelihood))
constraints = [log_likelihood == log_K - log_Q,
              log_c[A_ext] == cvx.log(c_U),             # Creating a concentration gradient between A, E and D,F
              log_c[E_ext] == cvx.log(c_U),
              log_c[D_ext] == cvx.log(c_L),
              log_c[F_ext] == cvx.log(c_L),
              -abs(external_free_energy) <= fullS.T.as_matrix()*mu,
              fullS.T.as_matrix()*mu <= abs(external_free_energy)
              ]
cvx.Problem(obj, constraints).solve()


v_L, v_U = mentos.get_rxn_bounds_from_log_likelihood( log_likelihood )

v = cvx.Variable(n)
obj = cvx.Maximize(v[biomass])
constraints = [S*v == 0,
              v_L <= v,
              v <= v_U]
cvx.Problem(obj, constraints).solve()

forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, v )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
                                                             , forward_rate, backward_rate, S, mets, internal_mets, 
                                                             mu0).astype(np.float64)
#display(mentos.compare_frames(**metab))
display(HTML(metab[algorithm].T.to_html()))
reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                   forward_rate, backward_rate, rxns, deltaG0,'R_8')
display(HTML(reactions[algorithm].T.to_html()))
#display(mentos.compare_frames(**reactions))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th>A_ext</th>
#       <th>D_ext</th>
#       <th>E_ext</th>
#       <th>F_ext</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Counts</th>
#       <td>4.22e+03</td>
#       <td>114</td>
#       <td>5.48e+03</td>
#       <td>2.25e+03</td>
#       <td>7.28e+04</td>
#       <td>19</td>
#       <td>6.02e+05</td>
#       <td>6</td>
#       <td>6.02e+05</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Concentrations</th>
#       <td>7.01e-06</td>
#       <td>1.9e-07</td>
#       <td>9.09e-06</td>
#       <td>3.73e-06</td>
#       <td>0.000121</td>
#       <td>3.16e-08</td>
#       <td>0.001</td>
#       <td>1e-08</td>
#       <td>0.001</td>
#       <td>1e-08</td>
#     </tr>
#     <tr>
#       <th>Log Concentrations</th>
#       <td>-11.9</td>
#       <td>-15.5</td>
#       <td>-11.6</td>
#       <td>-12.5</td>
#       <td>-9.02</td>
#       <td>-17.3</td>
#       <td>-6.91</td>
#       <td>-18.4</td>
#       <td>-6.91</td>
#       <td>-18.4</td>
#     </tr>
#     <tr>
#       <th>Standard Chemical potential</th>
#       <td>0</td>
#       <td>-2</td>
#       <td>-2</td>
#       <td>-4</td>
#       <td>-2</td>
#       <td>-10</td>
#       <td>0</td>
#       <td>-4</td>
#       <td>-2</td>
#       <td>-10</td>
#     </tr>
#     <tr>
#       <th>Chemical potential</th>
#       <td>-29.4</td>
#       <td>-40.4</td>
#       <td>-30.8</td>
#       <td>-35</td>
#       <td>-24.4</td>
#       <td>-52.8</td>
#       <td>-17.1</td>
#       <td>-49.7</td>
#       <td>-19.1</td>
#       <td>-55.7</td>
#     </tr>
#     <tr>
#       <th>Normalized Concentrations</th>
#       <td>0.00327</td>
#       <td>8.87e-05</td>
#       <td>0.00425</td>
#       <td>0.00174</td>
#       <td>0.0565</td>
#       <td>1.48e-05</td>
#       <td>0.467</td>
#       <td>4.67e-06</td>
#       <td>0.467</td>
#       <td>4.67e-06</td>
#     </tr>
#     <tr>
#       <th>Absolute activities</th>
#       <td>1.67e-13</td>
#       <td>2.95e-18</td>
#       <td>4.31e-14</td>
#       <td>6.42e-16</td>
#       <td>2.63e-11</td>
#       <td>1.16e-23</td>
#       <td>3.66e-08</td>
#       <td>2.7e-22</td>
#       <td>4.95e-09</td>
#       <td>6.69e-25</td>
#     </tr>
#     <tr>
#       <th>Normalized absolute activities</th>
#       <td>4.02e-06</td>
#       <td>7.09e-11</td>
#       <td>1.04e-06</td>
#       <td>1.54e-08</td>
#       <td>0.000633</td>
#       <td>2.79e-16</td>
#       <td>0.88</td>
#       <td>6.5e-15</td>
#       <td>0.119</td>
#       <td>1.61e-17</td>
#     </tr>
#     <tr>
#       <th>Entropy</th>
#       <td>4.99e-05</td>
#       <td>1.66e-09</td>
#       <td>1.43e-05</td>
#       <td>2.78e-07</td>
#       <td>0.00466</td>
#       <td>1e-14</td>
#       <td>0.112</td>
#       <td>2.12e-13</td>
#       <td>0.253</td>
#       <td>6.23e-16</td>
#     </tr>
#     <tr>
#       <th>Entropy of Concentrations</th>
#       <td>0.0187</td>
#       <td>0.000828</td>
#       <td>0.0232</td>
#       <td>0.0111</td>
#       <td>0.162</td>
#       <td>0.000164</td>
#       <td>0.356</td>
#       <td>5.73e-05</td>
#       <td>0.356</td>
#       <td>5.73e-05</td>
#     </tr>
#     <tr>
#       <th>S*forward_rate</th>
#       <td>-1.06</td>
#       <td>-2.86</td>
#       <td>1.35</td>
#       <td>2.6</td>
#       <td>9.87e-06</td>
#       <td>-7.62e-06</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#     </tr>
#     <tr>
#       <th

#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#     </tr>
#     <tr>
#       <th>Total Microscopic Entropy Production Rate</th>
#       <td>13.8</td>
#       <td>13.8</td>
#       <td>13.8</td>
#       <td>13.8</td>
#       <td>13.8</td>
#       <td>13.8</td>
#       <td>13.8</td>
#       <td>13.8</td>
#       <td>13.8</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux</th>
#       <td>5.86</td>
#       <td>4.65</td>
#       <td>0.394</td>
#       <td>1.02</td>
#       <td>1.02</td>
#       <td>0.529</td>
#       <td>0.758</td>
#       <td>5.41</td>
#       <td>0.529</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>5.86</td>
#       <td>4.64</td>
#       <td>0.17</td>
#       <td>0.962</td>
#       <td>0.962</td>
#       <td>0.396</td>
#       <td>0.675</td>
#       <td>5.41</td>
#       <td>0.396</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux</th>
#       <td>20.2</td>
#       <td>20.2</td>
#       <td>20.2</td>
#       <td>20.2</td>
#       <td>20.2</td>
#       <td>20.2</td>
#       <td>20.2</td>
#       <td>20.2</td>
#       <td>20.2</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux Difference</th>
#       <td>19.5</td>
#       <td>19.5</td>
#       <td>19.5</td>
#       <td>19.5</td>
#       <td>19.5</td>
#       <td>19.5</td>
#       <td>19.5</td>
#       <td>19.5</td>
#       <td>19.5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### FBA first, then likelihoods
#
#
#
# $$\begin{array}{ll}
#     \underset{\vec{\bf v}}{\mbox{maximize}}   & v_{biomass} \\
#     \mbox{subject to}  & S\cdot v = 0 \\
#     & v_{lower}(L) \leq v \leq v_{upper}(L) \\
# \end{array}$$
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \|\log L_+\|_2 \\
#     \mbox{subject to}  & \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#     & \log L_{+i} \geq 0 & \text{ if } v_i \geq 0 \\
#     & \log L_{+i} \leq 0 & \text{ if } v_i \leq 0 \\
#     & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
# \end{array}$$
#
#
# Where,
#
# $$\begin{eqnarray}
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \Delta G_{ext} & = & \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} -\mu_{E_{ext}} \\
# v_{lower}(L) & = & \min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1 \\
# v_{upper}(L) & = & \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1 \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, v_L, v_U, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext

algorithm = 'convex_mentos_external_free_energy_constraint_fba_then_likelihood'
problem = {}


v = cvx.Variable(n)
obj = cvx.Maximize(v[biomass])
constraints = [S*v == 0,
              0 <= v,
              v <= v_U,
              v[0] <= 1.0]
cvx.Problem(obj, constraints).solve()

display(v.value)
#met_bounds = mentos.getMetBounds(fullS, fluxes, c_L, c_U)
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)

log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods
obj  = cvx.Minimize(cvx.norm2(log_likelihood))
constraints = [log_likelihood == log_K - log_Q,
              log_c[A_ext] == cvx.log(c_U),             # Creating a concentration gradient between A, E and D,F
              log_c[E_ext] == cvx.log(c_U),
              log_c[D_ext] == cvx.log(c_L),
              log_c[F_ext] == cvx.log(c_L),
              -abs(external_free_energy) <= fullS.T.as_matrix()*mu,
              fullS.T.as_matrix()*mu <= abs(external_free_energy)
              ] + [log_likelihood[rxn] >= 0 if v[rxn].value >= 0 else log_likelihood[rxn] <= 0
                        for rxn in range(len(rxns))]
cvx.Problem(obj, constraints).solve()


#v_L, v_U = mentos.get_rxn_bounds_from_log_likelihood( log_likelihood )


forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, v )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
                                                             , forward_rate, backward_rate, S, mets, internal_mets, 
                                                             mu0).astype(np.float64)
display(mentos.compare_frames(**metab))
reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')
display(HTML(mentos.compare_frames(**reactions).to_html()))
# Out:
# matrix([[  1.00000000e+00],
#         [  9.99999999e-01],
#         [  5.16308119e-10],
#         [  9.99999999e-01],
#         [  9.99999999e-01],
#         [  1.26899166e-10],
#         [  6.43079068e-10],
#         [  2.00000000e+00],
#         [  1.27034409e-10]])
#                                                                                        A  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy              1.07e-12
#                             macro_maxent_production_rate_scipy                  6.04e-06
#                             micro_maxent_production_net_flux                    5.25e-10
#                             macro_maxent_production_rate_scipy_optimize_w_s...  6.04e-06
#                             convex_mentos_external_free_energy_constraint_f...  1.67e-13
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  8.38e-14
#                             convex_mentos_external_free_energy_constraint       1.67e-13
#                             convex_mentos_likelihoods_first_elmo                1.67e-13
#                             micro_maxent_production_rate_scipy_optimize         5.17e-06
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  1.07e-12
#                             macro_maxent_production_rate_wo_entropy             8.38e-14
# Chemical potential          macro_maxent_production_rate_w_entropy                 -27.6
#                             macro_maxent_production_rate_scipy                       -12
#                             micro_maxent_production_net_flux                       -21.4
#                             macro_maxent_production_rate_scipy_optimize_w_s...       -12
#                             convex_mentos_external_free_energy_constraint_f...     -29.4
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     -30.1
#                             convex_mentos_external_free_energy_constraint          -29.4
#                             convex_mentos_likelihoods_first_elmo                   -29.4
#                             micro_maxent_production_rate_scipy_optimize            -12.2
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...     -27.6
#                             macro_maxent_production_rate_wo_entropy                -30.1
# Concentrations              macro_maxent_production_rate_w_entropy              1.48e-05
#                             macro_maxent_production_rate_scipy                   0.00785
#                             micro_maxent_production_net_flux                    0.000181
#                             macro_maxent_production_rate_scipy_optimize_w_s...   0.00785
#                             convex_mentos_external_free_energy_constraint_f...  7.01e-06
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  5.31e-06
#                             convex_mentos_external_free_energy_constraint       7.01e-06
#                             convex_mentos_likelihoods_first_elmo                7.01e-06
# ...                                                                                  ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...  -0.00424
#                             convex_mentos_external_free_energy_constraint_f...  -0.00519
#                             macro_maxent_production_rate_pyOpt_optimize_w_p... -3.72e+07
#                             convex_mentos_external_free_energy_constraint          -1.06
#                             convex_mentos_likelihoods_first_elmo                   -0.46
#                             micro_maxent_production_rate_scipy_optimize         -0.00435
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...    -0.172
#                             macro_maxent_production_rate_wo_entropy            -3.72e+07
# S*net_flux                  macro_maxent_production_rate_w_entropy              3.37e-08
#                             macro_maxent_production_rate_scipy                  -0.00666
#                             micro_maxent_production_net_flux                       0.648
#                             macro_maxent_production_rate_scipy_optimize_w_s...  -0.00666
#                             convex_mentos_external_free_energy_constraint_f...  2.37e-14
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      1.26
#                             convex_mentos_external_free_energy_constraint      -2.89e-15
#                             convex_mentos_likelihoods_first_elmo                       0
#                             micro_maxent_production_rate_scipy_optimize        -0.000828
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  3.37e-08
#                             macro_maxent_production_rate_wo_entropy                 1.26
# Standard Chemical potential macro_maxent_production_rate_w_entropy                     0
#                             macro_maxent_production_rate_scipy                         0
#                             micro_maxent_production_net_flux                           0
#                             macro_maxent_production_rate_scipy_optimize_w_s...         0
#                             convex_mentos_external_free_energy_constraint_f...         0
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...         0
#                             convex_mentos_external_free_energy_constraint              0
#                             convex_mentos_likelihoods_first_elmo                       0
#                             micro_maxent_production_rate_scipy_optimize                0
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...         0
#                             macro_maxent_production_rate_wo_entropy                    0
#
#                                                                                        B  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy              3.81e-17
#                             macro_maxent_production_rate_scipy                  2.79e-15
#                             micro_maxent_production_net_flux                    7.73e-13
#                             macro_maxent_production_rate_scipy_optimize_w_s...  2.79e-15
#                             convex_mentos_external_free_energy_constraint_f...  2.95e-18
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  4.07e-17
#                             convex_mentos_external_free_energy_constraint       2.95e-18
#                             convex_mentos_likelihoods_first_elmo                2.95e-18
#                             micro_maxent_production_rate_scipy_optimize          1.6e-13
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  3.81e-17
#                             macro_maxent_production_rate_wo_entropy             4.07e-17
# Chemical potential          macro_maxent_production_rate_w_entropy                 -37.8
#                             macro_maxent_production_rate_scipy                     -33.5
#                             micro_maxent_production_net_flux                       -27.9
#                             macro_maxent_production_rate_scipy_optimize_w_s...     -33.5
#                             convex_mentos_external_free_energy_constraint_f...     -40.4
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     -37.7
#                             convex_mentos_external_free_energy_constraint          -40.4
#                             convex_mentos_likelihoods_first_elmo                   -40.4
#                             micro_maxent_production_rate_scipy_optimize            -29.5
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...     -37.8
#                             macro_maxent_production_rate_wo_entropy                -37.7
# Concentrations              macro_maxent_production_rate_w_entropy              5.33e-07
#                             macro_maxent_production_rate_scipy                  3.01e-06
#                             micro_maxent_production_net_flux                    2.91e-05
#                             macro_maxent_production_rate_scipy_optimize_w_s...  3.01e-06
#                             convex_mentos_external_free_energy_constraint_f...   1.9e-07
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  5.48e-07
#                             convex_mentos_external_free_energy_constraint        1.9e-07
#                             convex_mentos_likelihoods_first_elmo                 1.9e-07
# ...                                                                                  ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...       -25
#                             convex_mentos_external_free_energy_constraint_f...    -0.125
#                             macro_maxent_production_rate_pyOpt_optimize_w_p... -1.94e+05
#                             convex_mentos_external_free_energy_constraint          -2.86
#                             convex_mentos_likelihoods_first_elmo                  -0.192
#                             micro_maxent_production_rate_scipy_optimize            -52.5
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  -0.00385
#                             macro_maxent_production_rate_wo_entropy            -1.94e+05
# S*net_flux                  macro_maxent_production_rate_w_entropy              2.15e-05
#                             macro_maxent_production_rate_scipy                  0.000224
#                             micro_maxent_production_net_flux                      -0.992
#                             macro_maxent_production_rate_scipy_optimize_w_s...  0.000224
#                             convex_mentos_external_free_energy_constraint_f...  3.02e-14
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      2.38
#                             convex_mentos_external_free_energy_constraint      -1.78e-15
#                             convex_mentos_likelihoods_first_elmo                       0
#                             micro_maxent_production_rate_scipy_optimize          0.00403
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  2.15e-05
#                             macro_maxent_production_rate_wo_entropy                 2.38
# Standard Chemical potential macro_maxent_production_rate_w_entropy                    -2
#                             macro_maxent_production_rate_scipy                        -2
#                             micro_maxent_production_net_flux                          -2
#                             macro_maxent_production_rate_scipy_optimize_w_s...        -2
#                             convex_mentos_external_free_energy_constraint_f...        -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...        -2
#                             convex_mentos_external_free_energy_constraint             -2
#                             convex_mentos_likelihoods_first_elmo                      -2
#                             micro_maxent_production_rate_scipy_optimize               -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...        -2
#                             macro_maxent_production_rate_wo_entropy                   -2
#
#                                                                                        C  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy              1.58e-14
#                             macro_maxent_production_rate_scipy                  3.91e-08
#                             micro_maxent_production_net_flux                    6.44e-09
#                             macro_maxent_production_rate_scipy_optimize_w_s...  3.91e-08
#                             convex_mentos_external_free_energy_constraint_f...  4.31e-14
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  4.46e-12
#                             convex_mentos_external_free_energy_constraint       4.31e-14
#                             convex_mentos_likelihoods_first_elmo                4.31e-14
#                             micro_maxent_production_rate_scipy_optimize         2.37e-09
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  1.58e-14
#                             macro_maxent_production_rate_wo_entropy             4.46e-12
# Chemical potential          macro_maxent_production_rate_w_entropy                 -31.8
#                             macro_maxent_production_rate_scipy                     -17.1
#                             micro_maxent_production_net_flux                       -18.9
#                             macro_maxent_production_rate_scipy_optimize_w_s...     -17.1
#                             convex_mentos_external_free_energy_constraint_f...     -30.8
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     -26.1
#                             convex_mentos_external_free_energy_constraint          -30.8
#                             convex_mentos_likelihoods_first_elmo                   -30.8
#                             micro_maxent_production_rate_scipy_optimize            -19.9
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...     -31.8
#                             macro_maxent_production_rate_wo_entropy                -26.1
# Concentrations              macro_maxent_production_rate_w_entropy              6.07e-06
#                             macro_maxent_production_rate_scipy                    0.0023
#                             micro_maxent_production_net_flux                     0.00111
#                             macro_maxent_production_rate_scipy_optimize_w_s...    0.0023
#                             convex_mentos_external_free_energy_constraint_f...  9.09e-06
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  5.91e-05
#                             convex_mentos_external_free_energy_constraint       9.09e-06
#                             convex_mentos_likelihoods_first_elmo                9.09e-06
# ...                                                                                  ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...      9.45
#                             convex_mentos_external_free_energy_constraint_f...  6.25e-10
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  3.72e+07
#                             convex_mentos_external_free_energy_constraint           1.35
#                             convex_mentos_likelihoods_first_elmo                   0.424
#                             micro_maxent_production_rate_scipy_optimize             10.2
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...     0.112
#                             macro_maxent_production_rate_wo_entropy             3.72e+07
# S*net_flux                  macro_maxent_production_rate_w_entropy             -1.08e-05
#                             macro_maxent_production_rate_scipy                    0.0215
#                             micro_maxent_production_net_flux                        1.51
#                             macro_maxent_production_rate_scipy_optimize_w_s...    0.0215
#                             convex_mentos_external_free_energy_constraint_f...  1.28e-13
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     -1.37
#                             convex_mentos_external_free_energy_constraint       2.26e-12
#                             convex_mentos_likelihoods_first_elmo                       0
#                             micro_maxent_production_rate_scipy_optimize         6.64e-05
#                             macro_maxent_production_rate_pyOpt_optimize_w_s... -1.08e-05
#                             macro_maxent_production_rate_wo_entropy                -1.37
# Standard Chemical potential macro_maxent_production_rate_w_entropy                    -2
#                             macro_maxent_production_rate_scipy                        -2
#                             micro_maxent_production_net_flux                          -2
#                             macro_maxent_production_rate_scipy_optimize_w_s...        -2
#                             convex_mentos_external_free_energy_constraint_f...        -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...        -2
#                             convex_mentos_external_free_energy_constraint             -2
#                             convex_mentos_likelihoods_first_elmo                      -2
#                             micro_maxent_production_rate_scipy_optimize               -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...        -2
#                             macro_maxent_production_rate_wo_entropy                   -2
#
#                                                                                        D  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy              2.97e-17
#                             macro_maxent_production_rate_scipy                  7.35e-08
#                             micro_maxent_production_net_flux                    7.96e-11
#                             macro_maxent_production_rate_scipy_optimize_w_s...  7.35e-08
#                             convex_mentos_external_free_energy_constraint_f...  6.42e-16
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  2.25e-15
#                             convex_mentos_external_free_energy_constraint       6.42e-16
#                             convex_mentos_likelihoods_first_elmo                6.42e-16
#                             micro_maxent_production_rate_scipy_optimize         3.21e-08
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  2.97e-17
#                             macro_maxent_production_rate_wo_entropy             2.25e-15
# Chemical potential          macro_maxent_production_rate_w_entropy                 -38.1
#                             macro_maxent_production_rate_scipy                     -16.4
#                             micro_maxent_production_net_flux                       -23.3
#                             macro_maxent_production_rate_scipy_optimize_w_s...     -16.4
#                             convex_mentos_external_free_energy_constraint_f...       -35
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     -33.7
#                             convex_mentos_external_free_energy_constraint            -35
#                             convex_mentos_likelihoods_first_elmo                     -35
#                             micro_maxent_production_rate_scipy_optimize            -17.3
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...     -38.1
#                             macro_maxent_production_rate_wo_entropy                -33.7
# Concentrations              macro_maxent_production_rate_w_entropy              1.08e-06
#                             macro_maxent_production_rate_scipy                   0.00665
#                             micro_maxent_production_net_flux                    0.000423
#                             macro_maxent_production_rate_scipy_optimize_w_s...   0.00665
#                             convex_mentos_external_free_energy_constraint_f...  3.73e-06
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...   6.2e-06
#                             convex_mentos_external_free_energy_constraint       3.73e-06
#                             convex_mentos_likelihoods_first_elmo                3.73e-06
# ...                                                                                  ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...      5.61
#                             convex_mentos_external_free_energy_constraint_f...      0.27
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  3.87e+05
#                             convex_mentos_external_free_energy_constraint            2.6
#                             convex_mentos_likelihoods_first_elmo                   0.201
#                             micro_maxent_production_rate_scipy_optimize             20.9
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...    0.0817
#                             macro_maxent_production_rate_wo_entropy             3.87e+05
# S*net_flux                  macro_maxent_production_rate_w_entropy              4.42e-10
#                             macro_maxent_production_rate_scipy                  -0.00213
#                             micro_maxent_production_net_flux                        1.63
#                             macro_maxent_production_rate_scipy_optimize_w_s...  -0.00213
#                             convex_mentos_external_free_energy_constraint_f...  9.77e-15
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     -1.24
#                             convex_mentos_external_free_energy_constraint       4.57e-12
#                             convex_mentos_likelihoods_first_elmo               -2.22e-16
#                             micro_maxent_production_rate_scipy_optimize          -0.0067
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  4.42e-10
#                             macro_maxent_production_rate_wo_entropy                -1.24
# Standard Chemical potential macro_maxent_production_rate_w_entropy                    -4
#                             macro_maxent_production_rate_scipy                        -4
#                             micro_maxent_production_net_flux                          -4
#                             macro_maxent_production_rate_scipy_optimize_w_s...        -4
#                             convex_mentos_external_free_energy_constraint_f...        -4
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...        -4
#                             convex_mentos_external_free_energy_constraint             -4
#                             convex_mentos_likelihoods_first_elmo                      -4
#                             micro_maxent_production_rate_scipy_optimize               -4
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...        -4
#                             macro_maxent_production_rate_wo_entropy                   -4
#
#                                                                                        E  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy              3.39e-13
#                             macro_maxent_production_rate_scipy                  1.49e-06
#                             micro_maxent_production_net_flux                    1.09e-09
#                             macro_maxent_production_rate_scipy_optimize_w_s...  1.49e-06
#                             convex_mentos_external_free_energy_constraint_f...  2.63e-11
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  1.34e-11
#                             convex_mentos_external_free_energy_constraint       2.63e-11
#                             convex_mentos_likelihoods_first_elmo                2.63e-11
#                             micro_maxent_production_rate_scipy_optimize         1.49e-06
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  3.39e-13
#                             macro_maxent_production_rate_wo_entropy             1.34e-11
# Chemical potential          macro_maxent_production_rate_w_entropy                 -28.7
#                             macro_maxent_production_rate_scipy                     -13.4
#                             micro_maxent_production_net_flux                       -20.6
#                             macro_maxent_production_rate_scipy_optimize_w_s...     -13.4
#                             convex_mentos_external_free_energy_constraint_f...     -24.4
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...       -25
#                             convex_mentos_external_free_energy_constraint          -24.4
#                             convex_mentos_likelihoods_first_elmo                   -24.4
#                             micro_maxent_production_rate_scipy_optimize            -13.4
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...     -28.7
#                             macro_maxent_production_rate_wo_entropy                  -25
# Concentrations              macro_maxent_production_rate_w_entropy              2.09e-05
#                             macro_maxent_production_rate_scipy                      0.01
#                             micro_maxent_production_net_flux                    0.000542
#                             macro_maxent_production_rate_scipy_optimize_w_s...      0.01
#                             convex_mentos_external_free_energy_constraint_f...  0.000121
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  9.21e-05
#                             convex_mentos_external_free_energy_constraint       0.000121
#                             convex_mentos_likelihoods_first_elmo                0.000121
# ...                                                                                  ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...     -1.92
#                             convex_mentos_external_free_energy_constraint_f...  1.72e-07
#                             macro_maxent_production_rate_pyOpt_optimize_w_p... -1.94e+05
#                             convex_mentos_external_free_energy_constraint       9.87e-06
#                             convex_mentos_likelihoods_first_elmo                4.53e-07
#                             micro_maxent_production_rate_scipy_optimize            -3.51
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  5.33e-10
#                             macro_maxent_production_rate_wo_entropy            -1.94e+05
# S*net_flux                  macro_maxent_production_rate_w_entropy             -8.15e-11
#                             macro_maxent_production_rate_scipy                  -0.00572
#                             micro_maxent_production_net_flux                      0.0267
#                             macro_maxent_production_rate_scipy_optimize_w_s...  -0.00572
#                             convex_mentos_external_free_energy_constraint_f... -2.22e-15
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     0.657
#                             convex_mentos_external_free_energy_constraint      -8.75e-11
#                             convex_mentos_likelihoods_first_elmo                       0
#                             micro_maxent_production_rate_scipy_optimize          0.00403
#                             macro_maxent_production_rate_pyOpt_optimize_w_s... -8.15e-11
#                             macro_maxent_production_rate_wo_entropy                0.657
# Standard Chemical potential macro_maxent_production_rate_w_entropy                    -2
#                             macro_maxent_production_rate_scipy                        -2
#                             micro_maxent_production_net_flux                          -2
#                             macro_maxent_production_rate_scipy_optimize_w_s...        -2
#                             convex_mentos_external_free_energy_constraint_f...        -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...        -2
#                             convex_mentos_external_free_energy_constraint             -2
#                             convex_mentos_likelihoods_first_elmo                      -2
#                             micro_maxent_production_rate_scipy_optimize               -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...        -2
#                             macro_maxent_production_rate_wo_entropy                   -2
#
#                                                                                        F  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy              2.47e-22
#                             macro_maxent_production_rate_scipy                     5e-10
#                             micro_maxent_production_net_flux                    6.83e-25
#                             macro_maxent_production_rate_scipy_optimize_w_s...     5e-10
#                             convex_mentos_external_free_energy_constraint_f...  1.16e-23
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  1.58e-22
#                             convex_mentos_external_free_energy_constraint       1.16e-23
#                             convex_mentos_likelihoods_first_elmo                1.16e-23
#                             micro_maxent_production_rate_scipy_optimize            5e-10
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  2.47e-22
#                             macro_maxent_production_rate_wo_entropy             1.58e-22
# Chemical potential          macro_maxent_production_rate_w_entropy                 -49.8
#                             macro_maxent_production_rate_scipy                     -21.4
#                             micro_maxent_production_net_flux                       -55.6
#                             macro_maxent_production_rate_scipy_optimize_w_s...     -21.4
#                             convex_mentos_external_free_energy_constraint_f...     -52.8
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...     -50.2
#                             convex_mentos_external_free_energy_constraint          -52.8
#                             convex_mentos_likelihoods_first_elmo                   -52.8
#                             micro_maxent_production_rate_scipy_optimize            -21.4
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...     -49.8
#                             macro_maxent_production_rate_wo_entropy                -50.2
# Concentrations              macro_maxent_production_rate_w_entropy              1.09e-07
#                             macro_maxent_production_rate_scipy                      0.01
#                             micro_maxent_production_net_flux                    1.01e-08
#                             macro_maxent_production_rate_scipy_optimize_w_s...      0.01
#                             convex_mentos_external_free_energy_constraint_f...  3.16e-08
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  9.06e-08
#                             convex_mentos_external_free_energy_constraint       3.16e-08
#                             convex_mentos_likelihoods_first_elmo                3.16e-08
# ...                                                                                  ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...     -25.4
#                             convex_mentos_external_free_energy_constraint_f... -1.98e-13
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      1.26
#                             convex_mentos_external_free_energy_constraint      -7.62e-06
#                             convex_mentos_likelihoods_first_elmo               -5.88e-07
#                             micro_maxent_production_rate_scipy_optimize              -48
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  1.78e-11
#                             macro_maxent_production_rate_wo_entropy                 1.26
# S*net_flux                  macro_maxent_production_rate_w_entropy             -1.79e-10
#                             macro_maxent_production_rate_scipy                 -0.000474
#                             micro_maxent_production_net_flux                       0.207
#                             macro_maxent_production_rate_scipy_optimize_w_s... -0.000474
#                             convex_mentos_external_free_energy_constraint_f... -1.35e-13
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      1.85
#                             convex_mentos_external_free_energy_constraint       4.81e-10
#                             convex_mentos_likelihoods_first_elmo               -2.78e-17
#                             micro_maxent_production_rate_scipy_optimize        -2.49e-14
#                             macro_maxent_production_rate_pyOpt_optimize_w_s... -1.79e-10
#                             macro_maxent_production_rate_wo_entropy                 1.85
# Standard Chemical potential macro_maxent_production_rate_w_entropy                   -10
#                             macro_maxent_production_rate_scipy                       -10
#                             micro_maxent_production_net_flux                         -10
#                             macro_maxent_production_rate_scipy_optimize_w_s...       -10
#                             convex_mentos_external_free_energy_constraint_f...       -10
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...       -10
#                             convex_mentos_external_free_energy_constraint            -10
#                             convex_mentos_likelihoods_first_elmo                     -10
#                             micro_maxent_production_rate_scipy_optimize              -10
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...       -10
#                             macro_maxent_production_rate_wo_entropy                  -10
#
#                                                                                   A_ext  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy             3.66e-08
#                             macro_maxent_production_rate_scipy                    0.107
#                             micro_maxent_production_net_flux                   3.59e-08
#                             macro_maxent_production_rate_scipy_optimize_w_s...    0.107
#                             convex_mentos_external_free_energy_constraint_f... 3.66e-08
#                             macro_maxent_production_rate_pyOpt_optimize_w_p... 4.66e-09
#                             convex_mentos_external_free_energy_constraint      3.66e-08
#                             convex_mentos_likelihoods_first_elmo               3.66e-08
#                             micro_maxent_production_rate_scipy_optimize           0.111
#                             macro_maxent_production_rate_pyOpt_optimize_w_s... 3.66e-08
#                             macro_maxent_production_rate_wo_entropy            4.66e-09
# Chemical potential          macro_maxent_production_rate_w_entropy                -17.1
#                             macro_maxent_production_rate_scipy                    -2.23
#                             micro_maxent_production_net_flux                      -17.1
#                             macro_maxent_production_rate_scipy_optimize_w_s...    -2.23
#                             convex_mentos_external_free_energy_constraint_f...    -17.1
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...    -19.2
#                             convex_mentos_external_free_energy_constraint         -17.1
#                             convex_mentos_likelihoods_first_elmo                  -17.1
#                             micro_maxent_production_rate_scipy_optimize            -2.2
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...    -17.1
#                             macro_maxent_production_rate_wo_entropy               -19.2
# Concentrations              macro_maxent_production_rate_w_entropy                0.001
#                             macro_maxent_production_rate_scipy                    0.407
#                             micro_maxent_production_net_flux                   0.000993
#                             macro_maxent_production_rate_scipy_optimize_w_s...    0.407
#                             convex_mentos_external_free_energy_constraint_f...    0.001
#                             macro_maxent_production_rate_pyOpt_optimize_w_p... 0.000436
#                             convex_mentos_external_free_energy_constraint         0.001
#                             convex_mentos_likelihoods_first_elmo                  0.001
# ...                                                                                 ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...      nan
#                             convex_mentos_external_free_energy_constraint_f...      nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_likelihoods_first_elmo                    nan
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...      nan
#                             macro_maxent_production_rate_wo_entropy                 nan
# S*net_flux                  macro_maxent_production_rate_w_entropy                  nan
#                             macro_maxent_production_rate_scipy                      nan
#                             micro_maxent_production_net_flux                        nan
#                             macro_maxent_production_rate_scipy_optimize_w_s...      nan
#                             convex_mentos_external_free_energy_constraint_f...      nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_likelihoods_first_elmo                    nan
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...      nan
#                             macro_maxent_production_rate_wo_entropy                 nan
# Standard Chemical potential macro_maxent_production_rate_w_entropy                    0
#                             macro_maxent_production_rate_scipy                        0
#                             micro_maxent_production_net_flux                          0
#                             macro_maxent_production_rate_scipy_optimize_w_s...        0
#                             convex_mentos_external_free_energy_constraint_f...        0
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...        0
#                             convex_mentos_external_free_energy_constraint             0
#                             convex_mentos_likelihoods_first_elmo                      0
#                             micro_maxent_production_rate_scipy_optimize               0
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...        0
#                             macro_maxent_production_rate_wo_entropy                   0
#
#                                                                                   D_ext  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy              2.7e-22
#                             macro_maxent_production_rate_scipy                  0.00154
#                             micro_maxent_production_net_flux                   2.69e-22
#                             macro_maxent_production_rate_scipy_optimize_w_s...  0.00154
#                             convex_mentos_external_free_energy_constraint_f...  2.7e-22
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...  2.7e-22
#                             convex_mentos_external_free_energy_constraint       2.7e-22
#                             convex_mentos_likelihoods_first_elmo                2.7e-22
#                             micro_maxent_production_rate_scipy_optimize         0.00205
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...  2.7e-22
#                             macro_maxent_production_rate_wo_entropy             2.7e-22
# Chemical potential          macro_maxent_production_rate_w_entropy                -49.7
#                             macro_maxent_production_rate_scipy                    -6.48
#                             micro_maxent_production_net_flux                      -49.7
#                             macro_maxent_production_rate_scipy_optimize_w_s...    -6.48
#                             convex_mentos_external_free_energy_constraint_f...    -49.7
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...    -49.7
#                             convex_mentos_external_free_energy_constraint         -49.7
#                             convex_mentos_likelihoods_first_elmo                  -49.7
#                             micro_maxent_production_rate_scipy_optimize           -6.19
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...    -49.7
#                             macro_maxent_production_rate_wo_entropy               -49.7
# Concentrations              macro_maxent_production_rate_w_entropy                1e-08
#                             macro_maxent_production_rate_scipy                    0.368
#                             micro_maxent_production_net_flux                   9.99e-09
#                             macro_maxent_production_rate_scipy_optimize_w_s...    0.368
#                             convex_mentos_external_free_energy_constraint_f...    1e-08
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...    1e-08
#                             convex_mentos_external_free_energy_constraint         1e-08
#                             convex_mentos_likelihoods_first_elmo                  1e-08
# ...                                                                                 ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...      nan
#                             convex_mentos_external_free_energy_constraint_f...      nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_likelihoods_first_elmo                    nan
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...      nan
#                             macro_maxent_production_rate_wo_entropy                 nan
# S*net_flux                  macro_maxent_production_rate_w_entropy                  nan
#                             macro_maxent_production_rate_scipy                      nan
#                             micro_maxent_production_net_flux                        nan
#                             macro_maxent_production_rate_scipy_optimize_w_s...      nan
#                             convex_mentos_external_free_energy_constraint_f...      nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_likelihoods_first_elmo                    nan
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...      nan
#                             macro_maxent_production_rate_wo_entropy                 nan
# Standard Chemical potential macro_maxent_production_rate_w_entropy                   -4
#                             macro_maxent_production_rate_scipy                       -4
#                             micro_maxent_production_net_flux                         -4
#                             macro_maxent_production_rate_scipy_optimize_w_s...       -4
#                             convex_mentos_external_free_energy_constraint_f...       -4
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...       -4
#                             convex_mentos_external_free_energy_constraint            -4
#                             convex_mentos_likelihoods_first_elmo                     -4
#                             micro_maxent_production_rate_scipy_optimize              -4
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...       -4
#                             macro_maxent_production_rate_wo_entropy                  -4
#
#                                                                                   E_ext  \
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy             4.95e-09
#                             macro_maxent_production_rate_scipy                   0.0116
#                             micro_maxent_production_net_flux                   4.94e-09
#                             macro_maxent_production_rate_scipy_optimize_w_s...   0.0116
#                             convex_mentos_external_free_energy_constraint_f... 4.95e-09
#                             macro_maxent_production_rate_pyOpt_optimize_w_p... 4.83e-09
#                             convex_mentos_external_free_energy_constraint      4.95e-09
#                             convex_mentos_likelihoods_first_elmo               4.95e-09
#                             micro_maxent_production_rate_scipy_optimize          0.0114
#                             macro_maxent_production_rate_pyOpt_optimize_w_s... 4.95e-09
#                             macro_maxent_production_rate_wo_entropy            4.83e-09
# Chemical potential          macro_maxent_production_rate_w_entropy                -19.1
#                             macro_maxent_production_rate_scipy                    -4.45
#                             micro_maxent_production_net_flux                      -19.1
# ...
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...      nan
#                             macro_maxent_production_rate_wo_entropy                 nan
# S*net_flux                  macro_maxent_production_rate_w_entropy                  nan
#                             macro_maxent_production_rate_scipy                      nan
#                             micro_maxent_production_net_flux                        nan
#                             macro_maxent_production_rate_scipy_optimize_w_s...      nan
#                             convex_mentos_external_free_energy_constraint_f...      nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_likelihoods_first_elmo                    nan
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...      nan
#                             macro_maxent_production_rate_wo_entropy                 nan
# Standard Chemical potential macro_maxent_production_rate_w_entropy                   -2
#                             macro_maxent_production_rate_scipy                       -2
#                             micro_maxent_production_net_flux                         -2
#                             macro_maxent_production_rate_scipy_optimize_w_s...       -2
#                             convex_mentos_external_free_energy_constraint_f...       -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...       -2
#                             convex_mentos_external_free_energy_constraint            -2
#                             convex_mentos_likelihoods_first_elmo                     -2
#                             micro_maxent_production_rate_scipy_optimize              -2
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...       -2
#                             macro_maxent_production_rate_wo_entropy                  -2
#
#                                                                                   F_ext
# major                       minor
# Absolute activities         macro_maxent_production_rate_w_entropy             6.69e-25
#                             macro_maxent_production_rate_scipy                 3.81e-06
#                             micro_maxent_production_net_flux                   7.11e-25
#                             macro_maxent_production_rate_scipy_optimize_w_s... 3.81e-06
#                             convex_mentos_external_free_energy_constraint_f... 6.69e-25
#                             macro_maxent_production_rate_pyOpt_optimize_w_p... 6.74e-25
#                             convex_mentos_external_free_energy_constraint      6.69e-25
#                             convex_mentos_likelihoods_first_elmo               6.69e-25
#                             micro_maxent_production_rate_scipy_optimize        3.81e-06
#                             macro_maxent_production_rate_pyOpt_optimize_w_s... 6.69e-25
#                             macro_maxent_production_rate_wo_entropy            6.74e-25
# Chemical potential          macro_maxent_production_rate_w_entropy                -55.7
#                             macro_maxent_production_rate_scipy                    -12.5
#                             micro_maxent_production_net_flux                      -55.6
#                             macro_maxent_production_rate_scipy_optimize_w_s...    -12.5
#                             convex_mentos_external_free_energy_constraint_f...    -55.7
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...    -55.7
#                             convex_mentos_external_free_energy_constraint         -55.7
#                             convex_mentos_likelihoods_first_elmo                  -55.7
#                             micro_maxent_production_rate_scipy_optimize           -12.5
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...    -55.7
#                             macro_maxent_production_rate_wo_entropy               -55.7
# Concentrations              macro_maxent_production_rate_w_entropy                1e-08
#                             macro_maxent_production_rate_scipy                    0.368
#                             micro_maxent_production_net_flux                   1.02e-08
#                             macro_maxent_production_rate_scipy_optimize_w_s...    0.368
#                             convex_mentos_external_free_energy_constraint_f...    1e-08
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...    1e-08
#                             convex_mentos_external_free_energy_constraint         1e-08
#                             convex_mentos_likelihoods_first_elmo                  1e-08
# ...                                                                                 ...
# S*forward_rate              macro_maxent_production_rate_scipy_optimize_w_s...      nan
#                             convex_mentos_external_free_energy_constraint_f...      nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_likelihoods_first_elmo                    nan
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...      nan
#                             macro_maxent_production_rate_wo_entropy                 nan
# S*net_flux                  macro_maxent_production_rate_w_entropy                  nan
#                             macro_maxent_production_rate_scipy                      nan
#                             micro_maxent_production_net_flux                        nan
#                             macro_maxent_production_rate_scipy_optimize_w_s...      nan
#                             convex_mentos_external_free_energy_constraint_f...      nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_p...      nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_likelihoods_first_elmo                    nan
#                             micro_maxent_production_rate_scipy_optimize             nan
#                             macro_maxent_production_rate_pyOpt_optimize_w_s...
# D     5.43e-07                     0.0142
# E      0.00285                       0.14
# F     3.09e-12                   0.000111
# A_ext    0.112                      0.355
# D_ext 2.12e-13                   5.78e-05
# E_ext    0.253                      0.355
# F_ext 5.59e-13                   5.78e-05

# %%
display(fullS.T.dot(metab[algorithm]['Entropy']).to_frame('$S^T\cdot entropy$'))
display(metab[algorithm]['Entropy'].to_frame('Entropy'))
# Out:
#      $S^T\cdot entropy$
# R_1              -0.112
# R_2           -0.000119
# R_3             -0.0001
# R_4            -0.00285
# R_5              -0.251
# R_6            1.86e-05
# R_7           -1.81e-05
# R_8           -5.43e-07
# R_9           -2.53e-12
#        Entropy
# A     0.000119
# B      1.9e-08
# C     1.86e-05
# D     5.43e-07
# E      0.00285
# F     3.09e-12
# A_ext    0.112
# D_ext 2.12e-13
# E_ext    0.253
# F_ext 5.59e-13

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')
reactions[algorithm]['Delta G'].to_csv('{}_DeltaG.csv'.format(algorithm),header=True)
metab[algorithm]['Chemical potential'].to_csv(
    '{}_Chemical_potential.csv'.format(algorithm), header=True)
reaction_data = (reactions[algorithm]['Net flux']).to_dict()
metabolite_data = metab[algorithm]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="vtbwoplwpr"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"vtbwoplwpr"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": 21.090491341990447, "R_9": 1.0386067867144322, "R_1": 12.730617058698233, "R_2": 11.475694716113415, "R_3": 1.2549223425848144, "R_4": 9.398481094315663, "R_5": 9.398481093895198, "R_6": 1.0386068108988775, "R_7": 2.293529153442197}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -24.475927879625846, "C": -26.491605666213758, "B": -33.81215527022214, "E": -20.92889462602239, "D": -30.27296118807792, "F": -42.898382807572624, "F_ext": -44.66406054262949, "A_ext": -13.124022703486059, "D_ext": -45.66406054262949, "E_ext": -15.124022703486059}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210

# %%
# %matplotlib inline
from d3flux import flux_map
abc = cobra.io.load_json_model( model_name )
abc.optimize()
flux_map( abc, display_name_format= lambda x: str(x.id), figsize=(500,500))
# Out:
# <div id="d3flux003">
#   <!-- <style scoped> -->
#   <!--  -->
#   <!--  -->
#   <!-- </style> -->
#
# </div>
# <div id="d3flux003_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
#   <!-- <button type="button" class="btn btn-info" href="javascript:(function () { var e = document.createElement('script'); if (window.location.protocol === 'https:') { e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js'); } else { e.setAttribute('src', 'http://nytimes.github.com/svg-crowbar/svg-crowbar.js'); } e.setAttribute('class', 'svg-crowbar'); document.body.appendChild(e); })();">Download SVG</button> -->
# </div>
# <script type="text/Javascript">
# var d3flux003model = {"reactions": [{"id": "R_1", "name": "", "metabolites": {"A": 1, "A_ext": -1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_2", "name": "", "metabolites": {"A": -1, "B": 1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_3", "name": "", "metabolites": {"A": -1, "C": 1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_4", "name": "", "metabolites": {"B": -1, "D": 2, "E": -1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_5", "name": "", "metabolites": {"E": 1, "E_ext": -1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_6", "name": "", "metabolites": {"B": -2, "C": 1, "F": 1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_7", "name": "", "metabolites": {"C": -1, "D": 1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_8", "name": "", "metabolites": {"D": -1, "D_ext": 1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}, {"id": "R_9", "name": "", "metabolites": {"F": -1, "F_ext": 1}, "lower_bound": 0.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"flux": 0.0, "reversibility": false}}}], "metabolites": [{"id": "A", "name": "", "compartment": "c", "notes": {"map_info": {"flux": 0.0, "display_name": "A"}}}, {"id": "A_ext", "name": "", "compartment": "ext", "notes": {"map_info": {"flux": 0.0, "display_name": "A_ext"}}}, {"id": "B", "name": "", "compartment": "c", "notes": {"map_info": {"flux": 0.0, "display_name": "B"}}}, {"id": "C", "name": "", "compartment": "c", "notes": {"map_info": {"flux": 0.0, "display_name": "C"}}}, {"id": "D", "name": "", "compartment": "c", "notes": {"map_info": {"flux": 0.0, "display_name": "D"}}}, {"id": "D_ext", "name": "", "compartment": "ext", "notes": {"map_info": {"flux": 0.0, "display_name": "D_ext"}}}, {"id": "E", "name": "", "compartment": "c", "notes": {"map_info": {"flux": 0.0, "display_name": "E"}}}, {"id": "E_ext", "name": "", "compartment": "ext", "notes": {"map_info": {"flux": 0.0, "display_name": "E_ext"}}}, {"id": "F", "name": "", "compartment": "c", "notes": {"map_info": {"flux": 0.0, "display_name": "F"}}}, {"id": "F_ext", "name": "", "compartment": "ext", "notes": {"map_info": {"flux": 0.0, "display_name": "F_ext"}}}], "genes": [], "id": "ABC_model", "compartments": {}, "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     d3: "https://d3js.org/d3.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#     d3tip: "https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.6.7/d3-tip",
#   }
# });
#
# require(["d3", "math", "FileSaver", "d3tip"], function (d3, math, FileSaver, d3tip) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 500,
#     height = 500;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#               "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = d3.layout.force()
#       .linkDistance(30)
#       .charge(-100)
#       .chargeDistance(400)
#       .gravity(.015)
#       .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux003").append("svg")
#         .attr("viewBox", "0 0 500 500");
#     } else {
#       var svg = d3.select("#d3flux003").select("svg");
#     }
#
#     // Append the CSS styles
#     svg.append("style").text(".node.rxn{fill:#ffa319}.node.rxn.hidden{fill:none;stroke:none;stroke-width:0}.link{fill:none;stroke-linecap:round}text.nodelabel{fill:#555;font-family:Arial;font-size:12;pointer-events:none}text.cofactor{fill:#789}marker.inactive,.node.inactive,text.inactive{fill-opacity:1.0}.link.inactive{stroke-opacity:1.0}");
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux003_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux003_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       if (window.location.protocol === 'https:') {
#         e.setAttribute('src', 'https://rawgit.com/NYTimes/svg-crowbar/gh-pages/svg-crowbar.js');
#       } else {
#         e.setAttribute('src', 'https://nytimes.github.com/svg-crowbar/svg-crowbar.js');
#       }
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the r

# %%
import itertools
abc = cobra.io.load_json_model( model_name )
abc.remove_metabolites([met for met in abc.metabolites if '_ext' in met.id])
        
for f in itertools.chain([abc], abc.metabolites, abc.reactions):
    if 'map_info' not in f.notes:
        f.notes['map_info'] = {}
abc.notes
# Out:
# {'map_info': {}}

# %%
abc.reactions.R_1
# Out:
# <Reaction R_1 at 0x123139c10>

# %%
import sys
import cobra.core

sys.path.append('/Users/zuck016/Projects/src')

from myefm import calculate_elementary_modes, calculate_minimum_cut_sets

abc_efms = calculate_elementary_modes(abc)
unbiased_flux = abc_efms.sum(axis=0)/3.0
unbiased_flux.to_frame('Unbiased flux')
# Out:
# 2017-09-12  11:41:59.711  main                     INFO     | =====================================================
# 2017-09-12  11:41:59.712  main                     INFO     | efmtool version 4.7.1, 2009-12-04 18:30:05
# 2017-09-12  11:41:59.713  main                     INFO     | Copyright (c) 2009, Marco Terzer, Zurich, Switzerland
# 2017-09-12  11:41:59.713  main                     INFO     | This is free software, !!! NO WARRANTY !!!
# 2017-09-12  11:41:59.713  main                     INFO     | See LICENCE.txt for redistribution conditions
# 2017-09-12  11:41:59.713  main                     INFO     | =====================================================
# 2017-09-12  11:41:59.822  main    efm.impl         INFO     | Elemetary flux mode computation
# 2017-09-12  11:41:59.822  main    efm.impl         INFO     | Implementation:
# 2017-09-12  11:41:59.822  main    efm.impl         INFO     | ..algorithm name   : SequentialDoubleDescriptionImpl
# 2017-09-12  11:41:59.822  main    efm.impl         INFO     | ..model type       : NullspaceEfmModel
# 2017-09-12  11:41:59.822  main    efm.impl         INFO     | ..memory type      : InCoreMemory
# 2017-09-12  11:41:59.822  main    efm.impl         INFO     | ..output type      : RandomAccessFile
# 2017-09-12  11:41:59.822  main    efm.impl         INFO     | System:
# 2017-09-12  11:41:59.832  main    efm.impl         INFO     | ..hostname         : we30079b
# 2017-09-12  11:41:59.833  main    efm.impl         INFO     | ..operating system : x86_64/Mac OS X/10.12.6
# 2017-09-12  11:41:59.833  main    efm.impl         INFO     | ..processors       : 8
# 2017-09-12  11:41:59.833  main    efm.impl         INFO     | ..vm               : Oracle Corporation/Java HotSpot(TM) 64-Bit Server VM/25.144-b01
# 2017-09-12  11:41:59.834  main    efm.impl         INFO     | ..vm-spec          : Oracle Corporation/Java Virtual Machine Specification/1.8
# 2017-09-12  11:41:59.834  main    efm.impl         INFO     | ..vm arguments     : []
# 2017-09-12  11:41:59.835  main    efm.impl         INFO     | ..memory, commited : 257M
# 2017-09-12  11:41:59.835  main    efm.impl         INFO     | ..memory, used     : 16M
# 2017-09-12  11:41:59.836  main    efm.impl         INFO     | Config:
# 2017-09-12  11:41:59.836  main    efm.impl         INFO     | ..generator        : Efm
# 2017-09-12  11:41:59.836  main    efm.impl         INFO     | ..adj method       : pattern-tree-minzero
# 2017-09-12  11:41:59.836  main    efm.impl         INFO     | ..row ordering     : MostZerosOrAbsLexMin
# 2017-09-12  11:41:59.837  main    efm.impl         INFO     | ..arithmetic       : double (prec: -1 / zero: 1.0E-10)
# 2017-09-12  11:41:59.838  main    efm.impl         INFO     | ..compression      : on
# 2017-09-12  11:41:59.838  main    efm.impl         INFO     | ..compr. methods   : [CoupledZero, CoupledContradicting, CoupledCombine, UniqueFlows, DeadEnd, Recursive]
# 2017-09-12  11:41:59.838  main    efm.impl         INFO     | ..normalize        : max
# 2017-09-12  11:41:59.838  main    efm.impl         INFO     | ..max threads      : 8
# 2017-09-12  11:41:59.838  main    efm.impl         INFO     | ..self test        : off
# 2017-09-12  11:41:59.838  main    efm.impl         INFO     | ..progress type    : None
# 2017-09-12  11:41:59.838  main    efm.impl         INFO     | ..progress part.   : 100
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..suppress         : []
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..enforce          : []
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..nosplit          : []
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..temp dir         : /local/tmp/???
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..flag             : (none)
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | Distributed Config:
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..node count       : 2
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..nodes            : [localhost, localhost]
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..vmargs           : [-Xmx800M, -Xmx500M]
# 2017-09-12  11:41:59.839  main    efm.impl         INFO     | ..command          : /usr/bin/java [vmargs] -cp [classpath] [class] [args]
# 2017-09-12  11:41:59.840  main    efm.impl         INFO     | ..partition        : 256
# 2017-09-12  11:41:59.840  main    efm.impl         INFO     | ..cand. threshold  : 100000
# 2017-09-12  11:41:59.842  main    efm.impl         INFO     | original network: 6 metabolites, 9 reactions (0 reversible)
# 2017-09-12  11:41:59.873  main    efm.impl         INFO     | compressed network: 0 metabolites, 3 reactions (0 reversible)
# 2017-09-12  11:41:59.912  main    efm.impl         INFO     | stoich expanded has dimensions 0x0
# 2017-09-12  11:41:59.912  main    efm.impl         INFO     | kernel matrix has dimensions 0x0
# 2017-09-12  11:41:59.912  main    efm.impl         INFO     | TIME preprocessing: 93ms
# 2017-09-12  11:41:59.916  main    efm.impl         INFO     | iteration 0/0: 0 modes, dt=0ms.
# 2017-09-12  11:41:59.917  main    efm.impl         INFO     | TIME iterate: 3ms
# 2017-09-12  11:41:59.917  main    efm.impl         INFO     | efm count before postprocessing: 0
# 2017-09-12  11:41:59.917  main    efm.impl         INFO     | efm count after filtering/consolidation: 3
# 2017-09-12  11:41:59.917  main    efm.impl         INFO     | uncompressing modes (can take a while)
# 2017-09-12  11:41:59.927  main    efm.impl         INFO     | TIME postprocessing: 10ms
# 2017-09-12  11:41:59.927  main    efm.impl         INFO     | overall computation time: 108ms
#      Unbiased flux
# R_1          0.833
# R_2            0.5
# R_3          0.333
# R_4          0.167
# R_5          0.167
# R_6          0.167
# R_7            0.5
# R_8          0.833
# R_9          0.167

# %% [markdown]
# ## Solving for convex mentos without FBA ##
#
# We split the network into elementary modes, and divide the input flux equally amongst all the elementary modes.
#
#
# $$ \vec{\bf v} = \frac{\sum^n_i \vec{\bf e}_i}{n} $$
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \|\log L_+\|_2 \\
#     \mbox{subject to}  & \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#     & \log L_{+i} \geq 0 & \text{ if } v_i \geq 0 \\
#     & \log L_{+i} \leq 0 & \text{ if } v_i \leq 0 \\
#     & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
# \end{array}$$
#
#
# Where,
#
# $$\begin{eqnarray}
# \vec{\bf e}_i  & & \text{ is the $i$th elementary mode} \\
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \Delta G_{ext} & = & \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} -\mu_{E_{ext}} \\
# v_{lower}(L) & = & \min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1 \\
# v_{upper}(L) & = & \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1 \\
# \end{eqnarray}$$

# %%
import sys, os
sys.path.append('/Users/zuck016/Projects/src')
from myefm import calculate_elementary_modes, calculate_minimum_cut_sets

abc_dir = 'Mentos/ABC'
model_name = os.path.join(os.environ['HOME'], 'Projects/CRT',abc_dir,'ABC_model.json')
abc = cobra.io.load_json_model( model_name )
abc.remove_metabolites([met for met in abc.metabolites if '_ext' in met.id])
abc_efms = calculate_elementary_modes(abc, verbose=False)
abc_efms = abc_efms.T.divide(abc_efms['R_1']).T
display(abc_efms)
unbiased_flux = abc_efms.sum(axis=0)/abc_efms['R_1'].sum()
unbiased_flux.to_frame('Unbiased flux')
# Out:
#      R_1  R_2  R_3  R_4  R_5  R_6  R_7  R_8  R_9
# EM1    1    1    0    0    0  0.5  0.5  0.5  0.5
# EM2    1    1    0    1    1    0    0    2    0
# EM3    1    0    1    0    0    0    1    1    0
#      Unbiased flux
# R_1              1
# R_2          0.667
# R_3          0.333
# R_4          0.333
# R_5          0.333
# R_6          0.167
# R_7            0.5
# R_8           1.17
# R_9          0.167

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext
import sys
import cobra.core

sys.path.append('/Users/zuck016/Projects/src')

from myefm import calculate_elementary_modes, calculate_minimum_cut_sets
algorithm = 'convex_mentos_even_elmo'
problem = {}
#met_bounds = mentos.getMetBounds(fullS, fluxes, c_L, c_U)
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)

log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values
positive_flux_constraint = [log_likelihood[rxn]  >= 0 
                                for rxn in range(len(rxns)) 
                                    if unbiased_flux[rxn] >= 0]

negative_flux_constraint = [log_likelihood[rxn] <= 0 for rxn in range(len(rxns)) if unbiased_flux[rxn] <= 0]

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods
obj  = cvx.Minimize(cvx.norm2(log_likelihood))
constraints = [log_likelihood == log_K - log_Q,
              log_c[A_ext] == cvx.log(c_U),             # Creating a concentration gradient between A, E and D,F
              log_c[E_ext] == cvx.log(c_U),
              log_c[D_ext] == cvx.log(c_L),
              log_c[F_ext] == cvx.log(c_L),
             
              -abs(external_free_energy) <= fullS.T.as_matrix()*mu,
              fullS.T.as_matrix()*mu <= abs(external_free_energy)
              ] + positive_flux_constraint + negative_flux_constraint
cvx.Problem(obj, constraints).solve()


#v_L, v_U = mentos.get_rxn_bounds_from_log_likelihood( log_likelihood )

#v = cvx.Variable(n)
#obj = cvx.Maximize(v[biomass])
#constraints = [S*v == 0,
#              v_L <= v,
#              v <= v_U]
#cvx.Problem(obj, constraints).solve()

forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, unbiased_flux.values )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
                                                             , forward_rate, backward_rate, S, mets, internal_mets, 
                                                             mu0).astype(np.float64)
display(mentos.compare_frames(**metab))
reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')
display(mentos.compare_frames(**reactions))

if not os.path.isdir(algorithm):
    os.mkdir(algorithm)
for c in metab[algorithm].columns:
    metab[algorithm][c].to_csv(os.path.join(algorithm,"ABC_metab_{}.csv".format(c)),header=True)
for c in reactions[algorithm].columns:
    reactions[algorithm][c].to_csv(os.path.join(algorithm,'ABC_reaction_{}.csv'.format(c)),header=True)
display(HTML(reactions[algorithm].to_html()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6d77b57ebea5> in <module>()
#      47 metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
#      48                                                              , forward_rate, backward_rate, S, mets, internal_mets,
# ---> 49                                                              mu0).astype(np.float64)
#      50 display(mentos.compare_frames(**metab))
#      51 reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
#
# TypeError: generate_metabolite_report() takes at least 9 arguments (7 given)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
def boltzmann_distribution( x ):
    return np.exp(x)/np.sum(np.exp(x))

def uniform_distribution( x ):
    return x/np.sum(x)

def entropy( p ):
    return -p*np.log(p)
f, ax = plt.subplots(2,2,sharey="row", sharex = 'all')
x = np.array([1.,1.,1.,1.,1.,2., 1.])
f.suptitle('Boltzmann vs Uniform distribution for $x=[1 1 1 1 1 2 1]$\n\n')
ax[0, 0].plot(boltzmann_distribution( x ))
ax[0, 0].set_title('Boltzmann distribution')
print("Entropy of Boltzmann distribution is {}".format( np.sum(entropy(boltzmann_distribution(x)))))

ax[0, 0].set_ylim((0,0.4))
ax[0, 1].plot(uniform_distribution(x))
ax[0, 1].set_title('Uniform distribution')

ax[1, 0].plot(entropy(boltzmann_distribution(x)))
ax[1, 0].set_title('Entropy(Boltzmann)')
ax[1, 1].plot(entropy(uniform_distribution(x)))
print("Entropy of Uniform distribution is {}".format( np.sum(entropy(uniform_distribution(x)))))
ax[1, 1].set_title('Entropy(Uniform)')
plt.savefig('Boltzmann_vs_uniform_distribution.png')
# Out:
# Entropy of Boltzmann distribution is 1.85363117832
# Entropy of Uniform distribution is 1.90615474654

# %%
entropy(boltzmann_distribution(x))
# Out:
# array([ 0.24837717,  0.24837717,  0.24837717,  0.24837717,  0.24837717,
#         0.36336815,  0.24837717])

# %%
entropy(uniform_distribution(x))
# Out:
# array([ 0.25993019,  0.25993019,  0.25993019,  0.25993019,  0.25993019,
#         0.34657359,  0.25993019])

# %% [markdown]
# ## Convex mentos solving for likelihoods then fluxes without FBA ##
#
# We split the network into elementary modes, and divide the input flux equally amongst all the elementary modes.
#
#
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \|\log L_+\|_2 \\
#     \mbox{subject to}  & \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#     & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
# \end{array}$$
#
# From the Likelihoods, we set the direction of each reaction as a constraint and then compute the elementary modes.
# $$ \vec{\bf v} = \frac{\sum^n_i \vec{\bf e}_i}{n} $$
#
#
# Where,
#
# $$\begin{eqnarray}
# \vec{\bf e}_i  & & \text{ is the $i$th elementary mode} \\
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \Delta G_{ext} & = & \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} -\mu_{E_{ext}} \\
# v_{lower}(L) & = & \min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1 \\
# v_{upper}(L) & = & \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1 \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext
import sys
import mentos
import pandas as pd
import cobra.core

sys.path.append('/Users/zuck016/Projects/src')
abc_dir = ''
from myefm import calculate_elementary_modes, calculate_minimum_cut_sets
algorithm = 'convex_mentos_likelihoods_first_elmo'
problem = {}
#met_bounds = mentos.getMetBounds(fullS, fluxes, c_L, c_U)
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)

log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values
#positive_flux_constraint = [log_likelihood[rxn]  >= 0 
#                                for rxn in range(len(rxns)) 
#                                    if unbiased_flux[rxn] >= 0]

#negative_flux_con
#straint = [log_likelihood[rxn] <= 0 for rxn in range(len(rxns)) if unbiased_flux[rxn] <= 0]

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods
obj  = cvx.Minimize(cvx.norm2(log_likelihood))
constraints = [log_likelihood == log_K - log_Q,
              log_c[A_ext] == cvx.log(c_U),             # Creating a concentration gradient between A, E and D,F
              log_c[E_ext] == cvx.log(c_U),
              log_c[D_ext] == cvx.log(c_L),
              log_c[F_ext] == cvx.log(c_L),
             
              -abs(external_free_energy) <= fullS.T.as_matrix()*mu,
              fullS.T.as_matrix()*mu <= abs(external_free_energy)
              ] #+ positive_flux_constraint + negative_flux_constraint
cvx.Problem(obj, constraints).solve()

v_L, v_U = mentos.get_rxn_bounds_from_log_likelihood( log_likelihood )
v_L, v_U

import sys, os
sys.path.append('/Users/zuck016/Projects/src')
from myefm import calculate_elementary_modes, calculate_minimum_cut_sets

#abc_dir = os.path.join(os.environ['HOME'], 'Projects/CRT','Mentos/ABC')
model_name = os.path.join(abc_dir,'ABC_model.json')
abc = cobra.io.load_json_model( model_name )
abc.remove_metabolites([met for met in abc.metabolites if '_ext' in met.id])
for j, rxn in enumerate(abc.reactions):
    rxn.lower_bound = v_L[j]
    rxn.upper_bound = v_U[j]

abc_efms = calculate_elementary_modes(abc, verbose=False)
abc_efms = abc_efms.T.divide(abc_efms['R_1']).T
display(abc_efms)
unbiased_flux = abc_efms.sum(axis=0)/abc_efms['R_1'].sum()
unbiased_flux.to_frame('Unbiased flux')



#v = cvx.Variable(n)
#obj = cvx.Maximize(v[biomass])
#constraints = [S*v == 0,
#              v_L <= v,
#              v <= v_U]
#cvx.Problem(obj, constraints).solve()

forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, unbiased_flux.values )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
                                                             , forward_rate, backward_rate, S, mets, internal_mets, rxns, fullS,
                                                             mu0,).astype(np.float64)
#display(mentos.compare_frames(**metab))
display(HTML(metab[algorithm].T.to_html()))
reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')
#display(mentos.compare_frames(**reactions))
display(HTML(reactions[algorithm].T.to_html()))
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

#display(HTML(reactions[algorithm].to_html()))
# Out:
#      R_1  R_2  R_3  R_4  R_5  R_6  R_7  R_8  R_9
# EM1    1    1    0    1    1    0    0    2    0
# EM2    1    1    0    0    0  0.5  0.5  0.5  0.5
# EM3    1    0    1    0    0    0    1    1    0
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th>A_ext</th>
#       <th>D_ext</th>
#       <th>E_ext</th>
#       <th>F_ext</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Counts</th>
#       <td>4.22e+03</td>
#       <td>114</td>
#       <td>5.48e+03</td>
#       <td>2.25e+03</td>
#       <td>7.28e+04</td>
#       <td>19</td>
#       <td>6.02e+05</td>
#       <td>6</td>
#       <td>6.02e+05</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>Concentrations</th>
#       <td>7.01e-06</td>
#       <td>1.9e-07</td>
#       <td>9.09e-06</td>
#       <td>3.73e-06</td>
#       <td>0.000121</td>
#       <td>3.16e-08</td>
#       <td>0.001</td>
#       <td>1e-08</td>
#       <td>0.001</td>
#       <td>1e-08</td>
#     </tr>
#     <tr>
#       <th

#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#       <td>1.16</td>
#     </tr>
#     <tr>
#       <th>Total Microscopic Entropy Production Rate</th>
#       <td>0.955</td>
#       <td>0.955</td>
#       <td>0.955</td>
#       <td>0.955</td>
#       <td>0.955</td>
#       <td>0.955</td>
#       <td>0.955</td>
#       <td>0.955</td>
#       <td>0.955</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux</th>
#       <td>0.392</td>
#       <td>0.311</td>
#       <td>0.0263</td>
#       <td>0.0682</td>
#       <td>0.0682</td>
#       <td>0.0354</td>
#       <td>0.0507</td>
#       <td>0.362</td>
#       <td>0.0354</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>0.392</td>
#       <td>0.311</td>
#       <td>0.0114</td>
#       <td>0.0644</td>
#       <td>0.0644</td>
#       <td>0.0265</td>
#       <td>0.0452</td>
#       <td>0.362</td>
#       <td>0.0265</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux</th>
#       <td>1.35</td>
#       <td>1.35</td>
#       <td>1.35</td>
#       <td>1.35</td>
#       <td>1.35</td>
#       <td>1.35</td>
#       <td>1.35</td>
#       <td>1.35</td>
#       <td>1.35</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux Difference</th>
#       <td>1.3</td>
#       <td>1.3</td>
#       <td>1.3</td>
#       <td>1.3</td>
#       <td>1.3</td>
#       <td>1.3</td>
#       <td>1.3</td

# %% [markdown]
# ## maximizing entropy of the log likelihoods of the ABC model ##
# At steady state, the log likelihood is equal to the difference of the logs of the equilibrium constant $K$ and the mass action ratio $Q$, subject to the boundary conditions
#
# $$\begin{array}{ll}
#     \underset{\log\vec{\bf L}_+, \log\vec{\bf c}}{\mbox{minimize}}   & \sum_j \text{entropy}(\log L_+) \\
#     \mbox{subject to}  &  \log L_+ = \log K_{eq} - \log Q_r \\
#     & \log [A_{ext}] = \log c_{upper} \\
#     & \log [E_{ext}] = \log c_{upper} \\
#     & \log [D_{ext}] = \log c_{lower} \\
#     & \log [F_{ext}] = \log c_{lower} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_A \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_B \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_C \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_D \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_E \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_F \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
# \end{array}$$
#
# Where,
#
# $$\begin{eqnarray}
# L_+ & = & \frac{r_+}{r_-} \\
# \log K_{eq} & = & -\frac{1}{RT}S^T\cdot\mu^0 \\
# \log Q_r & = & S^T\cdot\log c \\
# \mu & = & RT\log c + \mu^0 \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext

algorithm = 'convex_mentos_external_free_energy_constraint_log_likelihood_entropy_maximization'
problem = {}
#met_bounds = mentos.getMetBounds(fullS, fluxes, c_L, c_U)
log_c = cvx.Variable(m)                                     # log of the concentrations
log_likelihood = cvx.Variable(n)

log_Q = fullS.as_matrix().T*log_c                              # log of the Reaction quotient
log_K = cvx.Constant(-1.0/(R*T)*deltaG0.as_matrix())           # log of the Equilibrium constnat
mu = R*T*log_c + mu0.values

#obj = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))  # entropy of the log likelihoods
obj  = cvx.Maximize(cvx.sum_entries(cvx.entr(log_likelihood)))
constraints = [log_likelihood == log_K - log_Q,
              log_c[A_ext] == cvx.log(c_U),             # Creating a concentration gradient between A, E and D,F
              log_c[E_ext] == cvx.log(c_U),
              log_c[D_ext] == cvx.log(c_L),
              log_c[F_ext] == cvx.log(c_L),
              -abs(external_free_energy) <= fullS.T.as_matrix()*mu,
              fullS.T.as_matrix()*mu <= abs(external_free_energy)
              ]
cvx.Problem(obj, constraints).solve()


v_L, v_U = mentos.get_rxn_bounds_from_log_likelihood( log_likelihood )

v = cvx.Variable(n)
obj = cvx.Maximize(v[biomass])
constraints = [S*v == 0,
              v_L <= v,
              v <= v_U]
cvx.Problem(obj, constraints).solve()

forward_rate,backward_rate = mentos.get_rates_from_log_likelihood_and_flux(  log_likelihood, v )
metab[algorithm] = mentos.generate_metabolite_report( np.squeeze(np.asarray(log_c.value))
                                                             , forward_rate, backward_rate, S, mets, internal_mets, 
                                                             mu0).astype(np.float64)
display(mentos.compare_frames(**metab))
reactions[algorithm] = mentos.generate_rxn_report(mets, log_c, log_Q.value, log_K.value,
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')
HTML(mentos.compare_frames(**reactions).to_html())
# Out:
#                                                                                        A  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints               1.35e+03
#                             convex_mentos_external_free_energy_constraint       6.18e+03
#                             convex_mentos_external_free_energy_constraint_l...  7.53e+03
#                             convex_mentos_implicit_constraints                  1.35e+03
#                             convex_mentos_intensional_constraints               1.35e+03
#                             maxent_production                                        130
#                             micro_maxent_production_net_flux_diff               9.25e+03
# Concentrations              convex_mentos_extensional_constraints               2.24e-06
#                             convex_mentos_external_free_energy_constraint       1.03e-05
#                             convex_mentos_external_free_energy_constraint_l...  1.25e-05
#                             convex_mentos_implicit_constraints                  2.24e-06
#                             convex_mentos_intensional_constraints               2.24e-06
#                             maxent_production                                   2.16e-07
#                             micro_maxent_production_net_flux_diff               1.54e-05
# Log Concentrations          convex_mentos_extensional_constraints                    -13
#                             convex_mentos_external_free_energy_constraint          -11.5
#                             convex_mentos_external_free_energy_constraint_l...     -11.3
#                             convex_mentos_implicit_constraints                       -13
#                             convex_mentos_intensional_constraints                    -13
#                             maxent_production                                      -15.3
#                             micro_maxent_production_net_flux_diff                  -11.1
# Standard Chemical potential convex_mentos_extensional_constraints                      4
#                             convex_mentos_external_free_energy_constraint              4
#                             convex_mentos_external_free_energy_constraint_l...         4
#                             convex_mentos_implicit_constraints                         4
#                             convex_mentos_intensional_constraints                      4
#                             maxent_production                                          4
#                             micro_maxent_production_net_flux_diff                      4
# Chemical potential          convex_mentos_extensional_constraints                  -28.2
#                             convex_mentos_external_free_energy_constraint          -24.5
#                             convex_mentos_external_free_energy_constraint_l...       -24
#                             convex_mentos_implicit_constraints                     -28.2
#                             convex_mentos_intensional_constraints                  -28.2
#                             maxent_production                                        -34
#                             micro_maxent_production_net_flux_diff                  -23.5
# S*forward_rate              convex_mentos_extensional_constraints                   -1.3
#                             convex_mentos_external_free_energy_constraint          -1.14
#                             convex_mentos_external_free_energy_constraint_l...    -0.614
#                             convex_mentos_implicit_constraints                      -1.3
#                             convex_mentos_intensional_constraints                   -1.3
#                             maxent_production                                   -6.9e+05
#                             micro_maxent_production_net_flux_diff                  -1.37
# S*backward_rate             convex_mentos_extensional_constraints                   -1.3
#                             convex_mentos_external_free_energy_constraint          -1.14
#                             convex_mentos_external_free_energy_constraint_l...    -0.614
#                             convex_mentos_implicit_constraints                      -1.3
#                             convex_mentos_intensional_constraints                   -1.3
#                             maxent_production                                   -6.9e+05
#                             micro_maxent_production_net_flux_diff                  -1.37
# S*net_flux                  convex_mentos_extensional_constraints              -1.33e-15
#                             convex_mentos_external_free_energy_constraint       3.55e-15
#                             convex_mentos_external_free_energy_constraint_l...  7.77e-16
#                             convex_mentos_implicit_constraints                  2.22e-16
#                             convex_mentos_intensional_constraints               2.22e-16
#                             maxent_production                                     -0.705
#                             micro_maxent_production_net_flux_diff               1.78e-15
#
#                                                                                        B  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints                    148
#                             convex_mentos_external_free_energy_constraint            320
#                             convex_mentos_external_free_energy_constraint_l...       407
#                             convex_mentos_implicit_constraints                       148
#                             convex_mentos_intensional_constraints                    148
#                             maxent_production                                          1
#                             micro_maxent_production_net_flux_diff                    359
# Concentrations              convex_mentos_extensional_constraints               2.47e-07
#                             convex_mentos_external_free_energy_constraint       5.32e-07
#                             convex_mentos_external_free_energy_constraint_l...  6.77e-07
#                             convex_mentos_implicit_constraints                  2.47e-07
#                             convex_mentos_intensional_constraints               2.47e-07
#                             maxent_production                                   3.05e-09
#                             micro_maxent_production_net_flux_diff               5.97e-07
# Log Concentrations          convex_mentos_extensional_constraints                  -15.2
#                             convex_mentos_external_free_energy_constraint          -14.4
#                             convex_mentos_external_free_energy_constraint_l...     -14.2
#                             convex_mentos_implicit_constraints                     -15.2
#                             convex_mentos_intensional_constraints                  -15.2
#                             maxent_production                                      -19.6
#                             micro_maxent_production_net_flux_diff                  -14.3
# Standard Chemical potential convex_mentos_extensional_constraints                      2
#                             convex_mentos_external_free_energy_constraint              2
#                             convex_mentos_external_free_energy_constraint_l...         2
#                             convex_mentos_implicit_constraints                         2
#                             convex_mentos_intensional_constraints                      2
#                             maxent_production                                          2
#                             micro_maxent_production_net_flux_diff                      2
# Chemical potential          convex_mentos_extensional_constraints                  -35.7
#                             convex_mentos_external_free_energy_constraint          -33.8
#                             convex_mentos_external_free_energy_constraint_l...     -33.2
#                             convex_mentos_implicit_constraints                     -35.7
#                             convex_mentos_intensional_constraints                  -35.7
#                             maxent_production                                      -46.6
#                             micro_maxent_production_net_flux_diff                  -33.5
# S*forward_rate              convex_mentos_extensional_constraints                  -2.69
#                             convex_mentos_external_free_energy_constraint          -2.73
#                             convex_mentos_external_free_energy_constraint_l...     -2.76
#                             convex_mentos_implicit_constraints                     -2.69
#                             convex_mentos_intensional_constraints                  -2.69
#                             maxent_production                                  -3.57e+06
#                             micro_maxent_production_net_flux_diff                  -3.84
# S*backward_rate             convex_mentos_extensional_constraints                  -2.69
#                             convex_mentos_external_free_energy_constraint          -2.73
#                             convex_mentos_external_free_energy_constraint_l...     -2.76
#                             convex_mentos_implicit_constraints                     -2.69
#                             convex_mentos_intensional_constraints                  -2.69
#                             maxent_production                                  -3.57e+06
#                             micro_maxent_production_net_flux_diff                  -3.84
# S*net_flux                  convex_mentos_extensional_constraints                      0
#                             convex_mentos_external_free_energy_constraint      -3.55e-15
#                             convex_mentos_external_free_energy_constraint_l...         0
#                             convex_mentos_implicit_constraints                 -8.88e-16
#                             convex_mentos_intensional_constraints              -8.88e-16
#                             maxent_production                                       4.56
#                             micro_maxent_production_net_flux_diff              -1.42e-14
#
#                                                                                       C  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints              1.35e+03
#                             convex_mentos_external_free_energy_constraint      6.14e+03
#                             convex_mentos_external_free_energy_constraint_l... 1.09e+04
#                             convex_mentos_implicit_constraints                 1.35e+03
#                             convex_mentos_intensional_constraints              1.35e+03
#                             maxent_production                                       231
#                             micro_maxent_production_net_flux_diff              3.19e+03
# Concentrations              convex_mentos_extensional_constraints              2.25e-06
#                             convex_mentos_external_free_energy_constraint      1.02e-05
#                             convex_mentos_external_free_energy_constraint_l... 1.82e-05
#                             convex_mentos_implicit_constraints                 2.25e-06
#                             convex_mentos_intensional_constraints              2.25e-06
#                             maxent_production                                  3.85e-07
#                             micro_maxent_production_net_flux_diff               5.3e-06
# Log Concentrations          convex_mentos_extensional_constraints                   -13
#                             convex_mentos_external_free_energy_constraint         -11.5
#                             convex_mentos_external_free_energy_constraint_l...    -10.9
#                             convex_mentos_implicit_constraints                      -13
#                             convex_mentos_intensional_constraints                   -13
#                             maxent_production                                     -14.8
#                             micro_maxent_production_net_flux_diff                 -12.1
# Standard Chemical potential convex_mentos_extensional_constraints                     2
#                             convex_mentos_external_free_energy_constraint             2
#                             convex_mentos_external_free_energy_constraint_l...        2
#                             convex_mentos_implicit_constraints                        2
#                             convex_mentos_intensional_constraints                     2
#                             maxent_production                                         2
#                             micro_maxent_production_net_flux_diff                     2
# Chemical potential          convex_mentos_extensional_constraints                 -30.2
#                             convex_mentos_external_free_energy_constraint         -26.5
#                             convex_mentos_external_free_energy_constraint_l...    -25.1
#                             convex_mentos_implicit_constraints                    -30.2
#                             convex_mentos_intensional_constraints                 -30.2
#                             maxent_production                                     -34.6
#                             micro_maxent_production_net_flux_diff                 -28.1
# S*forward_rate              convex_mentos_extensional_constraints                  1.36
#                             convex_mentos_external_free_energy_constraint          1.36
#                             convex_mentos_external_free_energy_constraint_l...      0.5
#                             convex_mentos_implicit_constraints                     1.36
#                             convex_mentos_intensional_constraints                  1.36
#                             maxent_production                                  8.27e+05
#                             micro_maxent_production_net_flux_diff                  2.08
# S*backward_rate             convex_mentos_extensional_constraints                  1.36
#                             convex_mentos_external_free_energy_constraint          1.36
#                             convex_mentos_external_free_energy_constraint_l...      0.5
#                             convex_mentos_implicit_constraints                     1.36
#                             convex_mentos_intensional_constraints                  1.36
#                             maxent_production                                  8.27e+05
#                             micro_maxent_production_net_flux_diff                  2.08
# S*net_flux                  convex_mentos_extensional_constraints              1.22e-12
#                             convex_mentos_external_free_energy_constraint      4.15e-11
#                             convex_mentos_external_free_energy_constraint_l... 1.33e-15
#                             convex_mentos_implicit_constraints                 1.22e-12
#                             convex_mentos_intensional_constraints              1.22e-12
#                             maxent_production                                     -3.86
#                             micro_maxent_production_net_flux_diff              1.78e-14
#
#                                                                                        D  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints                    673
#                             convex_mentos_external_free_energy_constraint       2.99e+03
#                             convex_mentos_external_free_energy_constraint_l...  1.12e+04
#                             convex_mentos_implicit_constraints                       673
#                             convex_mentos_intensional_constraints                    673
#                             maxent_production                                        914
#                             micro_maxent_production_net_flux_diff                    669
# Concentrations              convex_mentos_extensional_constraints               1.12e-06
#                             convex_mentos_external_free_energy_constraint       4.97e-06
#                             convex_mentos_external_free_energy_constraint_l...  1.86e-05
#                             convex_mentos_implicit_constraints                  1.12e-06
#                             convex_mentos_intensional_constraints               1.12e-06
#                             maxent_production                                   1.52e-06
#                             micro_maxent_production_net_flux_diff               1.11e-06
# Log Concentrations          convex_mentos_extensional_constraints                  -13.7
#                             convex_mentos_external_free_energy_constraint          -12.2
#                             convex_mentos_external_free_energy_constraint_l...     -10.9
#                             convex_mentos_implicit_constraints                     -13.7
#                             convex_mentos_intensional_constraints                  -13.7
#                             maxent_production                                      -13.4
#                             micro_maxent_production_net_flux_diff                  -13.7
# Standard Chemical potential convex_mentos_extensional_constraints                      0
#                             convex_mentos_external_free_energy_constraint              0
#                             convex_mentos_external_free_energy_constraint_l...         0
#                             convex_mentos_implicit_constraints                         0
#                             convex_mentos_intensional_constraints                      0
#                             maxent_production                                          0
#                             micro_maxent_production_net_flux_diff                      0
# Chemical potential          convex_mentos_extensional_constraints                    -34
#                             convex_mentos_external_free_energy_constraint          -30.3
#                             convex_mentos_external_free_energy_constraint_l...       -27
#                             convex_mentos_implicit_constraints                       -34
#                             convex_mentos_intensional_constraints                    -34
#                             maxent_production                                      -33.2
#                             micro_maxent_production_net_flux_diff                    -34
# S*forward_rate              convex_mentos_extensional_constraints                   2.55
#                             convex_mentos_external_free_energy_constraint            2.6
#                             convex_mentos_external_free_energy_constraint_l...         3
#                             convex_mentos_implicit_constraints                      2.55
#                             convex_mentos_intensional_constraints                   2.55
#                             maxent_production                                    1.7e+06
#                             micro_maxent_production_net_flux_diff                   2.27
# S*backward_rate             convex_mentos_extensional_constraints                   2.55
#                             convex_mentos_external_free_energy_constraint            2.6
#                             convex_mentos_external_free_energy_constraint_l...         3
#                             convex_mentos_implicit_constraints                      2.55
#                             convex_mentos_intensional_constraints                   2.55
#                             maxent_production                                    1.7e+06
#                             micro_maxent_production_net_flux_diff                   2.27
# S*net_flux                  convex_mentos_extensional_constraints               2.45e-12
#                             convex_mentos_external_free_energy_constraint       8.31e-11
#                             convex_mentos_external_free_energy_constraint_l...  2.02e-09
#                             convex_mentos_implicit_constraints                  2.45e-12
#                             convex_mentos_intensional_constraints               2.45e-12
#                             maxent_production                                       3.87
#                             micro_maxent_production_net_flux_diff              -1.42e-14
#
#                                                                                        E  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints               3.02e+03
#                             convex_mentos_external_free_energy_constraint       5.79e+04
#                             convex_mentos_external_free_energy_constraint_l...  1.92e+05
#                             convex_mentos_implicit_constraints                  3.02e+03
#                             convex_mentos_intensional_constraints               3.02e+03
#                             maxent_production                                   2.79e+05
#                             micro_maxent_production_net_flux_diff               1.22e+04
# Concentrations              convex_mentos_extensional_constraints               5.02e-06
#                             convex_mentos_external_free_energy_constraint       9.62e-05
#                             convex_mentos_external_free_energy_constraint_l...  0.000319
#                             convex_mentos_implicit_constraints                  5.02e-06
#                             convex_mentos_intensional_constraints               5.02e-06
#                             maxent_production                                   0.000464
#                             micro_maxent_production_net_flux_diff               2.03e-05
# Log Concentrations          convex_mentos_extensional_constraints                  -12.2
#                             convex_mentos_external_free_energy_constraint          -9.25
#                             convex_mentos_external_free_energy_constraint_l...     -8.05
#                             convex_mentos_implicit_constraints                     -12.2
#                             convex_mentos_intensional_constraints                  -12.2
#                             maxent_production                                      -7.68
#                             micro_maxent_production_net_flux_diff                  -10.8
# Standard Chemical potential convex_mentos_extensional_constraints                      2
#                             convex_mentos_external_free_energy_constraint              2
#                             convex_mentos_external_free_energy_constraint_l...         2
#                             convex_mentos_implicit_constraints                         2
#                             convex_mentos_intensional_constraints                      2
#                             maxent_production                                          2
#                             micro_maxent_production_net_flux_diff                      2
# Chemical potential          convex_mentos_extensional_constraints                  -28.2
#                             convex_mentos_external_free_energy_constraint          -20.9
#                             convex_mentos_external_free_energy_constraint_l...       -18
#                             convex_mentos_implicit_constraints                     -28.2
#                             convex_mentos_intensional_constraints                  -28.2
#                             maxent_production                                        -17
#                             micro_maxent_production_net_flux_diff                  -24.8
# S*forward_rate              convex_mentos_extensional_constraints                  -0.98
#                             convex_mentos_external_free_energy_constraint       2.48e-07
#                             convex_mentos_external_free_energy_constraint_l...  4.37e-08
#                             convex_mentos_implicit_constraints                     -0.98
#                             convex_mentos_intensional_constraints                  -0.98
#                             maxent_production                                   3.15e+06
#                             micro_maxent_production_net_flux_diff              -7.11e-15
# S*backward_rate             convex_mentos_extensional_constraints                  -0.98
#                             convex_mentos_external_free_energy_constraint       2.49e-07
#                             convex_mentos_external_free_energy_constraint_l...  6.02e-08
#                             convex_mentos_implicit_constraints                     -0.98
#                             convex_mentos_intensional_constraints                  -0.98
#                             maxent_production                                   3.15e+06
#                             micro_maxent_production_net_flux_diff              -7.99e-15
# S*net_flux                  convex_mentos_extensional_constraints              -8.88e-16
#                             convex_mentos_external_free_energy_constraint       -4.2e-10
#                             convex_mentos_external_free_energy_constraint_l... -1.65e-08
#                             convex_mentos_implicit_constraints                 -4.44e-16
#                             convex_mentos_intensional_constraints              -4.44e-16
#                             maxent_production                                       1.43
#                             micro_maxent_production_net_flux_diff                      0
#
#                                                                                        F  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints                     12
#                             convex_mentos_external_free_energy_constraint             12
#                             convex_mentos_external_free_energy_constraint_l...        11
#                             convex_mentos_implicit_constraints                        12
#                             convex_mentos_intensional_constraints                     12
#                             maxent_production                                          0
#                             micro_maxent_production_net_flux_diff                     19
# Concentrations              convex_mentos_extensional_constraints               2.02e-08
#                             convex_mentos_external_free_energy_constraint       2.04e-08
#                             convex_mentos_external_free_energy_constraint_l...  1.94e-08
#                             convex_mentos_implicit_constraints                  2.02e-08
#                             convex_mentos_intensional_constraints               2.02e-08
#                             maxent_production                                   1.64e-13
#                             micro_maxent_production_net_flux_diff               3.18e-08
# Log Concentrations          convex_mentos_extensional_constraints                  -17.7
#                             convex_mentos_external_free_energy_constraint          -17.7
#                             convex_mentos_external_free_energy_constraint_l...     -17.8
#                             convex_mentos_implicit_constraints                     -17.7
#                             convex_mentos_intensional_constraints                  -17.7
#                             maxent_production                                      -29.4
#                             micro_maxent_production_net_flux_diff                  -17.3
# Standard Chemical potential convex_mentos_extensional_constraints                      1
#                             convex_mentos_external_free_energy_constraint              1
#                             convex_mentos_external_free_energy_constraint_l...         1
#                             convex_mentos_implicit_constraints                         1
#                             convex_mentos_intensional_constraints                      1
#                             maxent_production                                          1
#                             micro_maxent_production_net_flux_diff                      1
# Chemical potential          convex_mentos_extensional_constraints                  -42.9
#                             convex_mentos_external_free_energy_constraint          -42.9
#                             convex_mentos_external_free_energy_constraint_l...       -43
#                             convex_mentos_implicit_constraints                     -42.9
#                             convex_mentos_intensional_constraints                  -42.9
#                             maxent_production                                        -72
#                             micro_maxent_production_net_flux_diff                  -41.8
# S*forward_rate              convex_mentos_extensional_constraints              -1.05e-05
#                             convex_mentos_external_free_energy_constraint       -1.1e-07
#                             convex_mentos_external_free_energy_constraint_l... -6.97e-08
#                             convex_mentos_implicit_constraints                 -1.05e-05
#                             convex_mentos_intensional_constraints              -1.05e-05
#                             maxent_production                                   5.02e+05
#                             micro_maxent_production_net_flux_diff              -4.37e-11
# S*backward_rate             convex_mentos_extensional_constraints              -1.05e-05
#                             convex_mentos_external_free_energy_constraint      -1.34e-07
#                             convex_mentos_external_free_energy_constraint_l... -6.97e-08
#                             convex_mentos_implicit_constraints                 -1.05e-05
#                             convex_mentos_intensional_constraints              -1.05e-05
#                             maxent_production                                   5.02e+05
#                             micro_maxent_production_net_flux_diff              -4.37e-11
# S*net_flux                  convex_mentos_extensional_constraints               1.53e-10
#                             convex_mentos_external_free_energy_constraint       2.42e-08
#                             convex_mentos_external_free_energy_constraint_l... -3.33e-16
#                             convex_mentos_implicit_constraints                  1.53e-10
#                             convex_mentos_intensional_constraints               1.53e-10
#                             maxent_production                                     -0.373
#                             micro_maxent_production_net_flux_diff               1.07e-14
#
#                                                                                   A_ext  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints              6.02e+05
#                             convex_mentos_external_free_energy_constraint      6.02e+05
#                             convex_mentos_external_free_energy_constraint_l... 6.02e+05
#                             convex_mentos_implicit_constraints                 6.02e+05
#                             convex_mentos_intensional_constraints              6.02e+05
#                             maxent_production                                   2.2e+07
#                             micro_maxent_production_net_flux_diff              6.02e+05
# Concentrations              convex_mentos_extensional_constraints                 0.001
#                             convex_mentos_external_free_energy_constraint         0.001
#                             convex_mentos_external_free_energy_constraint_l...    0.001
#                             convex_mentos_implicit_constraints                    0.001
#                             convex_mentos_intensional_constraints                 0.001
#                             maxent_production                                    0.0365
#                             micro_maxent_production_net_flux_diff                 0.001
# Log Concentrations          convex_mentos_extensional_constraints                 -6.91
#                             convex_mentos_external_free_energy_constraint         -6.91
#                             convex_mentos_external_free_energy_constraint_l...    -6.91
#                             convex_mentos_implicit_constraints                    -6.91
#                             convex_mentos_intensional_constraints                 -6.91
#                             maxent_production                                     -3.31
#                             micro_maxent_production_net_flux_diff                 -6.91
# Standard Chemical potential convex_mentos_extensional_constraints                     4
#                             convex_mentos_external_free_energy_constraint             4
#                             convex_mentos_external_free_energy_constraint_l...        4
#                             convex_mentos_implicit_constraints                        4
#                             convex_mentos_intensional_constraints                     4
#                             maxent_production                                         4
#                             micro_maxent_production_net_flux_diff                     4
# Chemical potential          convex_mentos_extensional_constraints                 -13.1
#                             convex_mentos_external_free_energy_constraint         -13.1
#                             convex_mentos_external_free_energy_constraint_l...    -13.1
#                             convex_mentos_implicit_constraints                    -13.1
#                             convex_mentos_intensional_constraints                 -13.1
#                             maxent_production                                      -4.2
#                             micro_maxent_production_net_flux_diff                 -13.1
# S*forward_rate              convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*backward_rate             convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*net_flux                  convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
#
#                                                                                   D_ext  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints                     6
#                             convex_mentos_external_free_energy_constraint             6
#                             convex_mentos_external_free_energy_constraint_l...        6
#                             convex_mentos_implicit_constraints                        6
#                             convex_mentos_intensional_constraints                     6
#                             maxent_production                                         5
#                             micro_maxent_production_net_flux_diff                     6
# Concentrations              convex_mentos_extensional_constraints                 1e-08
#                             convex_mentos_external_free_energy_constraint         1e-08
#                             convex_mentos_external_free_energy_constraint_l...    1e-08
#                             convex_mentos_implicit_constraints                    1e-08
#                             convex_mentos_intensional_constraints                 1e-08
#                             maxent_production                                  9.96e-09
#                             micro_maxent_production_net_flux_diff                 1e-08
# Log Concentrations          convex_mentos_extensional_constraints                 -18.4
#                             convex_mentos_external_free_energy_constraint         -18.4
#                             convex_mentos_external_free_energy_constraint_l...    -18.4
#                             convex_mentos_implicit_constraints                    -18.4
#                             convex_mentos_intensional_constraints                 -18.4
#                             maxent_production                                     -18.4
#                             micro_maxent_production_net_flux_diff                 -18.4
# Standard Chemical potential convex_mentos_extensional_constraints                     0
#                             convex_mentos_external_free_energy_constraint             0
#                             convex_mentos_external_free_energy_constraint_l...        0
#                             convex_mentos_implicit_constraints                        0
#                             convex_mentos_intensional_constraints                     0
#                             maxent_production                                         0
#                             micro_maxent_production_net_flux_diff                     0
# Chemical potential          convex_mentos_extensional_constraints                 -45.7
#                             convex_mentos_external_free_energy_constraint         -45.7
#                             convex_mentos_external_free_energy_constraint_l...    -45.7
#                             convex_mentos_implicit_constraints                    -45.7
#                             convex_mentos_intensional_constraints                 -45.7
#                             maxent_production                                     -45.7
#                             micro_maxent_production_net_flux_diff                 -45.7
# S*forward_rate              convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*backward_rate             convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*net_flux                  convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
#
#                                                                                   E_ext  \
# major                       minor
# Counts                      convex_mentos_extensional_constraints              6.02e+05
#                             convex_mentos_external_free_energy_constraint      6.02e+05
#                             convex_mentos_external_free_energy_constraint_l... 6.02e+05
#                             convex_mentos_implicit_constraints                 6.02e+05
#                             convex_mentos_intensional_constraints              6.02e+05
#                             maxent_production                                   3.5e+05
#                             micro_maxent_production_net_flux_diff              6.02e+05
# Concentrations              convex_mentos_extensional_constraints                 0.001
#                             convex_mentos_external_free_energy_constraint         0.001
#                             convex_mentos_external_free_energy_constraint_l...    0.001
#                             convex_mentos_implicit_constraints                    0.001
#                             convex_mentos_intensional_constraints                 0.001
#                             maxent_production                                  0.000581
#                             micro_maxent_production_net_flux_diff                 0.001
# Log Concentrations          convex_mentos_extensional_constraints                 -6.91
#                             convex_mentos_external_free_energy_constraint         -6.91
#                             convex_mentos_external_free_energy_constraint_l...    -6.91
#                             convex_mentos_implicit_constraints                    -6.91
#                             convex_mentos_intensional_constraints                 -6.91
#                             maxent_production                                     -7.45
#                             micro_maxent_production_net_flux_diff                 -6.91
# Standard Chemical potential convex_mentos_extensional_constraints                     2
#                             convex_mentos_external_free_energy_constraint             2
#                             convex_mentos_external_free_energy_constraint_l...        2
#                             convex_mentos_implicit_constraints                        2
#                             convex_mentos_intensional_constraints                     2
#                             maxent_production                                         2
#                             micro_maxent_production_net_flux_diff                     2
# Chemical potential          convex_mentos_extensional_constraints                 -15.1
#                             convex_mentos_external_free_energy_constraint         -15.1
#                             convex_mentos_external_free_energy_constraint_l...    -15.1
#                             convex_mentos_implicit_constraints                    -15.1
#                             convex_mentos_intensional_constraints                 -15.1
#                             maxent_production                                     -16.5
#                             micro_maxent_production_net_flux_diff                 -15.1
# S*forward_rate              convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*backward_rate             convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*net_flux                  convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
#
#                                                                                   F_ext
# major                       minor
# Counts                      convex_mentos_extensional_constraints                     6
#                             convex_mentos_external_free_energy_constraint             6
#                             convex_mentos_external_free_energy_constraint_l...        6
#                             convex_mentos_implicit_constraints                        6
#                             convex_mentos_intensional_constraints                     6
#                             maxent_production                                         7
#                             micro_maxent_production_net_flux_diff                     6
# Concentrations              convex_mentos_extensional_constraints                 1e-08
#                             convex_mentos_external_free_energy_constraint         1e-08
#                             convex_mentos_external_free_energy_constraint_l...    1e-08
#                             convex_mentos_implicit_constraints                    1e-08
#                             convex_mentos_intensional_constraints                 1e-08
#                             maxent_production                                  1.21e-08
#                             micro_maxent_production_net_flux_diff                 1e-08
# Log Concentrations          convex_mentos_extensional_constraints                 -18.4
#                             convex_mentos_external_free_energy_constraint         -18.4
#                             convex_mentos_external_free_energy_constraint_l...    -18.4
#                             convex_mentos_implicit_constraints                    -18.4
#                             convex_mentos_intensional_constraints                 -18.4
#                             maxent_production                                     -18.2
#                             micro_maxent_production_net_flux_diff                 -18.4
# Standard Chemical potential convex_mentos_extensional_constraints                     1
#                             convex_mentos_external_free_energy_constraint             1
#                             convex_mentos_external_free_energy_constraint_l...        1
#                             convex_mentos_implicit_constraints                        1
#                             convex_mentos_intensional_constraints                     1
#                             maxent_production                                         1
#                             micro_maxent_production_net_flux_diff                     1
# Chemical potential          convex_mentos_extensional_constraints                 -44.7
#                             convex_mentos_external_free_energy_constraint         -44.7
#                             convex_mentos_external_free_energy_constraint_l...    -44.7
#                             convex_mentos_implicit_constraints                    -44.7
#                             convex_mentos_intensional_constraints                 -44.7
#                             maxent_production                                     -44.2
#                             micro_maxent_production_net_flux_diff                 -44.7
# S*forward_rate              convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*backward_rate             convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# S*net_flux                  convex_mentos_extensional_constraints                   nan
#                             convex_mentos_external_free_energy_constraint           nan
#                             convex_mentos_external_free_energy_constraint_l...      nan
#                             convex_mentos_implicit_constraints                      nan
#                             convex_mentos_intensional_constraints                   nan
#                             maxent_production                                       nan
#                             micro_maxent_production_net_flux_diff                   nan
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>R_1</th>
#       <th>R_2</th>
#       <th>R_3</th>
#       <th>R_4</th>
#       <th>R_5</th>
#       <th>R_6</th>
#       <th>R_7</th>
#       <th>R_8</th>
#       <th>R_9</th>
#     </tr>
#     <tr>
#       <th>major</th>
#       <th>minor</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="7" valign="top">Forward likelihoods</th>
#       <th>convex_mentos_extensional_constraints</th>
#       <td>446</td>
#       <td>20.3</td>
#       <td>2.23</td>
#       <td>4.98</td>
#       <td>199</td>
#       <td>2.02</td>
#       <td>4.5</td>
#       <td>112</td>
#       <td>2.02</td>
#     </tr>
#     <tr>
#       <th>convex_mentos_external_free_energy_constra
td>
#     </tr>
#     <tr>
#       <th>micro_maxent_production_net_flux_diff</th>
#       <td>-4.18</td>
#       <td>-3.25</td>
#       <td>-1.06</td>
#       <td>-2.28</td>
#       <td>-3.9</td>
#       <td>-0.752

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')
reaction_data = (reactions['convex_mentos']['Delta G']).to_csv('energy_barrier_and_sink_DeltaG.csv',header=True)
metabolite_data = metab['convex_mentos']['Chemical potential'].to_csv(
    'energy_barrier_and_sink_Chemical_potential.csv', header=True)
reaction_data = (reactions['convex_mentos']['Delta G']).to_dict()
metabolite_data = metab['convex_mentos']['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="vjisurxrby"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({ paths: { d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                                      escher: '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min' }
#            });
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            });
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"vjisurxrby"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": -45.664060542620739, "R_9": -44.664060542500188, "R_1": 13.124022703402893, "R_2": 1.632579604709826e-10, "R_3": -8.4593643869177236e-11, "R_4": 1.8667528036847622e-10, "R_5": 15.124022703201204, "R_6": -4.5768219571462679e-10, "R_7": 1.5864748468268827e-10}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -8.2852835703306482e-11, "C": -1.6744605702001536e-10, "B": 8.0405460067822787e-11, "E": -2.8467805890386444e-10, "D": -8.7988049318744869e-12, "F": -1.2942558136330717e-10, "F_ext": -44.66406054262962, "A_ext": -13.124022703485746, "D_ext": -45.664060542629535, "E_ext": -15.124022703485885}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447894321204}}}},"27":{"name":"","bigg_id":"R_8",

# %% [markdown]
# # Nonconvex formulations of MENTOS #
# ## Maximize entropy production for the ABC model ##
#
# $$
# \begin{array}{ll}
#     \underset{\vec{\bf c}, \vec{r}_+,\vec{r}_-}{\mbox{maximize}}   & -\sum_i {\mathscr P}_{+i}\log{\mathscr P}_{+i}-\sum_i {\mathscr P}_{-i}\log{\mathscr P}_{-i}  \\
#     \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#       & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array}
# $$
#
# Where
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
# Decision variables are emphasized in **bold**.

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U

obj = 'maxent_production'

convex_mentos = 'convex_mentos_likelihoods_first_elmo'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_maxent_production_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def maxent_production(x):
        """Maximize entropy production of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum( np.log(forward_probability)*forward_probability
                    + np.log(backward_probability)*backward_probability)
        g = np.concatenate((np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return maxent_production
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_maxent_production_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')

#metab[obj].to_csv('ABC_metab_{}.csv'.format(obj))
#reactions[obj].to_csv('ABC_reactions_{obj}.csv'.format(obj=obj))

#display(metab[obj].T)
#HTML(reactions[obj].T.to_html())#
#true_metab[obj] = pd.read_csv('ABC_metab_{}.csv'.format(obj), index_col=0).astype(np.float64)
#true_reactions[obj] = pd.read_csv('ABC_reactions_{}.csv'.format(obj),index_col=0)

#display(mentos.compare_frames(true_metab[obj], metab[obj]))
#pd.testing.assert_frame_equal(true_metab[obj],metab[obj].astype(np.float64))
#pd.testing.assert_frame_equal(true_reactions[obj],reactions[obj])


#HTML(mentos.compare_frames(true_reactions[obj],reactions[obj]).to_html())
display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-d09952e4aa56> in <module>()
#       8 i,n = S.shape
#       9 variable_group = [dict(name='log_c',nvars=m, type='c',
# ---> 10                                      initial_value=metab[convex_mentos]['Log Concentrations'].values),
#      11                       dict(name='forward_rate', nvars=n, type='c',
#      12                                              initial_value=reactions[convex_mentos]['Forward rate'].values),
#
# KeyError: 'convex_mentos_likelihood_first_elmo'

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')

reaction_data = reactions[obj]['Net flux'].to_dict()
metabolite_data = metab[obj]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="mdterkctma"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({ paths: { d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                                      escher: '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min' }
#            });
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            });
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"mdterkctma"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": 21.682032032395224, "R_9": 0.47957320264637859, "R_1": 11.560376422205913, "R_2": 11.560375218363477, "R_3": 1.1456982257680892e-06, "R_4": 10.601228813006074, "R_5": 10.601228813011058, "R_6": 0.47957320267149023, "R_7": 0.47957440639305443}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -23.299971888897868, "C": -33.465288765701288, "B": -33.655798059882805, "E": -25.876176121749655, "D": -35.147143292668943, "F": -44.253069702743687, "F_ext": -44.664060542629493, "A_ext": -13.124022703486059, "D_ext": -45.664060542629493, "E_ext": -15.124022703486059}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447894321204}}}},"27":{"name":"","bigg_id":"R_8","reversibility":false,"label_x":1482.1

# %% [markdown]
# ## Minimize entropy production for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf c}, \vec{r}_+,\vec{r}_-}{\mbox{minimize}}   & -\sum_i {\mathscr P}_{+i}\log{\mathscr P}_{+i}-\sum_i {\mathscr P}_{-i}\log{\mathscr P}_{-i}  \\
#      \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#                            & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array} $$
#
# Where
#
#
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# * $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
#
# Decision variables are emphasized in **bold**.

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U

obj = 'minent_production'

convex_mentos = 'convex_mentos_external_free_energy_constraint'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_minent_production_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def minent_production(x):
        """Minimize entropy production of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum( np.log(forward_probability)*forward_probability
                    + np.log(backward_probability)*backward_probability)
        g = np.concatenate((np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return f, g, fail
    return minent_production
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_minent_production_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')

#metab[obj].to_csv('ABC_metab_{}.csv'.format(obj))
#reactions[obj].to_csv('ABC_reactions_{obj}.csv'.format(obj=obj))

#display(metab[obj].T)
#HTML(reactions[obj].T.to_html())#
#true_metab[obj] = pd.read_csv('ABC_metab_{}.csv'.format(obj), index_col=0).astype(np.float64)
#true_reactions[obj] = pd.read_csv('ABC_reactions_{}.csv'.format(obj),index_col=0)

#display(mentos.compare_frames(true_metab[obj], metab[obj]))
#pd.testing.assert_frame_equal(true_metab[obj],metab[obj].astype(np.float64))
#pd.testing.assert_frame_equal(true_reactions[obj],reactions[obj])


#HTML(mentos.compare_frames(true_reactions[obj],reactions[obj]).to_html())
display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
#                                     A         B        C        D        E  \
# Counts                       6.02e+05  8.67e+04 1.35e+06 5.12e+05 6.02e+05
# Concentrations                  0.001  0.000144  0.00224  0.00085    0.001
# Log Concentrations              -6.91     -8.85     -6.1    -7.07    -6.91
# Standard Chemical potential         4         2        2        0        2
# Chemical potential              -13.1     -19.9    -13.1    -17.5    -15.1
# S*forward_rate                  0.789     -11.2     3.33     22.3    -8.97
# S*backward_rate                 0.789     -11.2     3.33     22.3    -8.97
# S*net_flux                  -1.05e-13 -2.48e-13 1.91e-12 5.97e-08 6.66e-14
#
#                                     F    A_ext  D_ext    E_ext  F_ext
# Counts                            473 6.02e+05      6 6.02e+05      6
# Concentrations               7.86e-07    0.001  1e-08    0.001  1e-08
# Log Concentrations              -14.1    -6.91  -18.4    -6.91  -18.4
# Standard Chemical potential         1        4      0        2      1
# Chemical potential              -33.8    -13.1  -45.7    -15.1  -44.7
# S*forward_rate               4.45e-05      nan    nan      nan    nan
# S*backward_rate              4.45e-05      nan    nan      nan    nan
# S*net_flux                  -2.04e-14      nan    nan      nan    nan
#                                                          R_1      R_2  \
# Forward likelihoods                                        1     15.8
# Backward likelihoods                                       1   0.0635
# Delta G                                             -0.00113     -6.8
# log Q_r                                            -0.000454    -1.94
# log K_eq                                                  -0    0.807
# Delta G0                                                   0       -2
# logK - logQ                                         0.000454     2.74
# logQ - logK                                        -0.000454    -2.74
# Forward Log likelihoods                             0.000456     2.76
# Backward Log likelihoods                           -0.000456    -2.76
# Forward probabilities                               3.13e-05 0.000493
# Backward probabilities                              3.13e-05 1.99e-06
# Net probabilities                                   2.86e-08 0.000491
# Net likelihoods                                     0.000913     15.7
# Forward rate                                            4.12  0.00201
# Backward rate                                           4.11 0.000127
# Thermodynamic driving force                                1     15.8
# Net flux                                             0.00188  0.00188
# Forward Entropy Production                          0.000325  0.00375
# Backward Entropy Production                         0.000325 2.61e-05
# Reaction Entropy Production                         0.000649  0.00378
# Microscopic Reaction Entropy Production Rate         0.00267 7.54e-06
# Microscopic Reaction Entropy Production Net Flux    1.22e-06 7.11e-06
# Microscopic Reaction Entropy Production Net Flu...  5.03e-10 7.01e-06
# Total Entropy Production                              0.0311   0.0311
# Total Microscopic Entropy Production Rate           3.15e-05 3.15e-05
# Macroscopic Reaction Entropy Production Net Flux    6.27e-07 3.65e-06
# Macroscopic Reaction Entropy Production Net Flu...  2.59e-10  3.6e-06
# Total Macroscopic Entropy Production Net Flux          3e-05    3e-05
# Total Macroscopic Entropy Production Net Flux D...  2.73e-05 2.73e-05
#
#                                                          R_3       R_4  \
# Forward likelihoods                                        1         1
# Backward likelihoods                                       1         1
# Delta G                                             2.91e-05 -4.02e-06
# log Q_r                                                0.807      1.61
# log K_eq                                               0.807      1.61
# Delta G0                                                  -2        -4
# logK - logQ                                        -1.18e-05  1.62e-06
# logQ - logK                                         1.18e-05 -1.62e-06
# Forward Log likelihoods                            -3.05e-07  1.62e-06
# Backward Log likelihoods                            3.05e-07 -1.62e-06
# Forward probabilities                               3.13e-05  3.13e-05
# Backward probabilities                              3.13e-05  3.13e-05
# Net probabilities                                  -1.91e-11  1.02e-10
# Net likelihoods                                    -6.09e-07  3.25e-06
# Forward rate                                            3.33      11.2
# Backward rate                                           3.33      11.2
# Thermodynamic driving force                               -1         1
# Net flux                                           -1.01e-06  1.81e-05
# Forward Entropy Production                          0.000325  0.000325
# Backward Entropy Production                         0.000325  0.000325
# Reaction Entropy Production                         0.000649  0.000649
# Microscopic Reaction Entropy Production Rate         0.00216   0.00724
# Microscopic Reaction Entropy Production Net Flux   -6.58e-10  1.18e-08
# Microscopic Reaction Entropy Production Net Flu...  1.81e-16  1.72e-14
# Total Entropy Production                              0.0311    0.0311
# Total Microscopic Entropy Production Rate           3.15e-05  3.15e-05
# Macroscopic Reaction Entropy Production Net Flux    6.27e-07  6.27e-07
# Macroscopic Reaction Entropy Production Net Flu... -1.73e-13   9.2e-13
# Total Macroscopic Entropy Production Net Flux          3e-05     3e-05
# Total Macroscopic Entropy Production Net Flux D...  2.73e-05  2.73e-05
#
#                                                          R_5      R_6  \
# Forward likelihoods                                        1     17.5
# Backward likelihoods                                       1   0.0572
# Delta G                                            -2.05e-05    -7.11
# log Q_r                                            -8.29e-06    -2.47
# log K_eq                                                  -0    0.403
# Delta G0                                                   0       -1
# logK - logQ                                         8.29e-06     2.87
# logQ - logK                                        -8.29e-06    -2.87
# Forward Log likelihoods                             8.28e-06     2.86
# Backward Log likelihoods                           -8.28e-06    -2.86
# Forward probabilities                               3.13e-05 0.000547
# Backward probabilities                              3.13e-05 1.79e-06
# Net probabilities                                   5.19e-10 0.000545
# Net likelihoods                                     1.66e-05     17.4
# Forward rate                                            2.19 0.000987
# Backward rate                                           2.19 5.65e-05
# Thermodynamic driving force                                1     17.5
# Net flux                                            1.81e-05 0.000931
# Forward Entropy Production                          0.000325  0.00411
# Backward Entropy Production                         0.000325 2.37e-05
# Reaction Entropy Production                         0.000649  0.00413
# Microscopic Reaction Entropy Production Rate         0.00142 4.06e-06
# Microscopic Reaction Entropy Production Net Flux    1.18e-08 3.85e-06
# Microscopic Reaction Entropy Production Net Flu...   8.8e-14  3.8e-06
# Total Entropy Production                              0.0311   0.0311
# Total Microscopic Entropy Production Rate           3.15e-05 3.15e-05
# Macroscopic Reaction Entropy Production Net Flux    6.27e-07 3.99e-06
# Macroscopic Reaction Entropy Production Net Flu...  4.69e-12 3.95e-06
# Total Macroscopic Entropy Production Net Flux          3e-05    3e-05
# Total Macroscopic Entropy Production Net Flux D...  2.73e-05 2.73e-05
#
#                                                         R_7      R_8      R_9
# Forward likelihoods                                    6.57 3.18e+04     78.8
# Backward likelihoods                                  0.152 3.14e-05   0.0127
# Delta G                                                -4.4    -28.1    -10.8
# log Q_r                                              -0.969    -11.4    -4.36
# log K_eq                                              0.807       -0       -0
# Delta G0                                                 -2        0        0
# logK - logQ                                            1.78     11.4     4.36
# logQ - logK                                           -1.78    -11.4    -4.36
# Forward Log likelihoods                                1.88     10.4     4.37
# Backward Log likelihoods                              -1.88    -10.4    -4.37
# Forward probabilities                              0.000206    0.996  0.00247
# Backward probabilities                             4.77e-06 9.84e-10 3.97e-07
# Net probabilities                                  0.000201    0.996  0.00247
# Net likelihoods                                        6.41 3.18e+04     78.8
# Forward rate                                         0.0011 0.000966 0.000943
# Backward rate                                      0.000167 3.04e-08  1.2e-05
# Thermodynamic driving force                            6.57 3.18e+04     78.8
# Net flux                                            0.00093 0.000966 0.000931
# Forward Entropy Production                          0.00175  0.00396   0.0148
# Backward Entropy Production                        5.84e-05 2.04e-08 5.86e-06
# Reaction Entropy Production                          0.0018  0.00396   0.0148
# Microscopic Reaction Entropy Production Rate       1.92e-06 3.83e-06  1.4e-05
# Microscopic Reaction Entropy Production Net Flux   1.68e-06 3.83e-06 1.38e-05
# Microscopic Reaction Entropy Production Net Flu... 1.57e-06 3.83e-06 1.38e-05
# Total Entropy Production                             0.0311   0.0311   0.0311
# Total Microscopic Entropy Production Rate          3.15e-05 3.15e-05 3.15e-05
# Macroscopic Reaction Entropy Production Net Flux   1.74e-06 3.83e-06 1.43e-05
# Macroscopic Reaction Entropy Production Net Flu... 1.63e-06 3.83e-06 1.43e-05
# Total Macroscopic Entropy Production Net Flux         3e-05    3e-05    3e-05
# Total Macroscopic Entropy Production Net Flux D... 2.73e-05 2.73e-05 2.73e-05

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')

reaction_data = reactions[obj]['Net flux'].to_dict()
metabolite_data = metab[obj]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="tjphlwxfbw"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({ paths: { d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                                      escher: '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min' }
#            });
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            });
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"tjphlwxfbw"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": 2.3080677861395129, "R_9": 1.391684781030943, "R_1": 3.6997467035593057, "R_2": 2.7833754256395324, "R_3": 0.91637127791872919, "R_4": 5.8635944717444488e-06, "R_5": 5.7937628280008476e-06, "R_6": 1.3916847810255217, "R_7": 2.3080560589445618}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -28.248252798017234, "C": -29.700668597901075, "B": -35.176647371725664, "E": -28.927332890233469, "D": -32.051991802503174, "F": -42.67206430422727, "F_ext": -44.664060542590605, "A_ext": -13.124022703486055, "D_ext": -45.664060542653353, "E_ext": -15.124022703486059}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447894321204}}}},"27":{"name":"","bigg_id":"R_8","reversibility":false,"label_x":1482.1

# %% [markdown]
# ## Maximize microscopic entropy production net flux difference using external free energy constraint for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf r}_+,\vec{\bf r}_-, \vec{\bf c}}{\mbox{maximize}}   & -\sum_j{\mathscr P}_{+j}\log({\mathscr P}_{+j})v_{j} + \sum_j{\mathscr P}_{-j}\log({\mathscr P}_{-j})v_{j}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#        & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array} $$
# Where
#
#
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
#
# Decision variables are emphasized in **bold**.

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U

obj = 'micro_maxent_production_net_flux_diff'
convex_mentos = 'convex_mentos_likelihoods_first_elmo'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_micro_maxent_production_net_flux_diff_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def micro_maxent_production_net_flux_diff(x):
        """Maximize product of microscopic entropy production and net_flux of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum( np.log(forward_probability)*forward_probability*net_flux
                    - np.log(backward_probability)*backward_probability*net_flux)
        g = np.concatenate((np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return micro_maxent_production_net_flux_diff
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_micro_maxent_production_net_flux_diff_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')
algorithm = obj
print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

display(HTML(reactions[algorithm].to_html()))

display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-de25698364c4> in <module>()
#       7 i,n = S.shape
#       8 variable_group = [dict(name='log_c',nvars=m, type='c',
# ----> 9                                      initial_value=metab[convex_mentos]['Log Concentrations'].values),
#      10                       dict(name='forward_rate', nvars=n, type='c',
#      11                                              initial_value=reactions[convex_mentos]['Forward rate'].values),
#
# KeyError: 'convex_mentos_likelihoods_first_elmo'

# %%
print(os.path.exists.__doc__)
# Out:
# Test whether a path exists.  Returns False for broken symbolic links

# %% [markdown]
# ## Maximize microscopic entropy production net flux difference using energy barrier/sink as constraints on each potential for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf r}_+,\vec{\bf r}_-, \vec{\bf c}}{\mbox{maximize}}   & -\sum_j{\mathscr P}_{+j}\log({\mathscr P}_{+j})v_{j} + \sum_j{\mathscr P}_{-j}\log({\mathscr P}_{-j})v_{j}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#                            & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_A \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_B \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_C \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_D \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_E \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#      & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_F \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#     \end{array} $$
# Where
#
#
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# * $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
#
#
# Decision variables are emphasized in **bold**.

# %%
obj = 'micro_maxent_production_net_flux_diff_energy_barrier'
m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=i, type='i'),
                    dict(name='energy_sink',ncons=i,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_micro_maxent_production_net_flux_diff_energy_barrier_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])

    def micro_maxent_production_net_flux_diff_energy_barrier(x):
        """Maximize product of microscopic entropy production and net_flux of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum( np.log(forward_probability)*forward_probability*net_flux
                    - np.log(backward_probability)*backward_probability*net_flux)
        g = np.concatenate((np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),                 # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),
                              log_c[D_ext] - np.log(c_L),
                              log_c[F_ext] - np.log(c_L)],
                             [-mu[A] + mu[D_ext] + mu[F_ext],           # Energy sink constraint
                              -mu[B] + mu[D_ext] + mu[F_ext],
                              -mu[C] + mu[D_ext] + mu[F_ext],
                              -mu[D] + mu[D_ext] + mu[F_ext],
                              -mu[E] + mu[D_ext] + mu[F_ext],
                              -mu[F] + mu[D_ext] + mu[F_ext]],
    
                             [ mu[A] - mu[A_ext] - mu[E_ext],           # Energy barrier constraint
                               mu[B] - mu[A_ext] - mu[E_ext],
                               mu[C] - mu[A_ext] - mu[E_ext],
                               mu[D] - mu[A_ext] - mu[E_ext],
                               mu[E] - mu[A_ext] - mu[E_ext],
                               mu[F] - mu[A_ext] - mu[E_ext]],  
                            
                              np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux,
                              net_flux - np.maximum(1, thermodynamic_driving_force ) - 1))
        
        fail = 0
        return -f, g, fail
    return micro_maxent_production_net_flux_diff_energy_barrier
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_micro_maxent_production_net_flux_diff_energy_barrier_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')
algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4809d46d41bf> in <module>()
#      55                                         variable_group, constraint_group,
#      56                                         obj=make_micro_maxent_production_net_flux_diff_energy_barrier_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
# ---> 57                                         biomass_rxn='R_8')
#      58 algorithm = obj
#      59 mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
#
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.pyc in run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, variable_group, constraint_group, obj, biomass_rxn, R, T)
#     464         mentos.addConGroup(name=cg['name'], ncons=cg['ncons'], type=cg['type'] )
#     465     opt = pyOpt.PSQP()
# --> 466     f_star, x_star, message = opt(mentos, sens_type='FD', disp_opts=True, sens_mode='')
#     467     log_c = x_star[:m]
#     468     forward_rate = np.abs(x_star[m:m+n])
#
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/pyOpt/pyOpt_optimizer.pyc in __call__(self, opt_problem, *args, **kwargs)
#     158
#     159         # Solve Optimization Problem
# --> 160         return self.__solve__(opt_problem, *args, **kwargs)
#     161
#     162
#
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/pyOpt/pyPSQP/pyPSQP.pyc in __solve__(self, opt_problem, sens_type, store_sol, store_hst, hot_start, disp_opts, sens_mode, sens_step, *args, **kwargs)
#     485 		psqp.psqp_wrap(nf,nc,xx,xi,xl,xu,gg,gi,gl,gu,mit,mfv,
#     486                         met,mec,xmax,tolx,tolc,tolg,rpf,ff,gmax,cmax,
# --> 487 			iprint,iout,ifile,iterm,pobj,pdobj,pcon,pdcon)
#     488                 sol_time = time.time() - t0
#     489
#
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/pyOpt/pyPSQP/pyPSQP.pyc in pobj(n, x, f)
#     323
#     324                         if ((self.stored_data['x'] != x).any()):
# --> 325                                 eval(x)
#     326                         #end
#     327
#
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/pyOpt/pyPSQP/pyPSQP.pyc in eval(x)
#     236                                 [f,g,fail] = Bcast([f,g,fail],root=0)
#     237                         elif not self.h_start:
# --> 238                                 [f,g,fail] = opt_problem.obj_fun(xn, *args, **kwargs)
#     239                         #end
#     240
#
# <ipython-input-5-4809d46d41bf> in micro_maxent_production_net_flux_diff_energy_barrier(x)
#      32                               log_c[D_ext] - np.log(c_L),
#      33                               log_c[F_ext] - np.log(c_L)],
# ---> 34                              [-mu[A] + mu[D_ext] + mu[F_ext],           # Energy sink constraint
#      35                               -mu[B] + mu[D_ext] + mu[F_ext],
#      36                               -mu[C] + mu[D_ext] + mu[F_ext],
#
# NameError: global name 'A' is not defined

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')

reaction_data = reactions[obj]['Net flux'].to_dict()
metabolite_data = metab[obj]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="cetlvqertk"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({ paths: { d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                                      escher: '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min' }
#            });
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            });
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"cetlvqertk"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": -0.0063995106383458733, "R_9": 0.001332505235041026, "R_1": -0.044796862881057109, "R_2": -0.00039975828030947014, "R_3": -0.0013971235894132406, "R_4": -1.6820850305521162e-05, "R_5": 0.041608015075325966, "R_6": -0.00056347668305534171, "R_7": -0.0062810056269029246}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -49.070422025657471, "C": -32.176454121861816, "B": -60.613521871220911, "E": -28.031065767761962, "D": -44.077038336138322, "F": -84.458146737394628, "F_ext": -44.664159539297799, "A_ext": -13.123159450704872, "D_ext": -45.636265140243829, "E_ext": -15.368106736502504}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447894321204}}}},"27":{"name":"","bigg_id":"R_8","reversibil

# %% [markdown]
# ## Maximize microscopic entropy production net flux for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf r}_+,\vec{\bf r}_-, \vec{\bf c}}{\mbox{maximize}}   & -\sum_j{\mathscr P}_{+j}\log({\mathscr P}_{+j})v_{j} - \sum_j{\mathscr P}_{-j}\log({\mathscr P}_{-j})v_{j}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf a} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#     \end{array} $$
# Where
#
#
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# *  $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
#
# Decision variables are emphasized in **bold**.

# %% [markdown]
# ### PyOpt optimization

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U

obj = 'micro_maxent_production_net_flux'
convex_mentos = 'convex_mentos_likelihoods_first_elmo'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_micro_maxent_production_net_flux_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def micro_maxent_production_net_flux(x):
        """Maximize product of microscopic entropy production and net_flux of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum( np.log(forward_probability)*forward_probability*net_flux
                    + np.log(backward_probability)*backward_probability*net_flux)
        g = np.concatenate((np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return micro_maxent_production_net_flux
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_micro_maxent_production_net_flux_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')


algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
#                                        A        B        C        D         E  \
# Counts                          1.09e+05 1.75e+04  6.7e+05 2.55e+05  3.27e+05
# Concentrations                  0.000181 2.91e-05  0.00111 0.000423  0.000542
# Log Concentrations                 -8.62    -10.4     -6.8    -7.77     -7.52
# Standard Chemical potential            0       -2       -2       -4        -2
# Chemical potential                 -21.4    -27.9    -18.9    -23.3     -20.6
# Normalized Concentrations         0.0422  0.00681     0.26   0.0989     0.127
# Absolute activities             5.25e-10 7.73e-13 6.44e-09 7.96e-11  1.09e-09
# Normalized absolute activities    0.0107 1.58e-05    0.132  0.00162    0.0222
# Entropy                           0.0486 0.000174    0.267   0.0104    0.0844
# Entropy of Concentrations          0.134    0.034     0.35    0.229     0.262
# fullS*forward_rate             -7.84e+07 -3.3e+09 1.78e+09 5.49e+06 -8.28e+03
# fullS*backward_rate            -7.84e+07 -3.3e+09 1.78e+09 5.49e+06 -8.28e+03
# fullS*net_flux                     0.648   -0.992     1.51     1.63    0.0267
# fullS*net_likelihood           -4.54e-05  1.4e-09 4.47e-05     2.15   2.1e-08
# fullS*net_probabilities         -2.4e-06 7.41e-11 2.36e-06    0.114  1.11e-09
#
#                                        F     A_ext    D_ext     E_ext    F_ext
# Counts                                 6  5.98e+05        6  6.02e+05        6
# Concentrations                  1.01e-08  0.000993 9.99e-09  0.000999 1.02e-08
# Log Concentrations                 -18.4     -6.91    -18.4     -6.91    -18.4
# Standard Chemical potential          -10         0       -4        -2      -10
# Chemical potential                 -55.6     -17.1    -49.7     -19.1    -55.6
# Normalized Concentrations       2.36e-06     0.232 2.33e-06     0.233 2.39e-06
# Absolute activities             6.83e-25  3.59e-08 2.69e-22  4.94e-09 7.11e-25
# Normalized absolute activities   1.4e-17     0.733 5.49e-15     0.101 1.45e-17
# Entropy                         5.41e-16     0.228  1.8e-13     0.231 5.62e-16
# Entropy of Concentrations       3.05e-05     0.339 3.03e-05      0.34  3.1e-05
# fullS*forward_rate              1.74e+09 -1.87e+08    0.961 -2.54e+06 4.19e+07
# fullS*backward_rate             1.74e+09 -1.87e+08     2.44 -2.54e+06 4.19e+07
# fullS*net_flux                     0.207        -2    -1.48   -0.0267    0.483
# fullS*net_likelihood           -2.23e-08 -2.15e-08    -2.15  -2.1e-08 2.31e-08
# fullS*net_probabilities        -1.18e-09 -1.13e-09   -0.114 -1.11e-09 1.22e-09
#                                                          R_1       R_2  \
# Forward likelihoods                                        1         1
# Backward likelihoods                                       1         1
# Delta G                                                -4.23     -6.52
# log Q_r                                                 -1.7     -1.82
# log K_eq                                                  -0     0.807
# Delta G0                                                   0        -2
# logK - logQ                                              1.7      2.63
# logQ - logK                                             -1.7     -2.63
# Forward Log likelihoods                             1.07e-08  1.47e-09
# Backward Log likelihoods                           -1.07e-08 -1.47e-09
# Forward probabilities                                 0.0528    0.0528
# Backward probabilities                                0.0528    0.0528
# Net probabilities                                   1.13e-09  1.55e-10
# Net likelihoods                                     2.15e-08  2.94e-09
# Forward rate                                        1.87e+08  2.65e+08
# Backward rate                                       1.87e+08  2.65e+08
# Thermodynamic driving force                             4.23      6.52
# Net flux                                                   2     0.389
# Forward Entropy Production                             0.155     0.155
# Backward Entropy Production                            0.155     0.155
# Reaction Entropy Production                            0.311     0.311
# Net Reaction Entropy Production                      2.2e-09  3.01e-10
# Microscopic Reaction Entropy Production Rate         5.8e+07  8.23e+07
# Microscopic Reaction Entropy Production Net Flux       0.622     0.121
# Microscopic Reaction Entropy Production Net Flu...   4.4e-09  1.17e-10
# Total Entropy Production                                2.84      2.84
# Total Microscopic Entropy Production Rate              0.941     0.941
# Macroscopic Reaction Entropy Production Net Flux       -0.46     -0.46
# Macroscopic Reaction Entropy Production Net Flu... -3.26e-09 -4.46e-10
# Total Macroscopic Entropy Production Net Flux           -4.2      -4.2
# Total Macroscopic Entropy Production Net Flux D...      0.28      0.28
#
#                                                          R_3       R_4  \
# Forward likelihoods                                        1         1
# Backward likelihoods                                       1         1
# Delta G                                                 2.51      2.02
# log Q_r                                                 1.82      2.43
# log K_eq                                               0.807      1.61
# Delta G0                                                  -2        -4
# logK - logQ                                            -1.01    -0.816
# logQ - logK                                             1.01     0.816
# Forward Log likelihoods                             2.27e-05 -7.62e-12
# Backward Log likelihoods                           -2.27e-05  7.62e-12
# Forward probabilities                                 0.0528    0.0528
# Backward probabilities                                0.0528    0.0528
# Net probabilities                                    2.4e-06 -8.05e-13
# Net likelihoods                                     4.54e-05 -1.52e-11
# Forward rate                                        4.25e+04  2.54e+06
# Backward rate                                       4.25e+04  2.54e+06
# Thermodynamic driving force                            -2.51     -2.02
# Net flux                                               0.964 -1.94e-05
# Forward Entropy Production                             0.155     0.155
# Backward Entropy Production                            0.155     0.155
# Reaction Entropy Production                            0.311     0.311
# Net Reaction Entropy Production                     4.65e-06 -1.56e-12
# Microscopic Reaction Entropy Production Rate        1.32e+04   7.9e+05
# Microscopic Reaction Entropy Production Net Flux       0.299 -6.02e-06
# Microscopic Reaction Entropy Production Net Flu...  4.49e-06  3.03e-17
# Total Entropy Production                                2.84      2.84
# Total Microscopic Entropy Production Rate              0.941     0.941
# Macroscopic Reaction Entropy Production Net Flux       -0.46     -0.46
# Macroscopic Reaction Entropy Production Net Flu...  -6.9e-06  2.32e-12
# Total Macroscopic Entropy Production Net Flux           -4.2      -4.2
# Total Macroscopic Entropy Production Net Flux D...      0.28      0.28
#
#                                                          R_5       R_6  \
# Forward likelihoods                                        1         1
# Backward likelihoods                                       1         1
# Delta G                                                -1.51     -18.7
# log Q_r                                               -0.611     -4.33
# log K_eq                                                  -0      3.23
# Delta G0                                                   0        -8
# logK - logQ                                            0.611      7.55
# logQ - logK                                           -0.611     -7.55
# Forward Log likelihoods                             1.05e-08  3.87e-10
# Backward Log likelihoods                           -1.05e-08 -3.87e-10
# Forward probabilities                                 0.0528    0.0528
# Backward probabilities                                0.0528    0.0528
# Net probabilities                                   1.11e-09  4.09e-11
# Net likelihoods                                      2.1e-08  7.74e-10
# Forward rate                                        2.54e+06  1.78e+09
# Backward rate                                       2.54e+06  1.78e+09
# Thermodynamic driving force                             1.51      18.7
# Net flux                                              0.0267      0.69
# Forward Entropy Production                             0.155     0.155
# Backward Entropy Production                            0.155     0.155
# Reaction Entropy Production                            0.311     0.311
# Net Reaction Entropy Production                     2.16e-09  7.94e-11
# Microscopic Reaction Entropy Production Rate        7.88e+05  5.54e+08
# Microscopic Reaction Entropy Production Net Flux     0.00828     0.214
# Microscopic Reaction Entropy Production Net Flu...  5.75e-11  5.48e-11
# Total Entropy Production                                2.84      2.84
# Total Microscopic Entropy Production Rate              0.941     0.941
# Macroscopic Reaction Entropy Production Net Flux       -0.46     -0.46
# Macroscopic Reaction Entropy Production Net Flu...  -3.2e-09 -1.18e-10
# Total Macroscopic Entropy Production Net Flux           -4.2      -4.2
# Total Macroscopic Entropy Production Net Flux D...      0.28      0.28
#
#                                                          R_7    R_8       R_9
# Forward likelihoods                                        1  0.393         1
# Backward likelihoods                                       1   2.54         1
# Delta G                                                -4.39  -26.4     0.039
# log Q_r                                               -0.966  -10.7    0.0157
# log K_eq                                               0.807     -0        -0
# Delta G0                                                  -2      0         0
# logK - logQ                                             1.77   10.7   -0.0157
# logQ - logK                                            -1.77  -10.7    0.0157
# Forward Log likelihoods                             3.71e-07 -0.933  1.15e-08
# Backward Log likelihoods                           -3.71e-07  0.933 -1.15e-08
# Forward probabilities                                 0.0528 0.0208    0.0528
# Backward probabilities                                0.0528  0.134    0.0528
# Net probabilities                                   3.92e-08 -0.114  1.22e-09
# Net likelihoods                                     7.42e-07  -2.15  2.31e-08
# Forward rate                                        3.96e+05  0.961  4.19e+07
# Backward rate                                       3.96e+05   2.44  4.19e+07
# Thermodynamic driving force                             4.39   26.4    -0.039
# Net flux                                               0.147  -1.48     0.483
# Forward Entropy Production                             0.155 0.0805     0.155
# Backward Entropy Production                            0.155   0.27     0.155
# Reaction Entropy Production                            0.311   0.35     0.311
# Net Reaction Entropy Production                     7.61e-08 -0.189  2.37e-09
# Microscopic Reaction Entropy Production Rate        1.23e+05  0.736   1.3e+07
# Microscopic Reaction Entropy Production Net Flux      0.0456 -0.519      0.15
# Microscopic Reaction Entropy Production Net Flu...  1.12e-08   0.28  1.14e-09
# Total Entropy Production                                2.84   2.84      2.84
# Total Microscopic Entropy Production Rate              0.941  0.941     0.941
# Macroscopic Reaction Entropy Production Net Flux       -0.46 -0.519     -0.46
# Macroscopic Reaction Entropy Production Net Flu... -1.13e-07   0.28 -3.51e-09
# Total Macroscopic Entropy Production Net Flux           -4.2   -4.2      -4.2
# Total Macroscopic Entropy Production Net Flux D...      0.28   0.28      0.28

# %% [markdown]
# ### Scipy Optimization

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U
import mentos
import scipy
from scipy.stats import entropy
from IPython.display import Latex, Markdown, display
obj = 'micro_maxent_production_rate_scipy_optimize'
initial_value = 'convex_mentos_likelihoods_first_elmo'

modeldir = 'Boltzmann-2017-09-09/Models/ABC_model/'
#abc_model = cobra.io.read_json_model(os.path.join(modeldir,'abc_model.json'))
#noext = [r.id for r in core_model.reactions if 'EX_' not in r.id]

#fullS = pd.DataFrame(cobra.util.array.create_stoichiometric_matrix(core_model), 
#                    index=[m.id for m in core_model.metabolites],
#                    columns = [r.id for r in core_model.reactions])[noext]
mets, rxns = fullS.index, fullS.columns
m,n = fullS.shape
internal_mets = [m for m in mets if '_e' not in m]
#display(HTML(fullS.to_html()))
m,n = fullS.shape
rxns, mets = fullS.columns, fullS.index
S = fullS.loc[internal_mets].as_matrix()
i,n = S.shape
biomass_rxn =  "R_8"
biomass = rxns.get_loc(biomass_rxn)
#met_bounds = getMetBounds(fullS, reactions[initial_value]['Net flux'], c_L, c_U, m9_medium, ext=r'_ext')
#external_free_energy = fullS.T[external_mets].dot(mu_ext).sum() #dot(fluxes)
met_lb = np.log(1e-8)#set_log_conc( met_bounds, set_log_conc(  ecoli_comp_abs_conc.loc[fitted_mets,'L.B.'], pd.Series(np.log(c_L),index=mets) )).values
met_ub = np.log(1e-2)# set_log_conc( met_bounds, set_log_conc(  ecoli_comp_abs_conc.loc[fitted_mets,'U.B.'], pd.Series(np.log(c_U),index=mets ))).values

#rxnbounds = get_rxn_bounds( core_model )
#rxnbounds.loc['GLCpts', 'upper'] = 1

#lower,upper = rxnbounds.loc[rxns, 'lower'].values, rxnbounds.loc[rxns,'upper'].astype(float).values


def make_micro_maxent_production_rate_objective(initial_log_c, initial_forward_rate, initial_backward_rate,fullS, S, mu0, deltaG0, R, T, log_c_L, log_c_U,v_L, v_U, external_free_energy, met_bounds,biomass):

    def check_constraints( x0, constraints,rxns, mets ):
        internal_mets = [m for m in mets if '_e' not in m]
        for constraint in constraints: 
            constraint_eval = constraint['fun'](x0)
            if constraint['type'] == 'eq':
                if np.allclose(constraint_eval, 0):
                    display(Latex('{}'.format(constraint['fun'].__doc__)))
                    if 'jac' in constraint:
                        display(Latex('{}'.format(constraint['jac'].__doc__)))
                else:
                    display('{} violated'.format(constraint['fun'].__name__))
                    if len(constraint_eval) == len(internal_mets):
                        constraint_s = pd.Series(constraint_eval,index=internal_mets)
                        
                        display(constraint_s[~constraint_s.apply(lambda x: np.isclose(x,0))].to_frame(constraint['fun'].__doc__))
                    elif len(constraint_eval) == len(rxns):
                        display(pd.DataFrame(constraint_eval, index=rxns))
                    
            elif constraint['type'] == 'ineq':
                if np.all(constraint_eval >= 0):
                    display(Latex('{}'.format(constraint['fun'].__doc__)))
                else:
                    display('{} violated'.format(constraint['fun'].__name__))
                    if len(constraint_eval) == len(rxns):
                        display(pd.DataFrame(constraint_eval,index=rxns))

            
                    
                
                
                
            
    def make_logc_bounds(mets, met_bounds,epsilon=1):
        logc_bounds = []
        for met in mets:
            if met in met_bounds:
                logc_bounds.append((met_bounds[met]- epsilon, met_bounds[met]))
            else:
                logc_bounds.append((log_c_L, log_c_U))
        return logc_bounds
    def make_rate_bounds( rxns, r_L=0, r_U=None):
        return [(r_L, r_U) for rxn in rxns]
                
    def micro_entropy_production_rate(x):
        """Maximize product of  entropy production difference and microscopic biomass growth rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum(forward_probability*np.log(forward_probability)*net_flux + backward_probability*np.log(backward_probability)*net_flux)
        return -f
    def steady_state_constraint(x):
        """$$S\cdot v = 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.dot(S,net_flux)
    def thermodynamic_constraint(x):
        """$$\log r_+ - \log r_- = \log K - \log Q$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K
    def energy_barrier_constraint( x ):
        """$$ \|\Delta G_{ext}\| - S^T\mu \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return   np.abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu)
    def energy_sink_constraint( x ):
        """$$S^T\mu + \|\Delta G_{ext}\| \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return  np.dot(fullS.T.as_matrix(),mu) + np.abs(external_free_energy) 
    def second_law_constraint( x ):
        """$$\log L_+ \geq 0 \iff v \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.log(forward_likelihood)*net_flux
    def flux_upper_constraint( x ):
        """$$ v_U - r_+ + r_- \geq 0 $$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return v_U - forward_rate + backward_rate
    def flux_lower_constraint( x ):
        """$$ r_+ - r_- - v_L \geq 0  $$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return  forward_rate - backward_rate - v_L
    x0 = np.concatenate((initial_log_c.values,
                         initial_forward_rate.values,
                         initial_backward_rate.values))
    constraints = [dict(type='eq',  fun=steady_state_constraint),
                   dict(type='eq',  fun=thermodynamic_constraint),
                   dict(type='ineq',fun=energy_barrier_constraint),
                   dict(type='ineq',fun=energy_sink_constraint),
                   dict(type='ineq',fun=second_law_constraint),
                   dict(type='ineq',fun=flux_upper_constraint),
                   dict(type='ineq',fun=flux_lower_constraint)
]
                
    bounds = np.concatenate((make_logc_bounds(mets, met_bounds),
                             make_rate_bounds( rxns ),
                             make_rate_bounds( rxns )))
    check_constraints(x0, constraints, rxns, mets)
    mentos_result = scipy.optimize.minimize( fun=micro_entropy_production_rate,
                                            x0=x0,
                                            method='SLSQP',
                                            bounds=bounds,
                                            constraints=constraints,
                                            options=dict(disp=True))
    x_star = mentos_result.x
    log_c = x_star[:m]
    forward_rate = x_star[m:m+n]
    backward_rate = x_star[m+n:m+2*n]
    log_Q = np.dot(fullS.T,log_c)   # log of the Reaction quotient
    log_K = -1.0/(R*T)*deltaG0.as_matrix() 
    
    return mentos.generate_metabolite_report(log_c, forward_rate, backward_rate, S, mets, internal_mets, rxns, fullS, mu0), \
           mentos.generate_rxn_report(mets, log_c, log_Q, log_K,forward_rate, 
                                                backward_rate, rxns, deltaG0, biomass_rxn), mentos_result
metab[obj], reactions[obj], mentos_result = make_micro_maxent_production_rate_objective( 
                                metab[initial_value]['Log Concentrations'],
                                reactions[initial_value]['Forward rate'],
                                reactions[initial_value]['Backward rate'],
                                fullS, S, mu0[mets], deltaG0[rxns], R, T, 
                                met_lb, met_ub, v_L, v_U, external_free_energy, met_bounds, biomass)

if mentos_result.success:
        print("Success!")
else:
        print(mentos_result.message)
        print(mentos_result.keys())
display(HTML(metab[obj].T.to_html()))
                           
display(HTML(reactions[obj].T.to_html()))
algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])
# Out:
# $$S\cdot v = 0$$
# $$\log r_+ - \log r_- = \log K - \log Q$$
# $$ \|\Delta G_{ext}\| - S^T\mu \geq 0$$
# $$S^T\mu + \|\Delta G_{ext}\| \geq 0$$
# $$\log L_+ \geq 0 \iff v \geq 0$$
# $$ v_U - r_+ + r_- \geq 0 $$
# $$ r_+ - r_- - v_L \geq 0  $$
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.py:229 RuntimeWarning: divide by zero encountered in divide
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.py:232 RuntimeWarning: invalid value encountered in divide
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:85 RuntimeWarning: divide by zero encountered in log
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:85 RuntimeWarning: invalid value encountered in multiply
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:94 RuntimeWarning: divide by zero encountered in log
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.py:229 RuntimeWarning: invalid value encountered in divide
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.py:230 RuntimeWarning: invalid value encountered in divide
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:94 RuntimeWarning: invalid value encountered in subtract
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.py:230 RuntimeWarning: divide by zero encountered in divide
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.py:234 RuntimeWarning: divide by zero encountered in log
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/mentos/mentos.py:235 RuntimeWarning: divide by zero encountered in power
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:106 RuntimeWarning: divide by zero encountered in log
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: -3.07022519994
#             Iterations: 101
#             Function evaluations: 3438
#             Gradient evaluations: 101
# Iteration limit exceeded
# ['status', 'success', 'njev', 'nfev', 'fun', 'x', 'message', 'jac', 'nit']
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th>A_ext</th>
#       <th>D_ext</th>
#       <th>E_ext</th>
#       <th>F_ext</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Counts</th>
#       <td>4.23e+06</td>
#       <td>8.74e+03</td>
#       <td>3.95e+05</td>
#       <td>2.39e+06</td>
#       <td>6.02e+06</td>
#       <td>6.02e+06</td>
#       <td>2.51e+08</td>
#       <td>2.22e+08</td>
#       <td>2.22e+08</td>
#       <td>2.22e+08</td>
#     </tr>
#     <tr>
#       <th>Concentrations</th>
#       <td>0.00703</td>
#       <td>1.45e-05</td>
#       <td>0.000656</td>
#       <td>0.00397</td>
#       <td>0.01</td>
#       <td>0.01</td>
#       <td>0.417</td>
#       <td>0.368</td>
#       <td>0.368</td>
#       <td>0.368</td>
#     </tr>
#     <tr>
#       <th>Log Concentrations</th>
#       <td>-4.96</td>
#       <td>-11.1</td>
#       <td>-7.33</td>
#       <td>-5.53</td>
#       <td>-4.61</td>
#       <td>-4.61</td>
#       <td>-0.874</td>
#       <td>-1</td>
#       <td>-0.999</td>
#       <td>-1</td>
#     </tr>
#     <tr>
#       <th>Standard Chemical potential</th>
#       <td>0</td>
#       <td>-2</td>
#       <td>-2</td>
#       <td>-4</td>
#       <td>-2</td>
#       <td>-10</td>
#       <td>0</td>
#       <td>-4</td>
#       <td>-2</td>
#       <td>-10</td>
#     </tr>
#     <tr>
#       <th>
td>
#     </tr>
#     <tr>
#       <th>Microscopic Reaction Entropy Production Rate</th>
#       <td>1.4</td>
#       <td>1.67</td>
#       <td>6.97e-08</td>
#       <td>4.77e-09</td>
#       <td>0.00217</td>
#       <td>1.06e-08</td>
#       <td>5.19e-09</td>
#       <td>4.04e-08</td>
#       <td>3.39e-08</td>
#     </tr>
#     <tr>
#       <th>Microscopic Reaction Entropy Production Net Flux</th>
#       <td>1.4</td>
#       <td>1.67</td>
#       <td>6.95e-08</td>
#       <td>2.86e-09</td>
#       <td>0.00217</td>
#       <td>-1.07e-11</td>
#       <td>5.47e-10</td>
#       <td>3.83e-08</td>
#       <td>-1.07e-11</td>
#     </tr>
#     <tr>
#       <th>Microscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>1.4</td>
#       <td>1.67</td>
#       <td>6.95e-08</td>
#       <td>1.8e-09</td>
#       <td>0.00217</td>
#       <td>1.03e-14</td>
#       <td>5.57e-11</td>
#       <td>3.79e-08</td>
#       <td>3.23e-15</td>
#     </tr>
#     <tr>
#       <th>Total Entropy Production</th>
#       <td>0.596</td>
#       <td>0.596</td>
#       <td>0.596</td>
#       <td>0.596</td>
#       <td>0.596</td>
#       <td>0.596</td>
#       <td>0.596</td>
#       <td>0.596</td>
#       <td>0.596</td>
#     </tr>
#     <tr>
#       <th>Total Microscopic Entropy Production Rate</th>
#       <td>3.07</td>
#       <td>3.07</td>
#       <td>3.07</td>
#       <td>3.07</td>
#       <td>3.07</td>
#       <td>3.07</td>
#       <td>3.07</td>
#       <td>3.07</td>
#       <td>3.07</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux</th>
#       <td>2.5</td>
#       <td>3.74</td>
#       <td>6.15e-07</td>
#       <td>6.34e-09</td>
#       <td>0.00481</td>
#       <td>4.91e-09</td>
#       <td>4.94e-09</td>
#       <td>3.83e-08</td>
#       <td>4.91e-09</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>2.5</td>
#       <td>3.74</td>
#       <td>6.15e-07</td>
#       <td>4e-09</td>
#       <td>0.00481</td>
#       <td>-4.73e-12</td>
#       <td>5.02e-10</td>
#       <td>3.79e-08</td>
#       <td>-1.49e-12</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux</th>
#       <td>6.25</td>
#       <td>6.25</td>
#       <td>6.25</td>
#       <td>6.25</td>
#       <td>6.25</td>
#       <td>6.25</td>
#       <td>6.25</td>
#       <td>6.25</td>
#       <td>6.25</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')

reaction_data = reactions[obj]['Net flux'].to_dict()
metabolite_data = metab[obj]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="bslgefvnte"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', '//unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"bslgefvnte"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": 112.18734416562428, "R_9": 4.175951076133604, "R_1": 66.10652941739326, "R_2": 58.60866797663536, "R_3": 7.497861440758116, "R_4": 50.256765824366376, "R_5": 50.25676582436638, "R_6": 4.175951076133402, "R_7": 11.67381251689153}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -23.47620533368865, "C": -28.11550519251473, "B": -33.52508321112846, "E": -24.784630828312917, "D": -33.98516108213417, "F": -41.799360699855974, "F_ext": -44.66406054262949, "A_ext": -13.124022703486059, "D_ext": -45.66406054262949, "E_ext": -15.124022703486059}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447

# %% [markdown]
# ## Maximize microscopic entropy production rate for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf r}_+,\vec{\bf r}_-,\vec{\bf c}}{\mbox{maximize}}   & -\sum_j{\mathscr P}_{+j}\log({\mathscr P}_{+j})r_{+j} - \sum_j{\mathscr P}_{-j}\log({\mathscr P}_{-j})r_{-j}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#       & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array}
# $$
#
# Where
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
# Decision variables are emphasized in **bold**.

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U

obj = 'micro_maxent_production_rate'
convex_mentos = 'convex_mentos_external_free_energy_constraint'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_micro_maxent_production_rate_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def micro_maxent_production_rate(x):
        """Maximize product of microscopic entropy production and rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum( np.log(forward_probability)*forward_probability*forward_rate \
                   + np.log(backward_probability)*backward_probability*backward_rate)
        g = np.concatenate((np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return micro_maxent_production_rate
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_micro_maxent_production_rate_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')

display(metab[obj].T)
algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])
                      
display(reactions[obj].T)
# Out:
#                                     A        B        C        D        E  \
# Counts                        3.1e+04      252 1.58e+04      416  1.1e+04
# Concentrations               5.15e-05 4.19e-07 2.62e-05 6.91e-07 1.82e-05
# Log Concentrations              -9.87    -14.7    -10.6    -14.2    -10.9
# Standard Chemical potential         4        2        2        0        2
# Chemical potential              -20.5    -34.4    -24.2    -35.2    -25.1
# S*forward_rate                  0.429     -1.6     1.28   -0.124   -0.199
# S*backward_rate                 0.429     -1.6     1.28   -0.124   0.0148
# S*net_flux                  -8.45e-08 1.35e-11 6.31e-09 2.64e-07   -0.214
#
#                                    F    A_ext  D_ext    E_ext  F_ext
# Counts                             6 6.02e+05      6 6.02e+05      6
# Concentrations                 1e-08    0.001  1e-08    0.001  1e-08
# Log Concentrations             -18.4    -6.91  -18.4    -6.91  -18.4
# Standard Chemical potential        1        4      0        2      1
# Chemical potential             -44.7    -13.1  -45.7    -15.1  -44.7
# S*forward_rate                 -1.36      nan    nan      nan    nan
# S*backward_rate                -1.36      nan    nan      nan    nan
# S*net_flux                  1.31e-11      nan    nan      nan    nan
#                                                         R_1      R_2  \
# Forward likelihoods                                    13.5      227
# Backward likelihoods                                 0.0743  0.00441
# Delta G                                               -7.35    -13.9
# log Q_r                                               -2.97    -4.81
# log K_eq                                                 -0    0.807
# Delta G0                                                  0       -2
# logK - logQ                                            2.97     5.62
# logQ - logK                                           -2.97    -5.62
# Forward Log likelihoods                                 2.6     5.42
# Backward Log likelihoods                               -2.6    -5.42
# Forward probabilities                                0.0232    0.391
# Backward probabilities                             0.000128 7.61e-06
# Net probabilities                                    0.0231    0.391
# Net likelihoods                                        13.4      227
# Forward rate                                           13.6     12.7
# Backward rate                                          1.01    0.056
# Thermodynamic driving force                            13.5      227
# Net flux                                               12.6     12.6
# Forward Entropy Production                           0.0874    0.367
# Backward Entropy Production                         0.00115 8.97e-05
# Reaction Entropy Production                          0.0885    0.367
# Microscopic Reaction Entropy Production Rate           1.19     4.66
# Microscopic Reaction Entropy Production Net Flux       1.12     4.64
# Microscopic Reaction Entropy Production Net Flu...     1.09     4.64
# Total Entropy Production                               1.48     1.48
# Total Microscopic Entropy Production Rate              20.8     20.8
# Macroscopic Reaction Entropy Production Net Flux       2.24     9.28
# Macroscopic Reaction Entropy Production Net Flu...     2.18     9.28
# Total Macroscopic Entropy Production Net Flux          37.3     37.3
# Total Macroscopic Entropy Production Net Flux D...       35       35
#
#                                                          R_3      R_4  \
# Forward likelihoods                                        1      138
# Backward likelihoods                                       1  0.00725
# Delta G                                                -3.68    -10.9
# log Q_r                                               -0.678    -2.77
# log K_eq                                               0.807     1.61
# Delta G0                                                  -2       -4
# logK - logQ                                             1.48     4.38
# logQ - logK                                            -1.48    -4.38
# Forward Log likelihoods                             1.35e-08     4.93
# Backward Log likelihoods                           -1.35e-08    -4.93
# Forward probabilities                                0.00172    0.238
# Backward probabilities                               0.00172 1.25e-05
# Net probabilities                                   4.67e-11    0.238
# Net likelihoods                                     2.71e-08      138
# Forward rate                                           0.528     12.7
# Backward rate                                          0.528   0.0922
# Thermodynamic driving force                                1      138
# Net flux                                            7.15e-09     12.6
# Forward Entropy Production                             0.011    0.342
# Backward Entropy Production                            0.011 0.000141
# Reaction Entropy Production                           0.0219    0.342
# Microscopic Reaction Entropy Production Rate          0.0116     4.35
# Microscopic Reaction Entropy Production Net Flux    1.57e-10     4.32
# Microscopic Reaction Entropy Production Net Flu...  1.79e-18     4.31
# Total Entropy Production                                1.48     1.48
# Total Microscopic Entropy Production Rate               20.8     20.8
# Macroscopic Reaction Entropy Production Net Flux       0.555     8.64
# Macroscopic Reaction Entropy Production Net Flu...  6.33e-09     8.63
# Total Macroscopic Entropy Production Net Flux           37.3     37.3
# Total Macroscopic Entropy Production Net Flux D...        35       35
#
#                                                         R_5       R_6  \
# Forward likelihoods                                     117         1
# Backward likelihoods                                0.00854         1
# Delta G                                               -9.93  -0.00668
# log Q_r                                               -4.01     0.401
# log K_eq                                                 -0     0.403
# Delta G0                                                  0        -1
# logK - logQ                                            4.01    0.0027
# logQ - logK                                           -4.01   -0.0027
# Forward Log likelihoods                                4.76  6.38e-12
# Backward Log likelihoods                              -4.76 -6.38e-12
# Forward probabilities                                 0.202   0.00172
# Backward probabilities                             1.47e-05   0.00172
# Net probabilities                                     0.202   2.2e-14
# Net likelihoods                                         117  1.28e-11
# Forward rate                                           12.5     0.782
# Backward rate                                         0.107     0.782
# Thermodynamic driving force                             117         1
# Net flux                                               12.4  4.99e-12
# Forward Entropy Production                            0.323     0.011
# Backward Entropy Production                        0.000164     0.011
# Reaction Entropy Production                           0.323    0.0219
# Microscopic Reaction Entropy Production Rate           4.05    0.0172
# Microscopic Reaction Entropy Production Net Flux       4.01  1.09e-13
# Microscopic Reaction Entropy Production Net Flu...     4.01  5.89e-25
# Total Entropy Production                               1.48      1.48
# Total Microscopic Entropy Production Rate              20.8      20.8
# Macroscopic Reaction Entropy Production Net Flux       8.17     0.555
# Macroscopic Reaction Entropy Production Net Flu...     8.16  2.98e-12
# Total Macroscopic Entropy Production Net Flux          37.3      37.3
# Total Macroscopic Entropy Production Net Flux D...       35        35
#
#                                                          R_7      R_8  \
# Forward likelihoods                                        1     76.5
# Backward likelihoods                                       1   0.0131
# Delta G                                                  -11    -10.5
# log Q_r                                                -3.63    -4.24
# log K_eq                                               0.807       -0
# Delta G0                                                  -2        0
# logK - logQ                                             4.44     4.24
# logQ - logK                                            -4.44    -4.24
# Forward Log likelihoods                             3.22e-08     4.34
# Backward Log likelihoods                           -3.22e-08    -4.34
# Forward probabilities                                0.00172    0.132
# Backward probabilities                               0.00172 2.26e-05
# Net probabilities                                   1.11e-10    0.132
# Net likelihoods                                     6.45e-08     76.4
# Forward rate                                          0.0265     25.6
# Backward rate                                         0.0265    0.335
# Thermodynamic driving force                                1     76.5
# Net flux                                            8.54e-10     25.3
# Forward Entropy Production                             0.011    0.267
# Backward Entropy Production                            0.011 0.000241
# Reaction Entropy Production                           0.0219    0.267
# Microscopic Reaction Entropy Production Rate        0.000582     6.84
# Microscopic Reaction Entropy Production Net Flux    1.88e-11     6.76
# Microscopic Reaction Entropy Production Net Flu...  5.09e-19     6.74
# Total Entropy Production                                1.48     1.48
# Total Microscopic Entropy Production Rate               20.8     20.8
# Macroscopic Reaction Entropy Production Net Flux       0.555     6.76
# Macroscopic Reaction Entropy Production Net Flu...  1.51e-08     6.74
# Total Macroscopic Entropy Production Net Flux           37.3     37.3
# Total Macroscopic Entropy Production Net Flux D...        35       35
#
#                                                          R_9
# Forward likelihoods                                        1
# Backward likelihoods                                       1
# Delta G                                            -3.38e-11
# log Q_r                                            -1.36e-11
# log K_eq                                                  -0
# Delta G0                                                   0
# logK - logQ                                         1.36e-11
# logQ - logK                                        -1.36e-11
# Forward Log likelihoods                            -3.81e-12
# Backward Log likelihoods                            3.81e-12
# Forward probabilities                                0.00172
# Backward probabilities                               0.00172
# Net probabilities                                  -1.31e-14
# Net likelihoods                                    -7.61e-12
# Forward rate                                            2.14
# Backward rate                                           2.14
# Thermodynamic driving force                               -1
# Net flux                                           -8.14e-12
# Forward Entropy Production                             0.011
# Backward Entropy Production                            0.011
# Reaction Entropy Production                           0.0219
# Microscopic Reaction Entropy Production Rate           0.047
# Microscopic Reaction Entropy Production Net Flux   -1.79e-13
# Microscopic Reaction Entropy Production Net Flu...  5.73e-25
# Total Entropy Production                                1.48
# Total Microscopic Entropy Production Rate               20.8
# Macroscopic Reaction Entropy Production Net Flux       0.555
# Macroscopic Reaction Entropy Production Net Flu... -1.78e-12
# Total Macroscopic Entropy Production Net Flux           37.3
# Total Macroscopic Entropy Production Net Flux D...        35

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')

reaction_data = reactions[obj]['Net flux'].to_dict()
metabolite_data = metab[obj]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="kkzggfrtrl"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({ paths: { d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                                      escher: '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min' }
#            });
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            });
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"kkzggfrtrl"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": 25.268441585679028, "R_9": -8.1428197518107481e-12, "R_1": 12.634220846888471, "R_2": 12.634220924197439, "R_3": 7.1543689861286452e-09, "R_4": 12.634220924173965, "R_5": 12.420148656149907, "R_6": 4.9882320496408283e-12, "R_7": 8.5433242771881801e-10}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -20.475335453913324, "C": -24.155459927430734, "B": -34.406418898164063, "E": -25.05569388620939, "D": -35.164364632215445, "F": -44.664060542595685, "F_ext": -44.664060542629493, "A_ext": -13.124022703486066, "D_ext": -45.664060542629485, "E_ext": -15.124022703486087}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447894321204}}}},"27":{"name":"","bigg_id":"R_8","reversibility":false,"label_

# %% [markdown]
# ## Maximize macroscopic entropy production rate for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf r}_+,\vec{\bf r}_-,\vec{\bf c}}{\mbox{maximize}}   & - \sum_j\left({\mathscr P}_{+j}\log({\mathscr P}_{+j}) + {\mathscr P}_{-j}\log({\mathscr P}_{-j})\right)\cdot v_{growth}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#       & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array}
# $$
#
# Where
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
# Decision variables are emphasized in **bold**.

# %% [markdown]
# ### Scipy.optimize with scipy.stats.entropy

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U
import mentos
import scipy
from scipy.stats import entropy
from IPython.display import Latex, Markdown, display
obj = 'macro_maxent_production_rate_scipy_optimize_w_scipy_entropy'
initial_value = 'convex_mentos_likelihoods_first_elmo'

modeldir = 'Boltzmann-2017-09-09/Models/ABC_model/'
#abc_model = cobra.io.read_json_model(os.path.join(modeldir,'abc_model.json'))
#noext = [r.id for r in core_model.reactions if 'EX_' not in r.id]

#fullS = pd.DataFrame(cobra.util.array.create_stoichiometric_matrix(core_model), 
#                    index=[m.id for m in core_model.metabolites],
#                    columns = [r.id for r in core_model.reactions])[noext]
mets, rxns = fullS.index, fullS.columns
m,n = fullS.shape
internal_mets = [m for m in mets if '_e' not in m]
#display(HTML(fullS.to_html()))
m,n = fullS.shape
rxns, mets = fullS.columns, fullS.index
S = fullS.loc[internal_mets].as_matrix()
i,n = S.shape
biomass_rxn =  "R_8"
biomass = rxns.get_loc(biomass_rxn)
#met_bounds = getMetBounds(fullS, reactions[initial_value]['Net flux'], c_L, c_U, m9_medium, ext=r'_ext')
#external_free_energy = fullS.T[external_mets].dot(mu_ext).sum() #dot(fluxes)
met_lb = np.log(1e-8)#set_log_conc( met_bounds, set_log_conc(  ecoli_comp_abs_conc.loc[fitted_mets,'L.B.'], pd.Series(np.log(c_L),index=mets) )).values
met_ub = np.log(1e-2)# set_log_conc( met_bounds, set_log_conc(  ecoli_comp_abs_conc.loc[fitted_mets,'U.B.'], pd.Series(np.log(c_U),index=mets ))).values

#rxnbounds = get_rxn_bounds( core_model )
#rxnbounds.loc['GLCpts', 'upper'] = 1

#lower,upper = rxnbounds.loc[rxns, 'lower'].values, rxnbounds.loc[rxns,'upper'].astype(float).values


def make_macro_maxent_production_rate_objective(initial_log_c, initial_forward_rate, initial_backward_rate,fullS, S, mu0, deltaG0, R, T, log_c_L, log_c_U,v_L, v_U, external_free_energy, met_bounds,biomass):

    def check_constraints( x0, constraints,rxns, mets ):
        internal_mets = [m for m in mets if '_e' not in m]
        for constraint in constraints: 
            constraint_eval = constraint['fun'](x0)
            if constraint['type'] == 'eq':
                if np.allclose(constraint_eval, 0):
                    display(Latex('{}'.format(constraint['fun'].__doc__)))
                    if 'jac' in constraint:
                        display(Latex('{}'.format(constraint['jac'].__doc__)))
                else:
                    display('{} violated'.format(constraint['fun'].__name__))
                    if len(constraint_eval) == len(internal_mets):
                        constraint_s = pd.Series(constraint_eval,index=internal_mets)
                        
                        display(constraint_s[~constraint_s.apply(lambda x: np.isclose(x,0))].to_frame(constraint['fun'].__doc__))
                    elif len(constraint_eval) == len(rxns):
                        display(pd.DataFrame(constraint_eval, index=rxns))
                    
            elif constraint['type'] == 'ineq':
                if np.all(constraint_eval >= 0):
                    display(Latex('{}'.format(constraint['fun'].__doc__)))
                else:
                    display('{} violated'.format(constraint['fun'].__name__))
                    if len(constraint_eval) == len(rxns):
                        display(pd.DataFrame(constraint_eval,index=rxns))

            
                    
                
                
                
            
    def make_logc_bounds(mets, met_bounds,epsilon=1):
        logc_bounds = []
        for met in mets:
            if met in met_bounds:
                logc_bounds.append((met_bounds[met]- epsilon, met_bounds[met]))
            else:
                logc_bounds.append((log_c_L, log_c_U))
        return logc_bounds
    def make_rate_bounds( rxns, r_L=0, r_U=None):
        return [(r_L, r_U) for rxn in rxns]
                
    def macro_entropy_production_rate(x):
        """Maximize product of  entropy production difference and macroscopic biomass growth rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = entropy(np.concatenate( (forward_probability, backward_probability ) ) )*net_flux[biomass] #- 1000*np.sum(np.abs(slack))
        return -f
    def steady_state_constraint(x):
        """$$S\cdot v = 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.dot(S,net_flux)
    def thermodynamic_constraint(x):
        """$$\log r_+ - \log r_- = \log K - \log Q$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K
    def energy_barrier_constraint( x ):
        """$$ \|\Delta G_{ext}\| - S^T\mu \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return   np.abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu)
    def energy_sink_constraint( x ):
        """$$S^T\mu + \|\Delta G_{ext}\| \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return  np.dot(fullS.T.as_matrix(),mu) + np.abs(external_free_energy) 
    def second_law_constraint( x ):
        """$$\log L_+ \geq 0 \iff v \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.log(forward_likelihood)*net_flux
    def flux_upper_constraint( x ):
        """$$ v_U - r_+ + r_- \geq 0 $$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return v_U - forward_rate + backward_rate
    def flux_lower_constraint( x ):
        """$$ r_+ - r_- - v_L \geq 0  $$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return  forward_rate - backward_rate - v_L
    x0 = np.concatenate((initial_log_c.values,
                         initial_forward_rate.values,
                         initial_backward_rate.values))
    constraints = [dict(type='eq',  fun=steady_state_constraint),
                   dict(type='eq',  fun=thermodynamic_constraint),
                   dict(type='ineq',fun=energy_barrier_constraint),
                   dict(type='ineq',fun=energy_sink_constraint),
                   dict(type='ineq',fun=second_law_constraint),
                   dict(type='ineq',fun=flux_upper_constraint),
                   dict(type='ineq',fun=flux_lower_constraint)
]
                
    bounds = np.concatenate((make_logc_bounds(mets, met_bounds),
                             make_rate_bounds( rxns ),
                             make_rate_bounds( rxns )))
    check_constraints(x0, constraints, rxns, mets)
    mentos_result = scipy.optimize.minimize( fun=macro_entropy_production_rate,
                                            x0=x0,
                                            method='SLSQP',
                                            bounds=bounds,
                                            constraints=constraints,
                                            options=dict(disp=True))
    x_star = mentos_result.x
    log_c = x_star[:m]
    forward_rate = x_star[m:m+n]
    backward_rate = x_star[m+n:m+2*n]
    log_Q = np.dot(fullS.T,log_c)   # log of the Reaction quotient
    log_K = -1.0/(R*T)*deltaG0.as_matrix() 
    
    return mentos.generate_metabolite_report(log_c, forward_rate, backward_rate, S, mets, internal_mets,rxns, fullS, mu0), \
           mentos.generate_rxn_report(mets, log_c, log_Q, log_K,forward_rate, 
                                                backward_rate, rxns, deltaG0, biomass_rxn), mentos_result
metab[obj], reactions[obj], mentos_result = make_macro_maxent_production_rate_objective( 
                                metab[initial_value]['Log Concentrations'],
                                reactions[initial_value]['Forward rate'],
                                reactions[initial_value]['Backward rate'],
                                fullS, S, mu0[mets], deltaG0[rxns], R, T, 
                                met_lb, met_ub, v_L, v_U, external_free_energy, met_bounds, biomass)

if mentos_result.success:
        print("Success!")
else:
        print(mentos_result.message)
        print(mentos_result.keys())
display(HTML(metab[obj].T.to_html()))
                           
display(HTML(reactions[obj].T.to_html()))
algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])
# Out:
# $$S\cdot v = 0$$
# $$\log r_+ - \log r_- = \log K - \log Q$$
# $$ \|\Delta G_{ext}\| - S^T\mu \geq 0$$
# $$S^T\mu + \|\Delta G_{ext}\| \geq 0$$
# $$\log L_+ \geq 0 \iff v \geq 0$$
# $$ v_U - r_+ + r_- \geq 0 $$
# $$ r_+ - r_- - v_L \geq 0  $$
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py
td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>4.61e-05</td>
#       <td>8.05e-08</td>
#       <td>2.85e-05</td>
#       <td>-0.6</td>
#       <td>0.438</td>
#       <td>-5.96e-10</td>
#       <td>-1.24</td>
#       <td>8.03e-09</td>
#       <td>-0.254</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux</th>
#       <td>2.53</td>
#       <td>2.53</td>
#       <td>2.53</td>
#       <td>2.53</td>
#       <td>2.53</td>
#       <td>2.53</td>
#       <td>2.53</td>
#       <td>2.53</td>
#       <td>2.53</td>
#     </tr>
#     <tr>
#       <th>Total

# %% [markdown]
# ### PyOpt with scipy.stats.entropy

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U
from scipy.stats import entropy
obj = 'macro_maxent_production_rate_pyOpt_optimize_w_scipy_entropy'
convex_mentos = 'convex_mentos_likelihoods_first_elmo'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[#dict(name='steady_state_net_likelihood', ncons=i, type='e'),
                    dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_macro_maxent_production_rate_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def macro_maxent_production_rate(x):
        """Maximize product of  entropy production and macroscopic biomass growth rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = entropy( np.concatenate( ( forward_probability, backward_probability ) ) )*net_flux[biomass]
        g = np.concatenate((#np.dot(S,forward_likelihood - backward_likelihood),
                            np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return macro_maxent_production_rate
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_macro_maxent_production_rate_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')

algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
#                                       A         B        C        D        E  \
# Counts                         1.94e+04       114 4.37e+04      366  2.1e+04
# Concentrations                 3.23e-05   1.9e-07 7.26e-05 6.09e-07 3.48e-05
# Log Concentrations                -10.3     -15.5    -9.53    -14.3    -10.3
# Standard Chemical potential           0        -2       -2       -4       -2
# Chemical potential                -25.6     -40.4    -25.6    -39.5    -27.4
# Normalized Concentrations        0.0151   8.9e-05   0.0339 0.000285   0.0163
# Absolute activities            7.35e-12  2.97e-18 7.42e-12 7.17e-18  1.2e-12
# Normalized absolute activities 0.000177  7.14e-11 0.000179 1.73e-10 2.89e-05
# Entropy                         0.00153  1.67e-09  0.00154 3.88e-09 0.000302
# Entropy of Concentrations        0.0632   0.00083    0.115  0.00232    0.067
# fullS*forward_rate                -22.3     -1.48     23.9   -0.474     0.81
# fullS*backward_rate               -22.3     -1.48     23.9   -0.474     0.81
# fullS*net_flux                 8.73e-10 -2.98e-09 1.21e-09 1.14e-13  1.4e-10
# fullS*net_likelihood               -620       539     -462      626    -83.3
# fullS*net_probabilities          -0.461     0.401   -0.344    0.465  -0.0619
#
#                                        F    A_ext    D_ext    E_ext    F_ext
# Counts                                 6 6.02e+05        6 6.02e+05        6
# Concentrations                  1.04e-08    0.001    1e-08    0.001    1e-08
# Log Concentrations                 -18.4    -6.91    -18.4    -6.91    -18.4
# Standard Chemical potential          -10        0       -4       -2      -10
# Chemical potential                 -55.6    -17.1    -49.7    -19.1    -55.7
# Normalized Concentrations       4.85e-06    0.467 4.67e-06    0.467 4.67e-06
# Absolute activities             7.36e-25 3.66e-08  2.7e-22 4.95e-09 6.69e-25
# Normalized absolute activities  1.77e-17     0.88  6.5e-15    0.119 1.61e-17
# Entropy                         6.83e-16    0.112 2.12e-13    0.253 6.23e-16
# Entropy of Concentrations       5.94e-05    0.356 5.73e-05    0.356 5.73e-05
# fullS*forward_rate                 0.179    -29.4     57.7    -29.4    0.499
# fullS*backward_rate                0.179   -0.984     0.99    -1.07    0.452
# fullS*net_flux                   3.4e-10    -28.4     56.7    -28.3   0.0467
# fullS*net_likelihood             -0.0541    -29.8     58.2    -27.5    0.197
# fullS*net_probabilities        -4.02e-05  -0.0222   0.0433  -0.0204 0.000146
#                                                         R_1      R_2  \
# Forward likelihoods                                    29.9      650
# Backward likelihoods                                 0.0335  0.00154
# Delta G                                               -8.51    -14.7
# log Q_r                                               -3.43    -5.13
# log K_eq                                                 -0    0.807
# Delta G0                                                  0       -2
# logK - logQ                                            3.43     5.94
# logQ - logK                                           -3.43    -5.94
# Forward Log likelihoods                                 3.4     6.48
# Backward Log likelihoods                               -3.4    -6.48
# Forward probabilities                                0.0222    0.483
# Backward probabilities                             2.49e-05 1.14e-06
# Net probabilities                                    0.0222    0.483
# Net likelihoods                                        29.8      650
# Forward rate                                           29.4     28.5
# Backward rate                                         0.984   0.0438
# Thermodynamic driving force                            8.51     14.7
# Net flux                                               28.4     28.4
# Forward Entropy Production                           0.0845    0.351
# Backward Entropy Production                        0.000264 1.56e-05
# Reaction Entropy Production                          0.0848    0.351
# Net Reaction Entropy Production                      0.0843    0.351
# Microscopic Reaction Entropy Production Rate           2.49       10
# Microscopic Reaction Entropy Production Net Flux       2.41     9.98
# Microscopic Reaction Entropy Production Net Flu...     2.39     9.98
# Total Entropy Production                               1.26     1.26
# Total Microscopic Entropy Production Rate              28.2     28.2
# Macroscopic Reaction Entropy Production Net Flux       4.81     19.9
# Macroscopic Reaction Entropy Production Net Flu...     4.78     19.9
# Total Macroscopic Entropy Production Net Flux          71.3     71.3
# Total Macroscopic Entropy Production Net Flux D...     69.4     69.4
#
#                                                          R_3      R_4  \
# Forward likelihoods                                        1      111
# Backward likelihoods                                       1  0.00903
# Delta G                                              0.00955    -11.1
# log Q_r                                                0.811    -2.88
# log K_eq                                               0.807     1.61
# Delta G0                                                  -2       -4
# logK - logQ                                         -0.00385      4.5
# logQ - logK                                          0.00385     -4.5
# Forward Log likelihoods                            -0.000165     4.71
# Backward Log likelihoods                            0.000165    -4.71
# Forward probabilities                               0.000743   0.0824
# Backward probabilities                              0.000744 6.71e-06
# Net probabilities                                  -2.46e-07   0.0823
# Net likelihoods                                    -0.000331      111
# Forward rate                                            23.3     28.6
# Backward rate                                           23.3    0.258
# Thermodynamic driving force                         -0.00955     11.1
# Net flux                                            -0.00385     28.3
# Forward Entropy Production                           0.00536    0.206
# Backward Entropy Production                          0.00536    8e-05
# Reaction Entropy Production                           0.0107    0.206
# Net Reaction Entropy Production                    -1.53e-06    0.206
# Microscopic Reaction Entropy Production Rate           0.249     5.88
# Microscopic Reaction Entropy Production Net Flux   -4.12e-05     5.82
# Microscopic Reaction Entropy Production Net Flu...  5.87e-09     5.82
# Total Entropy Production                                1.26     1.26
# Total Microscopic Entropy Production Rate               28.2     28.2
# Macroscopic Reaction Entropy Production Net Flux       0.607     11.7
# Macroscopic Reaction Entropy Production Net Flu... -8.65e-05     11.6
# Total Macroscopic Entropy Production Net Flux           71.3     71.3
# Total Macroscopic Entropy Production Net Flux D...      69.4     69.4
#
#                                                         R_5      R_6      R_7  \
# Forward likelihoods                                    27.5     1.07      462
# Backward likelihoods                                 0.0363    0.931  0.00216
# Delta G                                               -8.32   -0.479    -13.8
# log Q_r                                               -3.36     3.03    -4.78
# log K_eq                                                 -0     3.23    0.807
# Delta G0                                                  0       -8       -2
# logK - logQ                                            3.36    0.193     5.59
# logQ - logK                                           -3.36   -0.193    -5.59
# Forward Log likelihoods                                3.31   0.0713     6.14
# Backward Log likelihoods                              -3.31  -0.0713    -6.14
# Forward probabilities                                0.0205 0.000799    0.344
# Backward probabilities                              2.7e-05 0.000692 1.61e-06
# Net probabilities                                    0.0204 0.000106    0.344
# Net likelihoods                                        27.5    0.143      462
# Forward rate                                           29.4    0.678   0.0429
# Backward rate                                          1.07    0.631 9.29e-05
# Thermodynamic driving force                            8.32    0.479     13.8
# Net flux                                               28.3   0.0467   0.0428
# Forward Entropy Production                           0.0796   0.0057    0.367
# Backward Entropy Production                        0.000284  0.00504 2.15e-05
# Reaction Entropy Production                          0.0799   0.0107    0.367
# Net Reaction Entropy Production                      0.0793 0.000659    0.367
# Microscopic Reaction Entropy Production Rate           2.34  0.00704   0.0158
# Microscopic Reaction Entropy Production Net Flux       2.26 0.000501   0.0157
# Microscopic Reaction Entropy Production Net Flu...     2.25 3.07e-05   0.0157
# Total Entropy Production                               1.26     1.26     1.26
# Total Microscopic Entropy Production Rate              28.2     28.2     28.2
# Macroscopic Reaction Entropy Production Net Flux       4.53    0.608     20.8
# Macroscopic Reaction Entropy Production Net Flu...     4.49   0.0373     20.8
# Total Macroscopic Entropy Production Net Flux          71.3     71.3     71.3
# Total Macroscopic Entropy Production Net Flux D...     69.4     69.4     69.4
#
#                                                         R_8      R_9
# Forward likelihoods                                    58.2      1.1
# Backward likelihoods                                 0.0172    0.906
# Delta G                                               -10.2  -0.0949
# log Q_r                                               -4.11  -0.0383
# log K_eq                                                 -0       -0
# Delta G0                                                  0        0
# logK - logQ                                            4.11   0.0383
# logQ - logK                                           -4.11  -0.0383
# Forward Log likelihoods                                4.06   0.0983
# Backward Log likelihoods                              -4.06  -0.0983
# Forward probabilities                                0.0433  0.00082
# Backward probabilities                             1.28e-05 0.000674
# Net probabilities                                    0.0433 0.000146
# Net likelihoods                                        58.2    0.197
# Forward rate                                           57.7    0.499
# Backward rate                                          0.99    0.452
# Thermodynamic driving force                            10.2   0.0949
# Net flux                                               56.7   0.0467
# Forward Entropy Production                            0.136  0.00583
# Backward Entropy Production                        0.000144  0.00492
# Reaction Entropy Production                           0.136   0.0108
# Net Reaction Entropy Production                       0.136 0.000908
# Microscopic Reaction Entropy Production Rate           7.84  0.00513
# Microscopic Reaction Entropy Production Net Flux       7.71 0.000502
# Microscopic Reaction Entropy Production Net Flu...      7.7 4.24e-05
# Total Entropy Production                               1.26     1.26
# Total Microscopic Entropy Production Rate              28.2     28.2
# Macroscopic Reaction Entropy Production Net Flux       7.71    0.609
# Macroscopic Reaction Entropy Production Net Flu...      7.7   0.0514
# Total Macroscopic Entropy Production Net Flux          71.3     71.3
# Total Macroscopic Entropy Production Net Flux D...     69.4     69.4

# %% [markdown]
# ### PyOpt without scipy.stats.entropy

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U
from scipy.stats import entropy
obj = 'macro_maxent_production_rate_pyOpt_optimize_w_p_log_p'
convex_mentos = 'convex_mentos_likelihoods_first_elmo'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_net_likelihood', ncons=i, type='e'),
                    dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_macro_maxent_production_rate_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def macro_maxent_production_rate(x):
        """Maximize product of  entropy production and macroscopic biomass growth rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum(sorted(forward_probability*np.log(forward_probability)*net_flux[biomass] + \
                    backward_probability*np.log(backward_probability)*net_flux[biomass]))
        g = np.concatenate((np.dot(S,forward_likelihood - backward_likelihood),
                            np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return macro_maxent_production_rate
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_macro_maxent_production_rate_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')
algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
#                                        A        B        C        D         E  \
# Counts                          9.12e+03      339 3.41e+03      656  1.23e+04
# Concentrations                  1.51e-05 5.63e-07 5.67e-06 1.09e-06  2.05e-05
# Log Concentrations                 -11.1    -14.4    -12.1    -13.7     -10.8
# Standard Chemical potential            0       -2       -2       -4        -2
# Chemical potential                 -27.5    -37.7    -31.9      -38     -28.8
# Normalized Concentrations        0.00741 0.000276  0.00277 0.000534      0.01
# Absolute activities             1.13e-12 4.36e-17 1.33e-14 3.04e-17  3.23e-13
# Normalized absolute activities  2.71e-05 1.05e-09 3.21e-07 7.31e-10  7.79e-06
# Entropy                         0.000285 2.17e-08  4.8e-06 1.54e-08  9.16e-05
# Entropy of Concentrations         0.0363  0.00226   0.0163  0.00402    0.0462
# fullS*forward_rate               -0.0479    -3.28     1.24    0.497  0.000724
# fullS*backward_rate              -0.0479    -24.8       12    0.497  0.000724
# fullS*net_flux                 -1.04e-08     21.5    -10.8 4.02e-07  -1.1e-07
# fullS*net_likelihood                7.61       57    -12.5     -113 -1.75e-05
# fullS*net_probabilities            0.028     0.21  -0.0462   -0.418 -6.44e-08
#
#                                       F    A_ext    D_ext     E_ext    F_ext
# Counts                               50 6.02e+05        6  6.02e+05        6
# Concentrations                  8.4e-08    0.001    1e-08     0.001    1e-08
# Log Concentrations                -16.3    -6.91    -18.4     -6.91    -18.4
# Standard Chemical potential         -10        0       -4        -2      -10
# Chemical potential                -50.4    -17.1    -49.7     -19.1    -55.7
# Normalized Concentrations      4.11e-05    0.489 4.89e-06     0.489 4.89e-06
# Absolute activities            1.31e-22 3.66e-08  2.7e-22  4.95e-09 6.69e-25
# Normalized absolute activities 3.15e-15    0.881  6.5e-15     0.119 1.61e-17
# Entropy                        1.05e-13    0.112 2.12e-13     0.254 6.23e-16
# Entropy of Concentrations      0.000415     0.35 5.98e-05      0.35 5.98e-05
# fullS*forward_rate                 1.12    -10.9     5.42   -0.0134     5.99
# fullS*backward_rate                11.9   -0.176   0.0434   -0.0134    0.615
# fullS*net_flux                    -10.8    -10.8     5.38 -2.19e-08     5.38
# fullS*net_likelihood              -10.8    -62.2      125 -3.27e-06     9.64
# fullS*net_probabilities         -0.0399   -0.229     0.46  -1.2e-08   0.0355
#                                                         R_1      R_2  \
# Forward likelihoods                                    62.2     54.6
# Backward likelihoods                                 0.0161   0.0183
# Delta G                                               -10.4    -10.2
# log Q_r                                               -4.19    -3.29
# log K_eq                                                 -0    0.807
# Delta G0                                                  0       -2
# logK - logQ                                            4.19      4.1
# logQ - logK                                           -4.19     -4.1
# Forward Log likelihoods                                4.13        4
# Backward Log likelihoods                              -4.13       -4
# Forward probabilities                                 0.229    0.201
# Backward probabilities                             5.93e-05 6.75e-05
# Net probabilities                                     0.229    0.201
# Net likelihoods                                        62.2     54.6
# Forward rate                                           10.9       11
# Backward rate                                         0.176    0.201
# Thermodynamic driving force                            10.4     10.2
# Net flux                                               10.8     10.8
# Forward Entropy Production                            0.338    0.323
# Backward Entropy Production                        0.000577 0.000648
# Reaction Entropy Production                           0.338    0.323
# Net Reaction Entropy Production                       0.337    0.322
# Microscopic Reaction Entropy Production Rate           3.69     3.53
# Microscopic Reaction Entropy Production Net Flux       3.64     3.48
# Microscopic Reaction Entropy Production Net Flu...     3.63     3.46
# Total Entropy Production                               1.45     1.45
# Total Microscopic Entropy Production Rate              10.2     10.2
# Macroscopic Reaction Entropy Production Net Flux       1.82     1.74
# Macroscopic Reaction Entropy Production Net Flu...     1.81     1.73
# Total Macroscopic Entropy Production Net Flux          7.78     7.78
# Total Macroscopic Entropy Production Net Flux D...     6.69     6.69
#
#                                                          R_3       R_4  \
# Forward likelihoods                                        1         1
# Backward likelihoods                                       1         1
# Delta G                                                -4.44     -9.64
# log Q_r                                               -0.983     -2.27
# log K_eq                                               0.807      1.61
# Delta G0                                                  -2        -4
# logK - logQ                                             1.79      3.89
# logQ - logK                                            -1.79     -3.89
# Forward Log likelihoods                            -8.89e-09  1.04e-05
# Backward Log likelihoods                            8.89e-09 -1.04e-05
# Forward probabilities                                0.00369   0.00369
# Backward probabilities                               0.00369   0.00369
# Net probabilities                                  -6.55e-11  7.64e-08
# Net likelihoods                                    -1.78e-08  2.07e-05
# Forward rate                                           0.023    0.0127
# Backward rate                                          0.023    0.0127
# Thermodynamic driving force                             4.44      9.64
# Net flux                                           -2.05e-10  1.32e-07
# Forward Entropy Production                            0.0207    0.0207
# Backward Entropy Production                           0.0207    0.0207
# Reaction Entropy Production                           0.0413    0.0413
# Net Reaction Entropy Production                    -3.02e-10  3.52e-07
# Microscopic Reaction Entropy Production Rate        0.000951  0.000524
# Microscopic Reaction Entropy Production Net Flux   -8.45e-12  5.44e-09
# Microscopic Reaction Entropy Production Net Flu...  6.17e-20  4.63e-14
# Total Entropy Production                                1.45      1.45
# Total Microscopic Entropy Production Rate               10.2      10.2
# Macroscopic Reaction Entropy Production Net Flux       0.222     0.222
# Macroscopic Reaction Entropy Production Net Flu... -1.62e-09  1.89e-06
# Total Macroscopic Entropy Production Net Flux           7.78      7.78
# Total Macroscopic Entropy Production Net Flux D...      6.69      6.69
#
#                                                          R_5      R_6  \
# Forward likelihoods                                        1    0.569
# Backward likelihoods                                       1     1.76
# Delta G                                                -9.64    -6.99
# log Q_r                                                -3.89    0.406
# log K_eq                                                  -0     3.23
# Delta G0                                                   0       -8
# logK - logQ                                             3.89     2.82
# logQ - logK                                            -3.89    -2.82
# Forward Log likelihoods                             1.63e-06   -0.563
# Backward Log likelihoods                           -1.63e-06    0.563
# Forward probabilities                                0.00369   0.0021
# Backward probabilities                               0.00369  0.00647
# Net probabilities                                    1.2e-08 -0.00438
# Net likelihoods                                     3.27e-06    -1.19
# Forward rate                                          0.0134     7.11
# Backward rate                                         0.0134     12.5
# Thermodynamic driving force                             9.64     6.99
# Net flux                                            2.19e-08    -5.38
# Forward Entropy Production                            0.0207   0.0129
# Backward Entropy Production                           0.0207   0.0326
# Reaction Entropy Production                           0.0413   0.0456
# Net Reaction Entropy Production                     5.54e-08  -0.0197
# Microscopic Reaction Entropy Production Rate        0.000554    0.499
# Microscopic Reaction Entropy Production Net Flux    9.06e-10   -0.245
# Microscopic Reaction Entropy Production Net Flu...  1.22e-15    0.106
# Total Entropy Production                                1.45     1.45
# Total Microscopic Entropy Production Rate               10.2     10.2
# Macroscopic Reaction Entropy Production Net Flux       0.222    0.245
# Macroscopic Reaction Entropy Production Net Flu...  2.98e-07   -0.106
# Total Macroscopic Entropy Production Net Flux           7.78     7.78
# Total Macroscopic Entropy Production Net Flux D...      6.69     6.69
#
#                                                         R_7      R_8      R_9
# Forward likelihoods                                    11.4      125     9.74
# Backward likelihoods                                 0.0875  0.00802    0.103
# Delta G                                               -6.09    -11.6    -5.27
# log Q_r                                               -1.65    -4.69    -2.13
# log K_eq                                              0.807       -0       -0
# Delta G0                                                 -2        0        0
# logK - logQ                                            2.45     4.69     2.13
# logQ - logK                                           -2.45    -4.69    -2.13
# Forward Log likelihoods                                2.44     4.83     2.28
# Backward Log likelihoods                              -2.44    -4.83    -2.28
# Forward probabilities                                0.0421     0.46   0.0359
# Backward probabilities                             0.000322 2.95e-05 0.000378
# Net probabilities                                    0.0418     0.46   0.0355
# Net likelihoods                                        11.3      125     9.64
# Forward rate                                           5.89     5.42     5.99
# Backward rate                                         0.515   0.0434    0.615
# Thermodynamic driving force                            6.09     11.6     5.27
# Net flux                                               5.38     5.38     5.38
# Forward Entropy Production                            0.133    0.357    0.119
# Backward Entropy Production                         0.00259 0.000308  0.00298
# Reaction Entropy Production                           0.136    0.358    0.122
# Net Reaction Entropy Production                       0.131    0.357    0.116
# Microscopic Reaction Entropy Production Rate          0.788     1.94    0.718
# Microscopic Reaction Entropy Production Net Flux      0.731     1.92    0.658
# Microscopic Reaction Entropy Production Net Flu...    0.704     1.92    0.626
# Total Entropy Production                               1.45     1.45     1.45
# Total Microscopic Entropy Production Rate              10.2     10.2     10.2
# Macroscopic Reaction Entropy Production Net Flux      0.731     1.92    0.658
# Macroscopic Reaction Entropy Production Net Flu...    0.704     1.92    0.626
# Total Macroscopic Entropy Production Net Flux          7.78     7.78     7.78
# Total Macroscopic Entropy Production Net Flux D...     6.69     6.69     6.69

# %%
import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')

reaction_data = reactions[obj]['Net flux'].to_dict()
metabolite_data = metab[obj]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="tqvfmjdwvh"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({ paths: { d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                                      escher: '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min' }
#            });
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            });
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"tqvfmjdwvh"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": 112.65343375062733, "R_9": 3.1690559627439024e-11, "R_1": 57.34786071404605, "R_2": 55.305573036674382, "R_3": 2.0422876773717249, "R_4": 55.305573036611946, "R_5": 55.305573036611953, "R_6": 3.1717739545911172e-11, "R_7": 2.042287677403436}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -23.118044771996949, "C": -23.220718147619245, "B": -33.020549740590695, "E": -25.026527672066379, "D": -33.974791190618639, "F": -42.820381330500197, "F_ext": -44.664060542629493, "A_ext": -13.124022703486059, "D_ext": -45.664060542629493, "E_ext": -15.124022703486059}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447894321204}}}},"27":{"name":"","bigg_id":"R_8","reversibility":false,"label_x":1482.17

# %% [markdown]
# ## Maximize macroscopic entropy production rate with steady state constraint for net likelihoods for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf r}_+,\vec{\bf r}_-,\vec{\bf c}}{\mbox{maximize}}   & - \sum_j\left({\mathscr P}_{+j}\log({\mathscr P}_{+j}) + {\mathscr P}_{-j}\log({\mathscr P}_{-j})\right)\cdot v_{growth}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf L}_+-\vec{\bf L}_-) = 0 \\
#                          & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                      %% & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#       & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array}
# $$
#
# Where
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
# Decision variables are emphasized in **bold**.

# %% [markdown]
# ### SS Net likelihood Scipy.optimize with scipy.stats.entropy

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U
import mentos
import scipy
from scipy.stats import entropy
from IPython.display import Latex, Markdown, display

obj = 'macro_maxent_production_rate_ss_net_likelihood_scipy_optimize_w_scipy_entropy'
initial_value = 'convex_mentos_likelihoods_first_elmo'

modeldir = 'Boltzmann-2017-09-09/Models/ABC_model/'
#abc_model = cobra.io.read_json_model(os.path.join(modeldir,'abc_model.json'))
#noext = [r.id for r in core_model.reactions if 'EX_' not in r.id]

#fullS = pd.DataFrame(cobra.util.array.create_stoichiometric_matrix(core_model), 
#                    index=[m.id for m in core_model.metabolites],
#                    columns = [r.id for r in core_model.reactions])[noext]
mets, rxns = fullS.index, fullS.columns
m,n = fullS.shape
internal_mets = [m for m in mets if '_e' not in m]
#display(HTML(fullS.to_html()))
m,n = fullS.shape
rxns, mets = fullS.columns, fullS.index
S = fullS.loc[internal_mets].as_matrix()
i,n = S.shape
biomass_rxn =  "R_8"
biomass = rxns.get_loc(biomass_rxn)
#met_bounds = getMetBounds(fullS, reactions[initial_value]['Net flux'], c_L, c_U, m9_medium, ext=r'_ext')
#external_free_energy = fullS.T[external_mets].dot(mu_ext).sum() #dot(fluxes)
met_lb = np.log(1e-8)#set_log_conc( met_bounds, set_log_conc(  ecoli_comp_abs_conc.loc[fitted_mets,'L.B.'], pd.Series(np.log(c_L),index=mets) )).values
met_ub = np.log(1e-2)# set_log_conc( met_bounds, set_log_conc(  ecoli_comp_abs_conc.loc[fitted_mets,'U.B.'], pd.Series(np.log(c_U),index=mets ))).values

#rxnbounds = get_rxn_bounds( core_model )
#rxnbounds.loc['GLCpts', 'upper'] = 1

#lower,upper = rxnbounds.loc[rxns, 'lower'].values, rxnbounds.loc[rxns,'upper'].astype(float).values


def make_macro_maxent_production_rate_objective(initial_log_c, initial_forward_rate, initial_backward_rate,fullS, S, mu0, deltaG0, R, T, log_c_L, log_c_U,v_L, v_U, external_free_energy, met_bounds,biomass):

    def check_constraints( x0, constraints,rxns, mets ):
        internal_mets = [m for m in mets if '_e' not in m]
        for constraint in constraints: 
            constraint_eval = constraint['fun'](x0)
            if constraint['type'] == 'eq':
                if np.allclose(constraint_eval, 0):
                    display(Latex('{}'.format(constraint['fun'].__doc__)))
                    if 'jac' in constraint:
                        display(Latex('{}'.format(constraint['jac'].__doc__)))
                else:
                    display('{} violated'.format(constraint['fun'].__name__))
                    if len(constraint_eval) == len(internal_mets):
                        constraint_s = pd.Series(constraint_eval,index=internal_mets)
                        
                        display(constraint_s[~constraint_s.apply(lambda x: np.isclose(x,0))].to_frame(constraint['fun'].__doc__))
                    elif len(constraint_eval) == len(rxns):
                        display(pd.DataFrame(constraint_eval, index=rxns))
                    
            elif constraint['type'] == 'ineq':
                if np.all(constraint_eval >= 0):
                    display(Latex('{}'.format(constraint['fun'].__doc__)))
                else:
                    display('{} violated'.format(constraint['fun'].__name__))
                    if len(constraint_eval) == len(rxns):
                        display(pd.DataFrame(constraint_eval,index=rxns))

            
                    
                
                
                
            
    def make_logc_bounds(mets, met_bounds,epsilon=1):
        logc_bounds = []
        for met in mets:
            if met in met_bounds:
                logc_bounds.append((met_bounds[met]- epsilon, met_bounds[met]))
            else:
                logc_bounds.append((log_c_L, log_c_U))
        return logc_bounds
    def make_rate_bounds( rxns, r_L=0, r_U=None):
        return [(r_L, r_U) for rxn in rxns]
                
    def macro_entropy_production_rate(x):
        """Maximize product of  entropy production difference and macroscopic biomass growth rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = entropy(np.concatenate( (forward_probability, backward_probability ) ) )*net_flux[biomass] #- 1000*np.sum(np.abs(slack))
        return -f
    def steady_state_net_likelihood_constraint(x):
        """$$S\cdot L_{net} = 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.dot(S,forward_likelihood-backward_likelihood)
    def steady_state_constraint(x):
        """$$S\cdot v = 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.dot(S,net_flux)
    def thermodynamic_constraint(x):
        """$$\log r_+ - \log r_- = \log K - \log Q$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K
    def energy_barrier_constraint( x ):
        """$$ \|\Delta G_{ext}\| - S^T\mu \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return   np.abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu)
    def energy_sink_constraint( x ):
        """$$S^T\mu + \|\Delta G_{ext}\| \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return  np.dot(fullS.T.as_matrix(),mu) + np.abs(external_free_energy) 
    def second_law_constraint( x ):
        """$$\log L_+ \geq 0 \iff v \geq 0$$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return np.log(forward_likelihood)*net_flux
    def flux_upper_constraint( x ):
        """$$ v_U - r_+ + r_- \geq 0 $$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return v_U - forward_rate + backward_rate
    def flux_lower_constraint( x ):
        """$$ r_+ - r_- - v_L \geq 0  $$"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux= mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        return  forward_rate - backward_rate - v_L
    x0 = np.concatenate((initial_log_c.values,
                         initial_forward_rate.values,
                         initial_backward_rate.values))
    constraints = [dict(type='eq',  fun=steady_state_net_likelihood_constraint),
                   dict(type='eq',  fun=steady_state_constraint),
                   dict(type='eq',  fun=thermodynamic_constraint),
                   dict(type='ineq',fun=energy_barrier_constraint),
                   dict(type='ineq',fun=energy_sink_constraint),
                   dict(type='ineq',fun=second_law_constraint),
                   dict(type='ineq',fun=flux_upper_constraint),
                   dict(type='ineq',fun=flux_lower_constraint)
]
                
    bounds = np.concatenate((make_logc_bounds(mets, met_bounds),
                             make_rate_bounds( rxns ),
                             make_rate_bounds( rxns )))
    check_constraints(x0, constraints, rxns, mets)
    mentos_result = scipy.optimize.minimize( fun=macro_entropy_production_rate,
                                            x0=x0,
                                            method='SLSQP',
                                            bounds=bounds,
                                            constraints=constraints,
                                            options=dict(disp=True))
    x_star = mentos_result.x
    log_c = x_star[:m]
    forward_rate = x_star[m:m+n]
    backward_rate = x_star[m+n:m+2*n]
    log_Q = np.dot(fullS.T,log_c)   # log of the Reaction quotient
    log_K = -1.0/(R*T)*deltaG0.as_matrix() 
    
    return mentos.generate_metabolite_report(log_c, forward_rate, backward_rate, S, mets, internal_mets,rxns, fullS, mu0), \
           mentos.generate_rxn_report(mets, log_c, log_Q, log_K,forward_rate, 
                                                backward_rate, rxns, deltaG0, biomass_rxn), mentos_result
metab[obj], reactions[obj], mentos_result = make_macro_maxent_production_rate_objective( 
                                metab[initial_value]['Log Concentrations'],
                                reactions[initial_value]['Forward rate'],
                                reactions[initial_value]['Backward rate'],
                                fullS, S, mu0[mets], deltaG0[rxns], R, T, 
                                met_lb, met_ub, v_L, v_U, external_free_energy, met_bounds, biomass)

if mentos_result.success:
        print("Success!")
else:
        print(mentos_result.message)
        print(mentos_result.keys())
display(HTML(metab[obj].T.to_html()))
                           
display(HTML(reactions[obj].T.to_html()))
algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])
# Out:
# 'steady_state_net_likelihood_constraint violated'
#    $$S\cdot L_{net} = 0$$
# A                    58.9
# B                    68.8
# C                   -1.28
# D                    -352
# E               -7.28e-05
# F                1.81e-05
# $$S\cdot v = 0$$
# $$\log r_+ - \log r_- = \log K - \log Q$$
# $$ \|\Delta G_{ext}\| - S^T\mu \geq 0$$
# $$S^T\mu + \|\Delta G_{ext}\| \geq 0$$
# $$\log L_+ \geq 0 \iff v \geq 0$$
# $$ v_U - r_+ + r_- \geq 0 $$
# $$ r_+ - r_- - v_L \geq 0  $$
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:99 RuntimeWarning: divide by zero encountered in log
# /Users/zuck016/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:99 RuntimeWarning: invalid value encountered in subtract
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: -110.086864557
#             Iterations: 28
#             Function evaluations: 776
#             Gradient evaluations: 24
# Success!
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th>A_ext</th>
#       <th>D_ext</th>
#       <th>E_ext</th>
#       <th>F_ext</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Counts</th>
#       <td>1.47e+05</td>
#       <td>7.59e+03</td>
#       <td>3.89e+05</td>
#       <td>5.52e+05</td>
#       <td>6.02e+06</td>
#       <td>4.84e+03</td>
#       <td>6.03e+08</td>
#       <td>2.22e+08</td>
#       <td>2.22e+08</td>
#       <td>6.02e+08</td>
#     </tr>
#     <tr>
#       <th>Concentrations</th>
#       <td>0.000243</td>
#       <td>1.26e-05</td>
#       <td>0.000646</td>
#       <td>0.000917</td>
#       <td>0.01</td>
#       <td>8.05e-06</td>
#       <td>1</td>
#       <td>0.368</td>
#       <td>0.368</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Log Concentrations</th>
#       <td>-8.32</td>
#       <td>-11.3</td>
#       <td>-7.34</td>
#       <td>-6.99</td>
#       <td>-4.61</td>
#       <td>-11.7</td>
#       <td>0.001</td>
#       <td>-1</td>
#       <td>-0.999</td>
#       <td>1e-08</td>
#     </tr>
#     <tr>
#       <th>Standard Chemical potential</th>
#       <td>0</td>
#       <td>-2</td>
#       <td>-2</td>
#       <td>-4</td>
#       <td>-2</td>
#       <td>-10</td>
#       <td>0</td>
#       <td>-4</td>
#       <td>-2</td>
#       <td>-10</td>
#     </tr>
#     <tr>
#       <th>Chemical potential</th>
#       <td>-20.6</td>
#       <td>-30</td>
#       <td>-20.2</td>
#       <td>-21.3</td>
#       <td>-13.4</td>
#       <td>-39.1</td>
#       <td>0.00248</td>
#       <td>-6.48</td>
#       <td>-4.48</td>
#       <td>-10</td>
#     </tr>
#     <tr>
#       <th>
td>
#     </tr>
#     <tr>
#       <th>Microscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>17.4</td>
#       <td>12.5</td>
#       <td>0.02</td>
#       <td>1.6</td>
#       <td>1.6</td>
#       <td>0.00571</td>
#       <td>0.0998</td>
#       <td>29.9</td>
#       <td>0.00571</td>
#     </tr>
#     <tr>
#       <th>Total Entropy Production</th>
#       <td>1.1</td>
#       <td>1.1</td>
#       <td>1.1</td>
#       <td>1.1</td>
#       <td>1.1</td>
#       <td>1.1</td>
#       <td>1.1</td>
#       <td>1.1</td>
#       <td>1.1</td>
#     </tr>
#     <tr>
#       <th>Total Microscopic Entropy Production Rate</th>
#       <td>64.2</td>
#       <td>64.2</td>
#       <td>64.2</td>
#       <td>64.2</td>
#       <td>64.2</td>
#       <td>64.2</td>
#       <td>64.2</td>
#       <td>64.2</td>
#       <td>64.2</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux</th>
#       <td>33.5</td>
#       <td>25.7</td>
#       <td>2.74</td>
#       <td>4.23</td>
#       <td>4.23</td>
#       <td>2.98</td>
#       <td>3.84</td>
#       <td>29.9</td>
#       <td>2.98</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>33.4</td>
#       <td>25.6</td>
#       <td>0.619</td>
#       <td>3.33</td>
#       <td>3.33</td>
#       <td>1.36</td>
#       <td>2.8</td>
#       <td>29.9</td>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux</th>
#       <td>110</td>
#       <td>110</td>
#       <td>110</td>
#       <td>110</td>
#       <td>110</td>
#       <td>110</td>
#       <td>110</td>
#       <td>110</td>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux Difference</th>
#       <td>102</td>
#       <td>102</td>
#       <td>102</td>
#       <td>102</td>
#       <td>102</td>
#       <td>102</td>
#       <td>102</td>
#       <td>102</td>
#       <td>102</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### SS net likelihood PyOpt optimize w SciPy entropy

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U
from scipy.stats import entropy
obj = 'macro_maxent_production_rate_ss_net_likelihood_pyOpt_optimize_w_scipy_entropy'
convex_mentos = 'convex_mentos_likelihoods_first_elmo'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_net_likelihood', ncons=i, type='e'),
                    dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_macro_maxent_production_rate_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def macro_maxent_production_rate(x):
        """Maximize product of  entropy production and macroscopic biomass growth rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = entropy( np.concatenate( ( forward_probability, backward_probability ) ) )*net_flux[biomass]
        g = np.concatenate((np.dot(S,forward_likelihood - backward_likelihood),
                            np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return macro_maxent_production_rate
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_macro_maxent_production_rate_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')

algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
#                                        A        B         C        D  \
# Counts                          8.92e+03      321  3.66e+03      650
# Concentrations                  1.48e-05 5.33e-07  6.07e-06 1.08e-06
# Log Concentrations                 -11.1    -14.4       -12    -13.7
# Standard Chemical potential            0       -2        -2       -4
# Chemical potential                 -27.6    -37.8     -31.8    -38.1
# Normalized Concentrations        0.00725 0.000261   0.00297 0.000529
# Absolute activities             1.07e-12 3.81e-17  1.58e-14 2.97e-17
# Normalized absolute activities  2.57e-05 9.16e-10  3.81e-07 7.15e-10
# Entropy                         0.000272 1.91e-08  5.64e-06 1.51e-08
# Entropy of Concentrations         0.0357  0.00215    0.0173  0.00399
# fullS*forward_rate                -0.172 -0.00385     0.112   0.0817
# fullS*backward_rate               -0.172 -0.00387     0.112   0.0817
# fullS*net_flux                  3.37e-08 2.15e-05 -1.08e-05 4.42e-10
# fullS*net_likelihood              -0.137     15.5     -7.77    0.285
# fullS*net_probabilities        -0.000383   0.0434   -0.0218   0.0008
#
#                                        E         F    A_ext    D_ext    E_ext  \
# Counts                          1.26e+04        65 6.02e+05        6 6.02e+05
# Concentrations                  2.09e-05  1.09e-07    0.001    1e-08    0.001
# Log Concentrations                 -10.8       -16    -6.91    -18.4    -6.91
# Standard Chemical potential           -2       -10        0       -4       -2
# Chemical potential                 -28.7     -49.8    -17.1    -49.7    -19.1
# Normalized Concentrations         0.0102  5.32e-05    0.489 4.89e-06    0.489
# Absolute activities             3.39e-13  2.47e-22 3.66e-08  2.7e-22 4.95e-09
# Normalized absolute activities  8.16e-06  5.96e-15    0.881  6.5e-15    0.119
# Entropy                         9.56e-05  1.95e-13    0.112 2.12e-13    0.254
# Entropy of Concentrations         0.0469  0.000523     0.35 5.98e-05     0.35
# fullS*forward_rate              5.33e-10  1.78e-11    -1.62     2.38   -0.781
# fullS*backward_rate             6.15e-10  1.97e-10   -0.024   0.0221  -0.0163
# fullS*net_flux                 -8.15e-11 -1.79e-10     -1.6     2.36   -0.765
# fullS*net_likelihood           -1.77e-06 -2.31e-05    -67.5      108    -47.9
# fullS*net_probabilities        -4.97e-09 -6.47e-08   -0.189    0.303   -0.134
#
#                                    F_ext
# Counts                                 6
# Concentrations                     1e-08
# Log Concentrations                 -18.4
# Standard Chemical potential          -10
# Chemical potential                 -55.7
# Normalized Concentrations       4.89e-06
# Absolute activities             6.69e-25
# Normalized absolute activities  1.61e-17
# Entropy                         6.23e-16
# Entropy of Concentrations       5.98e-05
# fullS*forward_rate              1.21e-05
# fullS*backward_rate             1.55e-05
# fullS*net_flux                 -3.43e-06
# fullS*net_likelihood              -0.504
# fullS*net_probabilities         -0.00141
#                                                         R_1     R_2      R_3  \
# Forward likelihoods                                    67.6    62.3     5.53
# Backward likelihoods                                 0.0148   0.016    0.181
# Delta G                                               -10.4   -10.2    -4.21
# log Q_r                                               -4.21   -3.32   -0.892
# log K_eq                                                 -0   0.807    0.807
# Delta G0                                                  0      -2       -2
# logK - logQ                                            4.21    4.13      1.7
# logQ - logK                                           -4.21   -4.13     -1.7
# Forward Log likelihoods                                4.21    4.13     1.71
# Backward Log likelihoods                              -4.21   -4.13    -1.71
# Forward probabilities                                  0.19   0.175   0.0155
# Backward probabilities                             4.15e-05 4.5e-05 0.000507
# Net probabilities                                     0.189   0.175    0.015
# Net likelihoods                                        67.5    62.3     5.35
# Forward rate                                           1.62   0.777     1.02
# Backward rate                                         0.024  0.0125    0.184
# Thermodynamic driving force                            10.4    10.2     4.21
# Net flux                                                1.6   0.765    0.832
# Forward Entropy Production                            0.315   0.305   0.0647
# Backward Entropy Production                        0.000419 0.00045  0.00385
# Reaction Entropy Production                           0.316   0.305   0.0685
# Net Reaction Entropy Production                       0.315   0.304   0.0608
# Microscopic Reaction Entropy Production Rate          0.511   0.237   0.0664
# Microscopic Reaction Entropy Production Net Flux      0.504   0.234    0.057
# Microscopic Reaction Entropy Production Net Flu...    0.503   0.233   0.0506
# Total Entropy Production                               1.78    1.78     1.78
# Total Microscopic Entropy Production Rate              2.16    2.16     2.16
# Macroscopic Reaction Entropy Production Net Flux      0.746   0.721    0.162
# Macroscopic Reaction Entropy Production Net Flu...    0.744   0.719    0.144
# Total Macroscopic Entropy Production Net Flux           4.2     4.2      4.2
# Total Macroscopic Entropy Production Net Flux D...     3.98    3.98     3.98
#
#                                                         R_4      R_5  \
# Forward likelihoods                                    47.9     47.9
# Backward likelihoods                                 0.0209   0.0209
# Delta G                                               -9.59    -9.59
# log Q_r                                               -2.25    -3.87
# log K_eq                                               1.61       -0
# Delta G0                                                 -4        0
# logK - logQ                                            3.87     3.87
# logQ - logK                                           -3.87    -3.87
# Forward Log likelihoods                                3.87     3.87
# Backward Log likelihoods                              -3.87    -3.87
# Forward probabilities                                 0.134    0.134
# Backward probabilities                             5.86e-05 5.86e-05
# Net probabilities                                     0.134    0.134
# Net likelihoods                                        47.9     47.9
# Forward rate                                          0.781    0.781
# Backward rate                                        0.0163   0.0163
# Thermodynamic driving force                            9.59     9.59
# Net flux                                              0.765    0.765
# Forward Entropy Production                             0.27     0.27
# Backward Entropy Production                        0.000571 0.000571
# Reaction Entropy Production                            0.27     0.27
# Net Reaction Entropy Production                       0.269    0.269
# Microscopic Reaction Entropy Production Rate          0.211    0.211
# Microscopic Reaction Entropy Production Net Flux      0.207    0.207
# Microscopic Reaction Entropy Production Net Flu...    0.206    0.206
# Total Entropy Production                               1.78     1.78
# Total Microscopic Entropy Production Rate              2.16     2.16
# Macroscopic Reaction Entropy Production Net Flux      0.638    0.638
# Macroscopic Reaction Entropy Production Net Flu...    0.636    0.636
# Total Macroscopic Entropy Production Net Flux           4.2      4.2
# Total Macroscopic Entropy Production Net Flux D...     3.98     3.98
#
#                                                          R_6      R_7  \
# Forward likelihoods                                    0.779     12.7
# Backward likelihoods                                    1.28   0.0787
# Delta G                                                -5.91    -6.28
# log Q_r                                                0.842    -1.73
# log K_eq                                                3.23    0.807
# Delta G0                                                  -8       -2
# logK - logQ                                             2.38     2.53
# logQ - logK                                            -2.38    -2.53
# Forward Log likelihoods                               -0.249     2.54
# Backward Log likelihoods                               0.249    -2.54
# Forward probabilities                                0.00219   0.0356
# Backward probabilities                                0.0036 0.000221
# Net probabilities                                   -0.00141   0.0354
# Net likelihoods                                       -0.504     12.6
# Forward rate                                        1.21e-05    0.903
# Backward rate                                       1.55e-05   0.0711
# Thermodynamic driving force                             5.91     6.28
# Net flux                                           -3.43e-06    0.832
# Forward Entropy Production                            0.0134    0.119
# Backward Entropy Production                           0.0203  0.00186
# Reaction Entropy Production                           0.0336    0.121
# Net Reaction Entropy Production                     -0.00686    0.117
# Microscopic Reaction Entropy Production Rate        4.77e-07    0.107
# Microscopic Reaction Entropy Production Net Flux   -1.15e-07      0.1
# Microscopic Reaction Entropy Production Net Flu...  2.35e-08   0.0973
# Total Entropy Production                                1.78     1.78
# Total Microscopic Entropy Production Rate               2.16     2.16
# Macroscopic Reaction Entropy Production Net Flux      0.0795    0.285
# Macroscopic Reaction Entropy Production Net Flu...   -0.0162    0.276
# Total Macroscopic Entropy Production Net Flux            4.2      4.2
# Total Macroscopic Entropy Production Net Flux D...      3.98     3.98
#
#                                                         R_8       R_9
# Forward likelihoods                                     108     0.779
# Backward likelihoods                                0.00925      1.28
# Delta G                                               -11.6     -5.91
# log Q_r                                               -4.68     -2.39
# log K_eq                                                 -0        -0
# Delta G0                                                  0         0
# logK - logQ                                            4.68      2.39
# logQ - logK                                           -4.68     -2.39
# Forward Log likelihoods                                4.68    -0.249
# Backward Log likelihoods                              -4.68     0.249
# Forward probabilities                                 0.303   0.00219
# Backward probabilities                              2.6e-05    0.0036
# Net probabilities                                     0.303  -0.00141
# Net likelihoods                                         108    -0.504
# Forward rate                                           2.38  1.21e-05
# Backward rate                                        0.0221  1.55e-05
# Thermodynamic driving force                            11.6      5.91
# Net flux                                               2.36 -3.43e-06
# Forward Entropy Production                            0.362    0.0134
# Backward Entropy Production                        0.000274    0.0203
# Reaction Entropy Production                           0.362    0.0336
# Net Reaction Entropy Production                       0.362  -0.00686
# Microscopic Reaction Entropy Production Rate          0.863  4.77e-07
# Microscopic Reaction Entropy Production Net Flux      0.855 -1.15e-07
# Microscopic Reaction Entropy Production Net Flu...    0.854  2.35e-08
# Total Entropy Production                               1.78      1.78
# Total Microscopic Entropy Production Rate              2.16      2.16
# Macroscopic Reaction Entropy Production Net Flux      0.855    0.0795
# Macroscopic Reaction Entropy Production Net Flu...    0.854   -0.0162
# Total Macroscopic Entropy Production Net Flux           4.2       4.2
# Total Macroscopic Entropy Production Net Flux D...     3.98      3.98

# %% [markdown]
# ## Maximize macroscopic entropy production net flux difference for the ABC model ##
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf r}_+,\vec{\bf r}_-,\vec{\bf c}}{\mbox{maximize}}   & - \sum_j\left({\mathscr P}_{+j}\log({\mathscr P}_{+j}) - {\mathscr P}_{-j}\log({\mathscr P}_{-j})\right)\cdot v_{growth}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf r}_+-\vec{\bf r}_-) = 0 \\
#                        &\log\vec{\bf r}_+ -\log\vec{\bf r}_-= -\frac{1}{RT}S^T\cdot\vec{\mu}^0 - S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                       & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                          & \vec{\bf r}_+ \geq 0 \\
#     & \vec{\bf r}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#                            & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_A \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#       & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array}
# $$
#
# Where
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
# Decision variables are emphasized in **bold**.

# %%
from mentos.abc_model import fullS, S, deltaG0, mu0, \
     c_U, c_L, mets, external_mets, met_bounds, internal_mets, rxns, \
     efflux, uptake, n, m, R, T, biomass, \
     external_free_energy, efflux, uptake, A_ext, D_ext, E_ext, F_ext, \
     v_L, v_U

obj = 'macro_maxent_production_net_flux_difference'
convex_mentos = 'convex_mentos_likelihoods_first_elmo'

m,n = fullS.shape
i,n = S.shape
variable_group = [dict(name='log_c',nvars=m, type='c',
                                     initial_value=metab[convex_mentos]['Log Concentrations'].values),
                      dict(name='forward_rate', nvars=n, type='c',
                                             initial_value=reactions[convex_mentos]['Forward rate'].values),
                      dict(name='backward_rate',nvars=n, type='c',
                                            initial_value=reactions[convex_mentos]['Backward rate'].values)]
constraint_group=[dict(name='steady_state_flux', ncons=i, type='e'),
                    dict(name='thermodynamics',ncons=n, type='e'),
                    dict(name='boundary_conditions', ncons=m-i, type='e'),
                    dict(name='energy_barrier', ncons=n, type='i'),
                    dict(name='energy_sink',ncons=n,type='i'),
                    dict(name='flux_lower_bounds', ncons=n, type='i'),
                    dict(name='flux_upper_bounds', ncons=n,type='i')]
def make_macro_maxent_production_net_flux_difference_objective(fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U):
    external_mets = [met for met in fullS.index if 'ext' in met]
    met_bounds = pd.Series({'A_ext':c_U, 'E_ext': c_U, 'F_ext': c_L, 'D_ext': c_L}, index=external_mets)
    mu_ext = mu0[external_mets] + R*T*met_bounds.apply(np.log)
    external_free_energy =  (mu_ext['D_ext'] + mu_ext['F_ext']) - (mu_ext['A_ext'] + mu_ext['E_ext'])
    
    def macro_maxent_production_net_flux_difference(x):
        """Maximize product of  entropy production difference and macroscopic biomass growth rate of the ABC model"""
        log_c, \
        forward_rate, backward_rate, \
        log_Q, log_K, \
        forward_likelihood, backward_likelihood, \
        forward_probability, backward_probability, mu, \
        thermodynamic_driving_force, \
        net_flux = mentos.make_variables( x, fullS, mu0, deltaG0, R, T )
        f = -np.sum( np.log(forward_probability)*forward_probability*net_flux[biomass]
                    - np.log(backward_probability)*backward_probability*net_flux[biomass])
        g = np.concatenate((np.dot(S,net_flux),
                            np.log(forward_rate) - np.log(backward_rate) + log_Q - log_K,
                            [ log_c[A_ext] - np.log(c_U),  # = 0               # Creating a concentration gradient between A, E and D,F
                              log_c[E_ext] - np.log(c_U),  # = 0
                              log_c[D_ext] - np.log(c_L),  # = 0
                              log_c[F_ext] - np.log(c_L)],  #= 0
                            -abs(external_free_energy) - np.dot(fullS.T.as_matrix(),mu), # <= 0
                            np.dot(fullS.T.as_matrix(),mu) - abs(external_free_energy),  # <= 0 
                            np.minimum(-1, thermodynamic_driving_force)+ 1 -net_flux, # <= 0
                            net_flux - np.maximum(1, thermodynamic_driving_force ) - 1)) # <= 0
        
        fail = 0
        return -f, g, fail
    return macro_maxent_production_net_flux_difference
metab[obj], reactions[obj] = mentos.run_mentos_ext_free_energy(fullS, S, internal_mets, deltaG0, mu0, 
                                        variable_group, constraint_group,
                                        obj=make_macro_maxent_production_net_flux_difference_objective( fullS, S, mu0, deltaG0, R, T, c_L, c_U,v_L, v_U),
                                        biomass_rxn='R_8')
algorithm = obj
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_metab_{}.csv', metab[algorithm] )
mentos.print_report( os.path.join(abc_dir, algorithm), 'ABC_reaction_{}.csv', reactions[algorithm])

display(metab[obj].T)
                             
display(reactions[obj].T)
# Out:
#                                        A         B         C        D  \
# Counts                          1.07e+04       440       368      672
# Concentrations                  1.77e-05  7.31e-07  6.11e-07 1.12e-06
# Log Concentrations                 -10.9     -14.1     -14.3    -13.7
# Standard Chemical potential            0        -2        -2       -4
# Chemical potential                 -27.1       -37     -37.5      -38
# Normalized Concentrations        0.00868  0.000359    0.0003 0.000548
# Absolute activities             1.66e-12  8.34e-17  5.35e-17 3.22e-17
# Normalized absolute activities     4e-05  2.01e-09  1.29e-09 7.76e-10
# Entropy                         0.000405  4.02e-08  2.64e-08 1.63e-08
# Entropy of Concentrations         0.0412   0.00285   0.00243  0.00411
# fullS*forward_rate               -0.0362 -1.55e-06     -9.77     10.9
# fullS*backward_rate              -0.0362 -1.97e-06     -9.77     10.9
# fullS*net_flux                 -2.04e-11  4.16e-07 -2.07e-07 3.91e-10
# fullS*net_likelihood               -62.7     -53.5      91.2    -2.84
# fullS*net_probabilities           -0.134    -0.115     0.196 -0.00609
#
#                                        E         F    A_ext    D_ext    E_ext  \
# Counts                          1.11e+04       498 6.02e+05        6 6.02e+05
# Concentrations                  1.84e-05  8.28e-07    0.001    1e-08    0.001
# Log Concentrations                 -10.9       -14    -6.91    -18.4    -6.91
# Standard Chemical potential           -2       -10        0       -4       -2
# Chemical potential                   -29     -44.7    -17.1    -49.7    -19.1
# Normalized Concentrations        0.00904  0.000406     0.49  4.9e-06     0.49
# Absolute activities             2.48e-13   3.8e-20 3.66e-08  2.7e-22 4.95e-09
# Normalized absolute activities  5.98e-06  9.15e-13    0.881  6.5e-15    0.119
# Entropy                         7.19e-05  2.54e-11    0.112 2.12e-13    0.254
# Entropy of Concentrations         0.0425   0.00317    0.349 5.99e-05    0.349
# fullS*forward_rate               3.1e-08   1.3e-07      nan      nan      nan
# fullS*backward_rate              3.1e-08  1.79e-07      nan      nan      nan
# fullS*net_flux                 -2.82e-12 -4.94e-08      nan      nan      nan
# fullS*net_likelihood           -1.59e-06     -14.6      nan      nan      nan
# fullS*net_probabilities        -3.41e-09   -0.0312   -0.121     0.24   -0.116
#
#                                   F_ext
# Counts                                6
# Concentrations                    1e-08
# Log Concentrations                -18.4
# Standard Chemical potential         -10
# Chemical potential                -55.7
# Normalized Concentrations       4.9e-06
# Absolute activities            6.69e-25
# Normalized absolute activities 1.61e-17
# Entropy                        6.23e-16
# Entropy of Concentrations      5.99e-05
# fullS*forward_rate                  nan
# fullS*backward_rate                 nan
# fullS*net_flux                      nan
# fullS*net_likelihood                nan
# fullS*net_probabilities          0.0886
#                                                         R_1      R_2      R_3  \
# Forward likelihoods                                    56.5     54.2     64.9
# Backward likelihoods                                 0.0177   0.0184   0.0154
# Delta G                                                 -10     -9.9    -10.3
# log Q_r                                               -4.03    -3.19    -3.37
# log K_eq                                                 -0    0.807    0.807
# Delta G0                                                  0       -2       -2
# logK - logQ                                            4.03     3.99     4.17
# logQ - logK                                           -4.03    -3.99    -4.17
# Forward Log likelihoods                                4.03     3.99     4.17
# Backward Log likelihoods                              -4.03    -3.99    -4.17
# Forward probabilities                                 0.121    0.116    0.139
# Backward probabilities                              3.8e-05 3.95e-05 3.31e-05
# Net probabilities                                     0.121    0.116    0.139
# Net likelihoods                                        56.4     54.2     64.9
# Forward rate                                           58.5     56.3     2.25
# Backward rate                                          1.04     1.04   0.0347
# Thermodynamic driving force                              10      9.9     10.3
# Net flux                                               57.5     55.2     2.22
# Forward Entropy Production                            0.256     0.25    0.274
# Backward Entropy Production                        0.000387 0.000401 0.000341
# Reaction Entropy Production                           0.256    0.251    0.275
# Net Reaction Entropy Production                       0.255     0.25    0.274
# Microscopic Reaction Entropy Production Rate             15     14.1    0.619
# Microscopic Reaction Entropy Production Net Flux       14.7     13.9     0.61
# Microscopic Reaction Entropy Production Net Flu...     14.7     13.8    0.609
# Total Entropy Production                               2.03     2.03     2.03
# Total Microscopic Entropy Production Rate              95.6     95.6     95.6
# Macroscopic Reaction Entropy Production Net Flux       28.9     28.3       31
# Macroscopic Reaction Entropy Production Net Flu...     28.8     28.2     30.9
# Total Macroscopic Entropy Production Net Flux           229      229      229
# Total Macroscopic Entropy Production Net Flux D...      226      226      226
#
#                                                         R_4      R_5      R_6  \
# Forward likelihoods                                    54.2     54.2     26.8
# Backward likelihoods                                 0.0184   0.0184   0.0373
# Delta G                                                -9.9     -9.9    -8.14
# log Q_r                                               -2.38    -3.99  -0.0556
# log K_eq                                               1.61       -0     3.23
# Delta G0                                                 -4        0       -8
# logK - logQ                                            3.99     3.99     3.28
# logQ - logK                                           -3.99    -3.99    -3.28
# Forward Log likelihoods                                3.99     3.99     3.29
# Backward Log likelihoods                              -3.99    -3.99    -3.29
# Forward probabilities                                 0.116    0.116   0.0575
# Backward probabilities                             3.95e-05 3.95e-05    8e-05
# Net probabilities                                     0.116    0.116   0.0574
# Net likelihoods                                        54.2     54.2     26.8
# Forward rate                                           56.3     56.3 1.34e-05
# Backward rate                                          1.04     1.04    5e-07
# Thermodynamic driving force                             9.9      9.9     8.14
# Net flux                                               55.2     55.2 1.29e-05
# Forward Entropy Production                             0.25     0.25    0.164
# Backward Entropy Production                        0.000401 0.000401 0.000755
# Reaction Entropy Production                           0.251    0.251    0.165
# Net Reaction Entropy Production                        0.25     0.25    0.163
# Microscopic Reaction Entropy Production Rate           14.1     14.1  2.2e-06
# Microscopic Reaction Entropy Production Net Flux       13.9     13.9 2.13e-06
# Microscopic Reaction Entropy Production Net Flu...     13.8     13.8 2.11e-06
# Total Entropy Production                               2.03     2.03     2.03
# Total Microscopic Entropy Production Rate              95.6     95.6     95.6
# Macroscopic Reaction Entropy Production Net Flux       28.3     28.3     18.6
# Macroscopic Reaction Entropy Production Net Flu...     28.2     28.2     18.4
# Total Macroscopic Entropy Production Net Flux           229      229      229
# Total Macroscopic Entropy Production Net Flux D...      226      226      226
#
#                                                         R_7      R_8      R_9
# Forward likelihoods                                    1.23      112     41.3
# Backward likelihoods                                  0.815  0.00895   0.0242
# Delta G                                              -0.506    -11.7    -10.9
# log Q_r                                               0.603    -4.72    -4.42
# log K_eq                                              0.807       -0       -0
# Delta G0                                                 -2        0        0
# logK - logQ                                           0.204     4.72     4.42
# logQ - logK                                          -0.204    -4.72    -4.42
# Forward Log likelihoods                               0.204     4.72     3.72
# Backward Log likelihoods                             -0.204    -4.72    -3.72
# Forward probabilities                               0.00263     0.24   0.0887
# Backward probabilities                              0.00175 1.92e-05 5.19e-05
# Net probabilities                                  0.000882     0.24   0.0886
# Net likelihoods                                       0.411      112     41.3
# Forward rate                                             12      114 1.33e-05
# Backward rate                                           9.8     1.02 3.21e-07
# Thermodynamic driving force                           0.506     11.7     10.9
# Net flux                                               2.22      113  1.3e-05
# Forward Entropy Production                           0.0156    0.342    0.215
# Backward Entropy Production                          0.0111 0.000209 0.000512
# Reaction Entropy Production                          0.0267    0.343    0.215
# Net Reaction Entropy Production                     0.00452    0.342    0.214
# Microscopic Reaction Entropy Production Rate          0.297     38.9 2.85e-06
# Microscopic Reaction Entropy Production Net Flux     0.0593     38.6 2.79e-06
# Microscopic Reaction Entropy Production Net Flu...     0.01     38.6 2.78e-06
# Total Entropy Production                               2.03     2.03     2.03
# Total Microscopic Entropy Production Rate              95.6     95.6     95.6
# Macroscopic Reaction Entropy Production Net Flux       3.01     38.6     24.3
# Macroscopic Reaction Entropy Production Net Flu...     0.51     38.6     24.2
# Total Macroscopic Entropy Production Net Flux           229      229      229
# Total Macroscopic Entropy Production Net Flux D...      226      226      226

# %%
#import escher,os
abc_dir = 'Mentos/ABC'
map_name = os.path.join(abc_dir,'ABC_map.json')
model_name = os.path.join(abc_dir,'ABC_model.json')

reaction_data = reactions[obj]['Net flux'].to_dict()
metabolite_data = metab[obj]['Chemical potential'].to_dict()
builder = escher.Builder(map_json=map_name, model_json=model_name, 
                         reaction_data=reaction_data,metabolite_data=metabolite_data)
builder.display_in_notebook(menu='zoom')
# Out:
#
#
#
#
#
#     <link rel="stylesheet" href="//npmcdn.com/escher-vis@1.4.0/css/dist/builder.min.css"/>
#
#
#
#
#   <div style="height: 500px; width: 100%;" id="nfcppxcmkc"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(d3, escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               d3.select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load d3 and escher
#            require.config({ paths: { d3: '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min',
#                                      escher: '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min' }
#            });
#            require(['d3', 'escher'], function(d3, escher) {
#                draw_escher(d3, escher);
#            });
#        } else {
#            // require.js not available: dynamically load d3 & escher
#            check_global_and_load('d3', '//cdnjs.cloudflare.com/ajax/libs/d3/3.5.14/d3.min.js', function(d3) {
#                check_global_and_load('escher', '//npmcdn.com/escher-vis@1.4.0/js/dist/escher.min.js', function(escher) {
#                    draw_escher(d3, escher);
#                })
#            });
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"nfcppxcmkc"'),
#                map_download_url: JSON.parse('"//escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"//escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"reaction_data": {"R_8": 2.3080677861395129, "R_9": 1.391684781030943, "R_1": 3.6997467035593057, "R_2": 2.7833754256395324, "R_3": 0.91637127791872919, "R_4": 5.8635944717444488e-06, "R_5": 5.7937628280008476e-06, "R_6": 1.3916847810255217, "R_7": 2.3080560589445618}, "enable_editing": false, "gene_data": null, "metabolite_data": {"A": -28.248252798017234, "C": -29.700668597901075, "B": -35.176647371725664, "E": -28.927332890233469, "D": -32.051991802503174, "F": -42.67206430422727, "F_ext": -44.664060542590605, "A_ext": -13.124022703486055, "D_ext": -45.664060542653353, "E_ext": -15.124022703486059}, "fill_screen": false, "enable_keys": false, "menu": "zoom", "scroll_behavior": "none", "ignore_bootstrap": true, "never_ask_before_quit": true}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name":"new_map","map_id":"BhsCR3UxNSqs","map_description":"","homepage":"https://escher.github.io","schema":"https://escher.github.io/escher/jsonschema/1-0-0#"},{"reactions":{"22":{"name":"","bigg_id":"R_1","reversibility":false,"label_x":732.1915294178682,"label_y":7.8236466323592,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A_ext","coefficient":-1},{"bigg_id":"A","coefficient":1}],"segments":{"93":{"from_node_id":"99","to_node_id":"100","b1":null,"b2":null},"94":{"from_node_id":"101","to_node_id":"100","b1":null,"b2":null},"95":{"from_node_id":"99","to_node_id":"98","b1":{"x":730.1991462248822,"y":46.93365229883145},"b2":{"x":684.7058109310195,"y":46.15490725699466}},"96":{"from_node_id":"101","to_node_id":"102","b1":{"x":834.1839126108541,"y":48.71364096588695},"b2":{"x":879.6772479047169,"y":49.49238600772373}}}},"23":{"name":"","bigg_id":"R_2","reversibility":false,"label_x":941.2816763663957,"label_y":-58.089391993111036,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"A","coefficient":-1},{"bigg_id":"B","coefficient":1}],"segments":{"97":{"from_node_id":"103","to_node_id":"104","b1":null,"b2":null},"98":{"from_node_id":"105","to_node_id":"104","b1":null,"b2":null},"99":{"from_node_id":"103","to_node_id":"102","b1":{"x":999.5346266510796,"y":-20.784531858938536},"b2":{"x":968.2579875691233,"y":12.261221994424417}},"100":{"from_node_id":"105","to_node_id":"106","b1":{"x":1071.0240874098367,"y":-96.31768352376793},"b2":{"x":1102.300726491793,"y":-129.3634373771308}}}},"24":{"name":"","bigg_id":"R_4","reversibility":false,"label_x":1258.2639017636986,"label_y":-95.02494274798356,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":2},{"bigg_id":"E","coefficient":-1},{"bigg_id":"B","coefficient":-1}],"segments":{"101":{"from_node_id":"107","to_node_id":"108","b1":null,"b2":null},"102":{"from_node_id":"109","to_node_id":"108","b1":null,"b2":null},"103":{"from_node_id":"109","to_node_id":"119","b1":{"x":1291.9194987798644,"y":-36.22078799936085},"b2":{"x":1341.490597951236,"y":6.974105073225502}},"104":{"from_node_id":"107","to_node_id":"111","b1":{"x":1209.833969084631,"y":-106.40601304461478},"b2":{"x":1287.4031776074785,"y":-179.93815697714433}},"105":{"from_node_id":"107","to_node_id":"106","b1":{"x":1212.874173888158,"y":-103.80656026516093},"b2":{"x":1178.2918442480366,"y":-133.37533563144848}}}},"25":{"name":"","bigg_id":"R_3","reversibility":false,"label_x":955.2988810578488,"label_y":184.17666110507764,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"C","coefficient":1},{"bigg_id":"A","coefficient":-1}],"segments":{"106":{"from_node_id":"112","to_node_id":"113","b1":null,"b2":null},"107":{"from_node_id":"114","to_node_id":"113","b1":null,"b2":null},"108":{"from_node_id":"114","to_node_id":"115","b1":{"x":1085.6999004372958,"y":181.6633033414933},"b2":{"x":1120.2822300774174,"y":211.23207870778083}},"109":{"from_node_id":"112","to_node_id":"102","b1":{"x":1006.6545755455894,"y":114.07753107569323},"b2":{"x":972.0722459054679,"y":84.50875570940563}}}},"26":{"name":"","bigg_id":"R_7","reversibility":false,"label_x":1302.959167627114,"label_y":148.08173116603948,"gene_reaction_rule":"","genes":[],"metabolites":[{"bigg_id":"D","coefficient":1},{"bigg_id":"C","coefficient":-1}],"segments":{"110":{"from_node_id":"116","to_node_id":"117","b1":null,"b2":null},"111":{"from_node_id":"118","to_node_id":"117","b1":null,"b2":null},"112":{"from_node_id":"118","to_node_id":"119","b1":{"x":1309.6885327804812,"y":109.50929424362832},"b2":{"x":1343.3638519234664,"y":78.9115348384351}},"113":{"from_node_id":"116","to_node_id":"115","b1":{"x":1232.716374739372,"y":179.44703002692717},"b2":{"x":1199.0410555963867,"y":210.0447894321204}}}},"27":{"name":"","bigg_id":"R_8","reversibility":false,"label_x":1482.1

# %% [markdown]
# # Use probabilities as decision variables
#
# $$ \begin{array}{ll}
#     \underset{\vec{\bf \mathscr P}_+,\vec{\bf \mathscr P}_-,\vec{\bf c}}{\mbox{maximize}}   & - \sum_j\left({\mathscr P}_{+j}\log({\mathscr P}_{+j}) - {\mathscr P}_{-j}\log({\mathscr P}_{-j})\right)\cdot v_{growth}   \\
#     \mbox{subject to}  & S\cdot(\vec{\bf \mathscr P}_+-\vec{\bf \mathscr P}_-) = 0 \\
#                        &Z\cdot\vec{\bf\mathscr P}_-= Q^T\cdot I\cdot K^{-1}_{eq} \\
#                       %% & \log\vec{\bf L}_- = \frac{1}{RT}S^T\cdot\vec{\mu}^0 + S^T\cdot\log\vec{\bf c} \\
#                       %% & \log\vec{\bf L}_+  -\log\vec{\bf L}_- \\
#                      %% & \vec{v}_{lower}(L_+) \leq \vec{\bf r}_+ -\vec{\bf r}_- \leq \vec{v}_{upper}(L_+) \\
#                        & \sum_j \mathscr P_+ + \sum_j\mathscr P_- = 1 \\
# & \vec{\bf \mathscr P}_+ \geq 0 \\
#     & \vec{\bf \mathscr P}_- \geq 0 \\
#                       & \log \left[{\bf A}_{ext}\right] = \log \left[{\bf E}_{ext}\right] =  \log c_{upper} \\
#                       & \log \left[{\bf E}_{ext}\right] = \log \left[{\bf D}_{ext}\right] = \log c_{lower}   \\
#                            & \mu_{D_{ext}} + \mu_{F_{ext}} \leq \mu_A \leq \mu_{A_{ext}} + \mu_{E_{ext}} \\
#       & -\left|\Delta G_{ext}\right| \leq S^T\mu \leq \left|\Delta G_{ext}\right|
#     \end{array}
# $$
#
# Where
# * $\vec{\bf r}_+,\vec{\bf r}_-$ are decision variables representing the forward and backward rates, respectively.
# * ${\mathscr P}_{+i},{\mathscr P}_{-i}$ are the normalized forward and backward thermodynamic driving forces $\frac{r_{+i}}{r_{-i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$ and $\frac{r_{-i}}{r_{+i}}\left(\sum_j\frac{r_{+j}}{r_{-j}} + \frac{r_{-j}}{r_{+j}}\right)^{-1}$
# * $\vec{\bf c}$ is a decision variable representing the chemical concentrations of each metabolite
# *  $S$ is the $m\times n$ stoichiometric matrix of representing $m$ metabolites and $n$ reactions of the model
# *  $\vec{\mu}^0$ is the vector of standard chemical potentials
# * $L_+ = \frac{r_+}{r_-}$
# * $L_- = \frac{r_-}{r_+}$
# * $v_{lower}(L) =\min\left(-1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) + 1$
# * $v_{upper}(L) = \max\left(1,\text{sign}(\log L)\cdot L^{\text{sign}(\log L)}\right) - 1$
# * $\Delta G_{ext} =  \mu_{D_{ext}} + \mu_{F_{ext}} - \mu_{A_{ext}} - \mu_{E_{ext}}$
#
# Decision variables are emphasized in **bold**.

# %%
algorithm = 'DeltaG_entropy'
metab[algorithm]  = pd.read_table(os.path.join(abc_dir, algorithm, 'ABC_metab_{}.csv'.format( algorithm)),index_col=0)
reactions[algorithm] = pd.read_table(os.path.join(abc_dir, algorithm, 'ABC_reaction_{}.csv'.format( algorithm)),index_col=0)
display(HTML(metab[algorithm].T.to_html()))
display(HTML(reactions[algorithm].T.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th>A_ext</th>
#       <th>D_ext</th>
#       <th>E_ext</th>
#       <th>F_ext</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Counts</th>
#       <td>9.77e+07</td>
#       <td>8.01e+07</td>
#       <td>3.12e+06</td>
#       <td>3.09e+05</td>
#       <td>2.71e+06</td>
#       <td>5.58e+09</td>
#       <td>6.02e+08</td>
#       <td>6.02e+03</td>
#       <td>3.09e+10</td>
#       <td>6.02e+08</td>
#     </tr>
#     <tr>
#       <th>Concentrations</th>
#       <td>0.162</td>
#       <td>0.133</td>
#       <td>0.00519</td>
#       <td>0.000513</td>
#       <td>0.0045</td>
#       <td>9.27</td>
#       <td>1</td>
#       <td>1e-05</td>
#       <td>51.3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>
td>
#     </tr>
#     <tr>
#       <th>Microscopic Reaction Entropy Production Rate</th>
#       <td>0.0159</td>
#       <td>0.00425</td>
#       <td>1.25</td>
#       <td>3.97e+03</td>
#       <td>3.97e+03</td>
#       <td>0.0325</td>
#       <td>0.161</td>
#       <td>0.713</td>
#       <td>0.0325</td>
#     </tr>
#     <tr>
#       <th>Microscopic Reaction Entropy Production Net Flux</th>
#       <td>0.0137</td>
#       <td>0.00296</td>
#       <td>1.24</td>
#       <td>3.97e+03</td>
#       <td>3.97e+03</td>
#       <td>0.0294</td>
#       <td>0.155</td>
#       <td>0.699</td>
#       <td>0.0294</td>
#     </tr>
#     <tr>
#       <th>Microscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>0.0127</td>
#       <td>0.00213</td>
#       <td>1.24</td>
#       <td>3.97e+03</td>
#       <td>3.97e+03</td>
#       <td>0.0284</td>
#       <td>0.154</td>
#       <td>0.698</td>
#       <td>0.0284</td>
#     </tr>
#     <tr>
#       <th>Total Entropy Production</th>
#       <td>0.744</td>
#       <td>0.744</td>
#       <td>0.744</td>
#       <td>0.744</td>
#       <td>0.744</td>
#       <td>0.744</td>
#       <td>0.744</td>
#       <td>0.744</td>
#       <td>0.744</td>
#     </tr>
#     <tr>
#       <th>Total Microscopic Entropy Production Rate</th>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#       <td>7.94e+03</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux</th>
#       <td>0.117</td>
#       <td>0.0641</td>
#       <td>0.906</td>
#       <td>17.8</td>
#       <td>17.8</td>
#       <td>0.165</td>
#       <td>0.351</td>
#       <td>0.699</td>
#       <td>0.165</td>
#     </tr>
#     <tr>
#       <th>Macroscopic Reaction Entropy Production Net Flux Difference</th>
#       <td>0.109</td>
#       <td>0.0461</td>
#       <td>0.905</td>
#       <td>17.8</td>
#       <td>17.8</td>
#       <td>0.159</td>
#       <td>0.349</td>
#       <td>0.698</td>
#       <td>0.159</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux</th>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>
#     </tr>
#     <tr>
#       <th>Total Macroscopic Entropy Production Net Flux Difference</th>
#       <td>38.1</td>
#       <td>38.1</td>
#       <td>38.1</td>

# %% [markdown]
# # Comparing the predictions of alternative objective functions #

# %%
import os, re
nonchar = re.compile('[^a-zA-Z0-9]')
for obj in metab:
    print(obj)
    if not os.path.exists(obj):
        os.makedirs(obj)
    for col in metab[obj].columns:
        filename = nonchar.sub('_',col)
        print("\t{}".format(filename))
        metab[obj][col].to_csv('{obj}/metab_{col}.tsv'.format(obj=obj,col=filename), sep='\t',header=True)
# Out:
# micro_maxent_production_net_flux_diff
# 	Counts
# 	Concentrations
# 	Log_Concentrations
# 	Standard_Chemical_potential
# 	Chemical_potential
# 	Normalized_Concentrations
# 	Absolute_activities
# 	Normalized_absolute_activities
# 	Entropy
# 	Entropy_of_Concentrations
# 	S_forward_rate
# 	S_backward_rate
# 	S_net_flux
# macro_maxent_production_rate_pyOpt_optimize_w_scipy_entropy
# 	Counts
# 	Concentrations
# 	Log_Concentrations
# 	Standard_Chemical_potential
# 	Chemical_potential
# 	Normalized_Concentrations
# 	Absolute_activities
# 	Normalized_absolute_activities
# 	Entropy
# 	Entropy_of_Concentrations
# 	S_forward_rate
# 	S_backward_rate
# 	S_net_flux
# convex_mentos_likelihoods_first_elmo
# 	Counts
# 	Concentrations
# 	Log_Concentrations
# 	Standard_Chemical_potential
# 	Chemical_potential
# 	Normalized_Concentrations
# 	Absolute_activities
# 	Normalized_absolute_activities
# 	Entropy
# 	Entropy_of_Concentrations
# 	S_forward_rate
# 	S_backward_rate
# 	S_net_flux

# %%
HTML(mentos.compare_frames(**metab).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th>A_ext</th>
#       <th>D_ext</th>
#       <th>E_ext</th>
#       <th>F_ext</th>
#     </tr>
td>
#     </tr>
#     <tr>
#       <th>micro_maxent_production_net_flux</th>
#       <td>0.0528</td>
#       <td>0.0528</td>
#       <td>0.0528</td>
#       <td>0.0528</td>
#       <td>0.0528</td>
#       <td>0.0528</td>
#       <td>0.0528</td>
#       <td>0.134</td>
#       <td>0.0528</td>
#     </tr>
#     <tr>
#       <th>macro_maxent_production_rate_scipy_optimize_w_scipy_entropy</th>
#       <td>8.06e-15</td>
#       <td>6.65e-12</td>
#       <td>1.35e-14</td>
#       <td>0.903</td>
#       <td>2.4e-19</td>
#       <td>6.48e-11</td>
#       <td>0.0728</td>
#       <td>4.1e-11</td>
#       <td>0.00812</td>
#     </tr>
#     <tr>
#       <th>macro_maxent_production_rate_pyOpt_optimize_w_p_log_p</th>
#       <td>5.93e-05</td>
#       <td>6.75e-05</td>
#       <td>0.00369</td>
#       <td>0.00369</td>
#       <td>0.00369</td>
#       <td>0.00647</td>
#       <td>0.000322</td>
#       <td>2.95e-05</td>
#       <td>0.000378</td>
#     </tr>
#     <tr>
#       <th>convex_mentos_likelihoods_first_elmo</th>
#       <td>1.11e-05</td>
#       <td>1.92e-05</td>
#       <td>0.000919</td>
#       <td>0.000192</td>
#       <td>0.000192</td>
#       <td>0.000502</td>
#       <td>0.

# %% [markdown]
# # Boltzmann comparison
#
# $$\begin{eqnarray}
# L_{net} & = &\frac{r_+}{r_-} - \frac{r_-}{r_+} \\
# & = &\frac{r_+}{r_+}\frac{r_+}{r_-} - \frac{r_-}{r_-} \frac{r_-}{r_+} \\
# & = & \frac{r_+^2 - r_-^2}{r_+r_-} \\
# & = & \frac{(r_+ + r_-)\cdot(r_+ - r_-)}{r_+r_-} \\
# & = &\frac{(r_+ + r_-)}{r_+r_-}\cdot v \\
# \frac{r_+r_-}{r_+ + r_-}\cdot L_{net} & = & v \\
# \end{eqnarray}$$

# %%
from mentos.abc_model import fullS, S, mets, rxns, mu0, deltaG0, internal_mets
fullS
# Out:
#        R_1  R_2  R_3  R_4  R_5  R_6  R_7  R_8  R_9
# A        1   -1   -1    0    0    0    0    0    0
# B        0    1    0   -1    0   -2    0    0    0
# C        0    0    1    0    0    1   -1    0    0
# D        0    0    0    2    0    0    1   -1    0
# E        0    0    0   -1    1    0    0    0    0
# F        0    0    0    0    0    1    0    0   -1
# A_ext   -1    0    0    0    0    0    0    0    0
# D_ext    0    0    0    0    0    0    0    1    0
# E_ext    0    0    0    0   -1    0    0    0    0
# F_ext    0    0    0    0    0    0    0    0    1

# %% [markdown]
# ## Computing the forward and reverse rates from the likelihood and the flux ##
# From the definition of forward likelihood and net flux:
#
# $$\begin{eqnarray}
# L_+ &=& \frac{r_{+}}{r_{-}} \\
# v &=& r_{+} - r_{-} \\
# \end{eqnarray}$$
#
# We can solve for the forward reaction rates $r_{+}$ and $r_{-}$:
# $$\begin{eqnarray}
# r_{-} & = & \frac{r_{+}}{L_+} \\
#  r_{+}  - r_{-} & = & v\\
#  r_{+} - \frac{r_{+}}{L_+} & = & v \\
# r_{+}(1 -\frac{1}{L_+}) & = & v \\
# r_{+} & = & \frac{v}{1-\frac{1}{L_+}} \\
#        & = & \frac{L_+v}{L_+ - 1} \\
# r_{-} & = & \frac{v}{L_+ - 1}  \\
# \end{eqnarray}$$

# %%
forward_likelihood = pd.Series(dict(R_1 =  63.6,
R_2 =  56.7,
R_3  = 7.05,
R_4 =  50.4,
R_5 =  50.4,
R_6 =   3.4,
R_7 =  10.1,
R_8 =   111,
R_9 =   3.4))
backward_likelihood = np.reciprocal(forward_likelihood)
net_likelihood = forward_likelihood - backward_likelihood
display(net_likelihood)
fullS.dot(net_likelihood)

forward_rate = forward_likelihood*net_likelihood/(forward_likelihood - 1)
forward_rate

backward_rate = net_likelihood/(forward_likelihood - 1)
backward_rate

reduced_rate = forward_rate * backward_rate/(forward_rate + backward_rate)
reduced_rate
allrates = pd.DataFrame({r'$L_+$':forward_likelihood, r'$L_-$':backward_likelihood,r'$L_{net}$':net_likelihood, r'$r_+$':forward_rate,r'$r_-$':backward_rate,r'$\frac{r_+r_-}{r_++r_-}$':reduced_rate })
allrates
# Out:
# R_1   63.6
# R_2   56.7
# R_3   6.91
# R_4   50.4
# R_5   50.4
# R_6   3.11
# R_7     10
# R_8    111
# R_9   3.11
# dtype: float64
#      $L_+$   $L_-$  $L_{net}$  $\frac{r_+r_-}{r_++r_-}$  $r_+$  $r_-$
# R_1   63.6  0.0157       63.6                         1   64.6   1.02
# R_2   56.7  0.0176       56.7                         1   57.7   1.02
# R_3   7.05   0.142       6.91                         1   8.05   1.14
# R_4   50.4  0.0198       50.4                         1   51.4   1.02
# R_5   50.4  0.0198       50.4                         1   51.4   1.02
# R_6    3.4   0.294       3.11                         1    4.4   1.29
# R_7   10.1   0.099         10                         1   11.1    1.1
# R_8    111 0.00901        111                         1    112   1.01
# R_9    3.4   0.294       3.11                         1    4.4   1.29

# %%
fullS.dot(allrates)
# Out:
#        $L_+$   $L_-$  $L_{net}$  $\frac{r_+r_-}{r_++r_-}$  $r_+$  $r_-$
# A      -0.15  -0.144   -0.00624                        -1  -1.15  -1.14
# B       -0.5   -0.59     0.0904                        -2   -2.5  -2.59
# C       0.35   0.337      0.013                         1   1.35   1.34
# D       -0.1    0.13      -0.23                         2    1.9   2.13
# E          0       0          0                         0      0      0
# F          0       0          0                         0      0      0
# A_ext  -63.6 -0.0157      -63.6                        -1  -64.6  -1.02
# D_ext    111 0.00901        111                         1    112   1.01
# E_ext  -50.4 -0.0198      -50.4                        -1  -51.4  -1.02
# F_ext    3.4   0.294       3.11                         1    4.4   1.29

# %% [markdown]
# ## Comparing Boltzmann output vs various mentos variations

# %%
concs = """
A       1.57e-05
A_ext      0.001
B       6.22e-07
C          5e-06
D       1.11e-06
D_ext      1e-08
E       1.98e-05
E_ext      0.001
F        3.4e-08
F_ext      1e-08
"""
log_conc_boltzmann = pd.Series(dict([met_conc.split() for met_conc in concs.strip().split('\n')])).astype(float).apply(np.log)
log_conc_boltzmann

algorithm = 'boltzmann'
reactions[algorithm] = mentos.generate_rxn_report(mets, log_conc_boltzmann, fullS.T.dot(log_conc_boltzmann), 1/(-R*T)*fullS.T.dot(mu0),
                                                         forward_rate, backward_rate, rxns, deltaG0,'R_8')
reactions[algorithm].T

metab[algorithm] = mentos.generate_metabolite_report( log_conc_boltzmann,
                                                              forward_rate, backward_rate, S, mets, internal_mets, 
                                                             rxns, fullS, mu0).astype(np.float64)
display(HTML(mentos.compare_frames(**metab).to_html()))
#display(HTML(metab[algorithm].T.to_html()))

display(HTML(mentos.compare_frames(**reactions).to_html()))
#display(HTML(reactions[algorithm].T.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>A</th>
#       <th>B</th>
#       <th>C</th>
#       <th>D</th>
#       <th>E</th>
#       <th>F</th>
#       <th